# %%
import glob
import numpy
import pandas
import seaborn
import matplotlib.pyplot as plt
from tqdm import tqdm
import multiprocessing as mp
import os
from build import build_model

# %%
from IPython.display import display, HTML, Math, Markdown
display(HTML("<style>.container { width:95% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# !bash report.sh
organisms = set(pandas.read_csv("biomass_constrained.txt",index_col=0,header=None).index.to_list())
done = {i.split(".csv")[0] for i in os.listdir("./cases/fluxes/low-0.5_lipid/")}

# %%
run_for = organisms - done
len(run_for)
# Out:
# 495

# %%
# exchanges = ["EX_ac(e)","EX_but(e)","EX_ppa(e)"]

# %%
exchanges = ["EX_arachd(e)",
            "EX_chsterol(e)",
            "EX_glyc(e)",
            "EX_hdca(e)",
            "EX_hdcea(e)",
            "EX_lnlc(e)",
            "EX_lnlnca(e)",
            "EX_lnlncg(e)",
            "EX_ocdca(e)",
            "EX_ocdcea(e)",
            "EX_octa(e)",
            "EX_ttdca(e)"]

# %%
from diets import load_model,constrain_exchanges,get_bounds
from overflow import get_overflow
import coralme

conditions = ["low-0.5"]
metabolite = "lipid"
# metabolite = "FA"

for c in conditions:
    name = "{}_{}".format(c,metabolite)
    fluxdir = "./cases/fluxes/{}".format(name)
    overflowdir = "./cases/overflow/{}".format(name)
    if not os.path.isdir(fluxdir):
        os.makedirs(fluxdir)
        os.makedirs(overflowdir)

def run(org):
    model = coralme.io.pickle.load_pickle_me_model("./me-models/{}/MEModel-BIO-{}-ME-TS.pkl".format(org,org))
    # return model
    sol0 = model.solution
    df0 = sol0.to_frame()
    # Exchanges
    rlist = [r for r in exchanges if model.reactions.has_id(r)]
    # Run for all conditions
    for condition in conditions:
        name = "{}_{}".format(condition,metabolite)
        # dct = {k:-0.5 for k in rlist if k in model.reactions}
        dct = get_bounds(sol0,rlist,multiplier=0.5) # low
        constrain_exchanges(model,dct)
        model.optimize()
        model.solution.to_frame().to_csv("cases/fluxes/{}/{}.csv".format(name,org))
        get_overflow(model).to_csv("./cases/overflow/{}/{}.csv".format(name,org))

# %%
NP = min([20,len(run_for)])
pool = mp.Pool(NP,maxtasksperchild=1)
pbar = tqdm(total=len(run_for),position=0,leave=True)
pbar.set_description('Building ({} threads)'.format(NP))
def collect_result(result):
    pbar.update(1)

for org in run_for:
    args = ([org])
    pool.apply_async(run,args, callback=collect_result)
pool.close()
pool.join()
# Out:
# Building (20 threads):   0%|          | 0/495 [00:00<?, ?it/s]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpzmu2efw8.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmplc7lh43z.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpnq324xoe.lp
# Reading time = 0.00 seconds
# : 962 rows, 2212 columns, 9500 nonzeros
# Read LP format model from file /tmp/tmpa39ef7oa.lp
# Reading time = 0.00 seconds
# : 832 rows, 1698 columns, 7376 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp6lh4dbs5.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp60bes3y7.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpdep9f77p.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpsjpo6fh_.lp
# Reading time = 0.00 seconds
# : 884 rows, 1928 columns, 8230 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp8ro2y_sb.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpdn4_5unr.lp
# Reading time = 0.00 seconds
# : 938 rows, 1938 columns, 8484 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpdg37ecfr.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpbqkb0mc4.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpkqrgmyhu.lp
# Reading time = 0.00 seconds
# Set parameter Username
# : 835 rows, 1878 columns, 7730 nonzeros
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpdtheyqug.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpv0x80dqc.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp0nf2qc4i.lp
# Reading time = 0.00 seconds
# : 917 rows, 1946 columns, 8318 nonzeros
# Read LP format model from file /tmp/tmpuj5v175x.lp
# Reading time = 0.00 seconds
# : 1103 rows, 2652 columns, 11452 nonzeros
# Read LP format model from file /tmp/tmptieeiyg5.lp
# Reading time = 0.00 seconds
# : 1086 rows, 2392 columns, 10338 nonzeros
# Read LP format model from file /tmp/tmph6p8u_89.lp
# Reading time = 0.00 seconds
# : 917 rows, 1958 columns, 8346 nonzeros
# Read LP format model from file /tmp/tmp40z1kt6w.lp
# Reading time = 0.01 seconds
# : 998 rows, 2318 columns, 9944 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpkqk62jco.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpjw01rniv.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp9ziwxfxd.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpuima7ydy.lp
# Reading time = 0.00 seconds
# : 964 rows, 2210 columns, 9300 nonzeros
# Set parameter Username
# Read LP format model from file /tmp/tmp1ew7y7w3.lp
# Reading time = 0.00 seconds
# : 1160 rows, 2786 columns, 11382 nonzeros
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp4ud5j788.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmph9msb7m4.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp8zgtoydd.lp
# Reading time = 0.01 seconds
# : 1067 rows, 2358 columns, 10396 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmptpma9kpd.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp7dwwa8am.lp
# Reading time = 0.01 seconds
# : 1068 rows, 2404 columns, 10112 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpz6o1a93v.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp3inbnbic.lp
# Reading time = 0.00 seconds
# Read LP format model from file /tmp/tmpg0z7owmm.lp
# : 1061 rows, 2590 columns, 11398 nonzeros
# Reading time = 0.01 seconds
# : 850 rows, 1696 columns, 7176 nonzeros
# Read LP format model from file /tmp/tmpdcsh211h.lp
# Reading time = 0.01 seconds
# : 1122 rows, 2626 columns, 11096 nonzeros
# Read LP format model from file /tmp/tmpx_yp6o1e.lp
# Reading time = 0.01 seconds
# : 1069 rows, 2428 columns, 10312 nonzeros
# Read LP format model from file /tmp/tmpjfom3hts.lp
# Reading time = 0.01 seconds
# : 1190 rows, 2754 columns, 11850 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpayhyny43.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp704tp3q1.lp
# Reading time = 0.01 seconds
# : 961 rows, 1936 columns, 8364 nonzeros
# Read LP format model from file /tmp/tmph6gbp01e.lp
# Reading time = 0.00 seconds
# : 1109 rows, 2390 columns, 10218 nonzeros
# Read LP format model from file /tmp/tmp30a0xhas.lp
# Reading time = 0.00 seconds
# : 836 rows, 1876 columns, 7610 nonzeros
# Read LP format model from file /tmp/tmpbjar9luc.lp
# Reading time = 0.00 seconds
# : 906 rows, 1926 columns, 8030 nonzeros
# Read LP format model from file /tmp/tmp9np1pkxy.lp
# Reading time = 0.01 seconds
# : 1257 rows, 2964 columns, 13012 nonzeros
# Read LP format model from file /tmp/tmpe2z59p5c.lp
# Reading time = 0.00 seconds
# : 942 rows, 1944 columns, 8198 nonzeros
# Read LP format model from file /tmp/tmp7ggfxnob.lp
# Reading time = 0.01 seconds
# : 942 rows, 1956 columns, 8226 nonzeros
# Read LP format model from file /tmp/tmpj861jxqj.lp
# Reading time = 0.01 seconds
# : 1000 rows, 2316 columns, 9744 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp7p6t4a6f.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpe7ustvpi.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp54om3syy.lp
# Reading time = 0.00 seconds
# : 1185 rows, 2784 columns, 11212 nonzeros
# Read LP format model from file /tmp/tmp1cs3fv13.lp
# Reading time = 0.00 seconds
# : 1128 rows, 2650 columns, 11252 nonzeros
# Read LP format model from file /tmp/tmpnjg_xy4k.lp
# Reading time = 0.01 seconds
# : 1297 rows, 3258 columns, 14028 nonzeros
# Read LP format model from file /tmp/tmpyvhdbdxp.lp
# Reading time = 0.01 seconds
# : 1379 rows, 3634 columns, 15408 nonzeros
# Read LP format model from file /tmp/tmpryhuvxqb.lp
# Reading time = 0.01 seconds
# : 1089 rows, 2588 columns, 11278 nonzeros
# Read LP format model from file /tmp/tmpv674yj8t.lp
# Reading time = 0.00 seconds
# : 1215 rows, 2752 columns, 11680 nonzeros
# Read LP format model from file /tmp/tmpxbjtou20.lp
# Reading time = 0.00 seconds
# : 1081 rows, 2356 columns, 10196 nonzeros
# Read LP format model from file /tmp/tmp0uigmhvf.lp
# Reading time = 0.01 seconds
# : 1091 rows, 2402 columns, 9990 nonzeros
# Read LP format model from file /tmp/tmpkzw7yzsl.lp
# Reading time = 0.01 seconds
# : 1094 rows, 2426 columns, 10190 nonzeros
# Read LP format model from file /tmp/tmp1spf7py6.lp
# Reading time = 0.01 seconds
# : 1147 rows, 2624 columns, 10926 nonzeros
# Read LP format model from file /tmp/tmpild0qe08.lp
# Reading time = 0.00 seconds
# : 1270 rows, 2962 columns, 12842 nonzeros
# Read LP format model from file /tmp/tmpgluuehg6.lp
# Reading time = 0.01 seconds
# : 1330 rows, 3256 columns, 13858 nonzeros
# Read LP format model from file /tmp/tmpve3tu7mu.lp
# Reading time = 0.01 seconds
# : 1418 rows, 3632 columns, 15288 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
#         3	0.3512570171756479	Not feasible
#         2	0.7025140343512959	Not feasible
#         2	0.7025140343512959	Not feasible
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
#         2	0.7025140343512959	Not feasible
#         1	1.4050280687025918	Not feasible
#         4	0.1756285085878240	Not feasible
#         3	0.3512570171756479	Not feasible
#         3	0.3512570171756479	Not feasible
#         3	0.3512570171756479	Not feasible
#         3	0.3512570171756479	Not feasible
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
#         5	0.0878142542939120	Not feasible
#         1	1.4050280687025918	Not feasible
#         3	0.3512570171756479	Not feasible
#         1	1.4050280687025918	Not feasible
#         4	0.1756285085878240	Not feasible
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         4	0.1756285085878240	Not feasible
#         6	0.0439071271469560	Not feasible
#         1	1.4050280687025918	Not feasible
#         4	0.1756285085878240	Not feasible
#         4	0.1756285085878240	Not feasible
#         2	0.7025140343512959	Not feasible
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
#         7	0.0219535635734780	Not feasible
#         5	0.0878142542939120	Not feasible
#         4	0.1756285085878240	Not feasible
#         3	0.3512570171756479	Not feasible
#         1	1.4050280687025918	Not feasible
#         5	0.0878142542939120	Not feasible
#         2	0.7025140343512959	Not feasible
#         1	1.4050280687025918	Not feasible
#         5	0.0878142542939120	Not feasible
#         5	0.0878142542939120	Optimal
#         8	0.0109767817867390	Not feasible
#         6	0.1317213814408680	Not feasible
#         6	0.0439071271469560	Optimal
#         2	0.7025140343512959	Not feasible
#         2	0.7025140343512959	Not feasible
#         7	0.1097678178673900	Not feasible
#         8	0.0987910360806510	Not feasible
#         7	0.0658606907204340	Not feasible
#         9	0.0933026451872815	Not feasible
#         6	0.0439071271469560	Not feasible
#         2	0.7025140343512959	Not feasible
#         5	0.0878142542939120	Not feasible
#         8	0.0548839089336950	Optimal
#         9	0.0054883908933695	Not feasible
#         3	0.3512570171756479	Not feasible
#        10	0.0905584497405967	Optimal
#         6	0.0439071271469560	Not feasible
#         9	0.0603722998270645	Not feasible
#        11	0.0919305474639391	Optimal
#         4	0.1756285085878240	Not feasible
#        10	0.0576281043803797	Optimal
#        12	0.0926165963256103	Not feasible
#        13	0.0922735718947747	Not feasible
#        11	0.0590002021037221	Optimal
#        14	0.0921020596793569	Not feasible
#         2	0.7025140343512959	Not feasible
#        12	0.0596862509653933	Not feasible
#        15	0.0920163035716480	Not feasible
#         3	0.3512570171756479	Not feasible
#        10	0.0027441954466847	Not feasible
#         1	1.4050280687025918	Not feasible
#        16	0.0919734255177936	Not feasible
#        13	0.0593432265345577	Optimal
#         2	0.7025140343512959	Not feasible
#        17	0.0919519864908663	Not feasible
#        14	0.0595147387499755	Not feasible
#         7	0.0219535635734780	Optimal
#        18	0.0919412669774027	Not feasible
#        15	0.0594289826422666	Not feasible
#         3	0.3512570171756479	Not feasible
#         2	0.7025140343512959	Not feasible
#        19	0.0919359072206709	Not feasible
#        16	0.0593861045884122	Optimal
#         8	0.0329303453602170	Optimal
#         7	0.0219535635734780	Optimal
#         6	0.0439071271469560	Optimal
#         3	0.3512570171756479	Not feasible
#        20	0.0919332273423050	Optimal
#        17	0.0594075436153394	Not feasible
#         9	0.0384187362535865	Not feasible
#        21	0.0919345672814880	Not feasible
#        18	0.0593968241018758	Optimal
#         8	0.0329303453602170	Optimal
#        22	0.0919338973118965	Optimal
# Building (20 threads):   0%|          | 1/495 [01:36<13:10:43, 96.04s/it]
#         7	0.0658606907204340	Optimal
#        19	0.0594021838586076	Not feasible
#        11	0.0013720977233424	Optimal
#        20	0.0593995039802417	Not feasible
#        12	0.0020581465850136	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp6si0zkjb.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpjmgl8ohn.lp
# Reading time = 0.00 seconds
# : 1002 rows, 2176 columns, 9304 nonzeros
#        10	0.0356745408069017	Optimal
#         2	0.7025140343512959	Not feasible
#         3	0.3512570171756479	Not feasible
#         8	0.0768374725071730	Optimal
#         9	0.0384187362535865	Not feasible
#        13	0.0017151221541780	Optimal
#        21	0.0593981640410587	Optimal
# Read LP format model from file /tmp/tmpu9pj8zc_.lp
# Reading time = 0.00 seconds
# : 1025 rows, 2174 columns, 9182 nonzeros
#        14	0.0018866343695958	Not feasible
#        22	0.0593988340106502	Optimal
# Building (20 threads):   0%|          | 2/495 [01:39<5:41:14, 41.53s/it]
#        11	0.0370466385302441	Optimal
#        10	0.0356745408069017	Not feasible
#         4	0.1756285085878240	Optimal
#        15	0.0018008782618869	Optimal
#        16	0.0018437563157413	Not feasible
#        12	0.0377326873919153	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp48vsqgoz.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        17	0.0018223172888141	Not feasible
#        11	0.0343024430835594	Optimal
# Read LP format model from file /tmp/tmpc5cohtio.lp
# Reading time = 0.01 seconds
# : 1280 rows, 3176 columns, 13856 nonzeros
#        18	0.0018115977753505	Not feasible
#         9	0.0823258634005425	Optimal
#         3	0.3512570171756479	Not feasible
#        19	0.0018062380186187	Not feasible
#         5	0.0878142542939120	Not feasible
#        12	0.0349884919452306	Not feasible
#        20	0.0018035581402528	Not feasible
# Read LP format model from file /tmp/tmpm6_zgtiw.lp
# Reading time = 0.01 seconds
# : 1305 rows, 3174 columns, 13686 nonzeros
#        10	0.0850700588472272	Not feasible
#         5	0.2634427628817360	Optimal
#        21	0.0018022182010698	Not feasible
#        13	0.0373896629610797	Optimal
#        22	0.0018015482314783	Optimal
# Building (20 threads):   1%|          | 3/495 [01:44<3:23:08, 24.77s/it]
#        11	0.0836979611238849	Not feasible
#        13	0.0346454675143950	Not feasible
#        14	0.0375611751764975	Not feasible
#        12	0.0830119122622137	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpvb_b6_3x.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpmp9q8sdg.lp
# Reading time = 0.00 seconds
# : 1212 rows, 2852 columns, 12378 nonzeros
#        14	0.0344739552989772	Optimal
#        13	0.0826688878313781	Optimal
# Read LP format model from file /tmp/tmphqg2t5g_.lp
# Reading time = 0.00 seconds
# : 1229 rows, 2850 columns, 12178 nonzeros
#        15	0.0374754190687886	Not feasible
#         6	0.3073498900286920	Optimal
#        15	0.0345597114066861	Optimal
#        14	0.0828404000467959	Optimal
#         4	0.1756285085878240	Not feasible
#        16	0.0346025894605405	Optimal
#        15	0.0829261561545048	Not feasible
#         7	0.3293034536021699	Optimal
#        17	0.0346240284874677	Optimal
#        16	0.0374325410149342	Optimal
#        16	0.0828832781006503	Not feasible
#        17	0.0828618390737231	Optimal
#        18	0.0346347480009313	Optimal
#        17	0.0374539800418614	Not feasible
#         4	0.1756285085878240	Not feasible
#         8	0.3402802353889089	Optimal
#        18	0.0828725585871867	Optimal
#        19	0.0346401077576632	Not feasible
#        19	0.0828779183439185	Optimal
#        18	0.0374432605283978	Not feasible
#         9	0.3457686262822784	Not feasible
#         3	0.3512570171756479	Optimal
#        20	0.0346374278792973	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        20	0.0828805982222844	Optimal
#        19	0.0374379007716660	Not feasible
#        21	0.0346360879401143	Optimal
#        21	0.0828819381614674	Not feasible
#        10	0.3430244308355937	Not feasible
#        22	0.0828812681918759	Optimal
#         3	0.3512570171756479	Not feasible
# Building (20 threads):   1%|          | 4/495 [01:56<2:41:41, 19.76s/it]
#        22	0.0346367579097058	Optimal
# Building (20 threads):   1%|          | 5/495 [01:56<1:43:49, 12.71s/it]
#        11	0.3416523331122513	Not feasible
#        20	0.0374352208933001	Optimal
#         3	0.3512570171756479	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpvwojuuai.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpwk_8p35o.lp
# Reading time = 0.00 seconds
# : 896 rows, 1938 columns, 8522 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp4a8mn1od.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpx0_nhhn4.lp
# Reading time = 0.00 seconds
# : 980 rows, 2084 columns, 9160 nonzeros
#         4	0.1756285085878240	Optimal
# Read LP format model from file /tmp/tmpyvdixwhy.lp
# Reading time = 0.00 seconds
# : 919 rows, 1936 columns, 8352 nonzeros
#         6	0.0439071271469560	Optimal
#        21	0.0374365608324830	Not feasible
#        12	0.3409662842505801	Optimal
# Read LP format model from file /tmp/tmpvxfyu01m.lp
# Reading time = 0.00 seconds
#         4	0.5268855257634719	Not feasible: 983 rows, 2082 columns, 8990 nonzeros
#
#         7	0.0658606907204340	Optimal
#         2	0.7025140343512959	Not feasible
#        13	0.3413093086814157	Optimal
#        22	0.0374358908628915	Optimal
# Building (20 threads):   1%|          | 6/495 [02:01<1:22:49, 10.16s/it]
#         5	0.4390712714695599	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpl8gyvgla.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpzeiyk5nz.lp
# Reading time = 0.00 seconds
# : 784 rows, 1646 columns, 7082 nonzeros
#         4	0.1756285085878240	Optimal
#         5	0.2634427628817360	Not feasible
#         4	0.1756285085878240	Not feasible
# Read LP format model from file /tmp/tmpgp2xcv9u.lp
# Reading time = 0.00 seconds
# : 806 rows, 1644 columns, 6962 nonzeros
#        14	0.3414808208968335	Not feasible
#         8	0.0768374725071730	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         3	0.3512570171756479	Not feasible
#         5	0.2634427628817360	Not feasible
#         1	1.4050280687025918	Not feasible
#         6	0.2195356357347800	Not feasible
#         6	0.3951641443226039	Optimal
#        15	0.3413950647891246	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         9	0.0713490816138035	Optimal
#         6	0.2195356357347800	Not feasible
#         5	0.0878142542939120	Not feasible
#         5	0.0878142542939120	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         7	0.1975820721613020	Not feasible
#         7	0.4171177078960819	Optimal
#        10	0.0740932770604882	Not feasible
#        16	0.3413521867352702	Optimal
#         7	0.1975820721613020	Optimal
#         8	0.1866052903745630	Not feasible
#        11	0.0727211793371459	Optimal
#         8	0.4280944896828209	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         6	0.1317213814408680	Not feasible
#        17	0.3413736257621974	Not feasible
#        12	0.0734072281988171	Optimal
#         9	0.4335828805761904	Optimal
#         1	1.4050280687025918	Not feasible
#         8	0.2085588539480410	Optimal
#        13	0.0737502526296527	Not feasible
#        10	0.4363270760228752	Not feasible
#         9	0.1811168994811935	Optimal
#         9	0.2140472448414105	Not feasible
#        14	0.0735787404142348	Optimal
#        18	0.3413629062487338	Not feasible
#         4	0.1756285085878240	Not feasible
#        15	0.0736644965219437	Optimal
#         7	0.1097678178673900	Optimal
#        11	0.4349549782995328	Not feasible
#         1	1.4050280687025918	Not feasible
#        16	0.0737073745757982	Not feasible
#        10	0.1838610949278782	Optimal
#        12	0.4342689294378616	Not feasible
#        19	0.3413575464920020	Not feasible
#         8	0.1207445996541290	Optimal
#        10	0.2113030493947257	Optimal
#        17	0.0736859355488710	Optimal
#        11	0.1852331926512206	Not feasible
#        13	0.4339259050070260	Optimal
#         1	1.4050280687025918	Not feasible
#        18	0.0736966550623346	Optimal
#        12	0.1845471437895494	Not feasible
#         6	0.0439071271469560	Not feasible
#        20	0.3413548666136361	Not feasible
#        11	0.2126751471180681	Optimal
#        19	0.0737020148190664	Not feasible
#         5	0.0878142542939120	Not feasible
#        14	0.4340974172224438	Optimal
#        13	0.1842041193587138	Not feasible
#         9	0.1262329905474985	Optimal
#        20	0.0736993349407005	Not feasible
#        10	0.1289771859941832	Not feasible
#        14	0.1840326071432960	Not feasible       15	0.4341831733301527	Optimal
#
#        21	0.0736979950015176	Not feasible
#         4	0.1756285085878240	Optimal
#        21	0.3413535266744532	Optimal
#        12	0.2133611959797393	Optimal
#        11	0.1276050882708409	Optimal
#        16	0.4342260513840072	Optimal
#        15	0.1839468510355871	Not feasible
#        22	0.0736973250319261	Not feasible
# Building (20 threads):   1%|▏         | 7/495 [02:29<2:08:29, 15.80s/it]
#        12	0.1282911371325121	Optimal
#        16	0.1839039729817327	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmprln8foa2.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp6ztmxjf3.lp
# Reading time = 0.00 seconds
# : 1008 rows, 2248 columns, 9700 nonzeros
#         1	1.4050280687025918	Not feasible
#        17	0.4342474904109344	Optimal
#         1	1.4050280687025918	Not feasible
#        22	0.3413541966440446	Not feasible
# Building (20 threads):   2%|▏         | 8/495 [02:31<1:32:22, 11.38s/it]
#        13	0.2137042204105749	Optimal
#        17	0.1838825339548054	Not feasible
# Read LP format model from file /tmp/tmpom9pmp1u.lp
# Reading time = 0.01 seconds
# : 1038 rows, 2246 columns, 9530 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpwcafdqx7.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpssr74x3d.lp
# Reading time = 0.00 seconds
# : 850 rows, 1822 columns, 7954 nonzeros
#        13	0.1286341615633476	Not feasible
#        18	0.4342582099243980	Optimal
#        18	0.1838718144413418	Optimal
#         2	0.7025140343512959	Not feasible
# Read LP format model from file /tmp/tmpi7wxgvaw.lp
# Reading time = 0.00 seconds
# : 876 rows, 1820 columns, 7834 nonzeros
#        14	0.1284626493479298	Optimal
#         4	0.1756285085878240	Not feasible
#        14	0.2138757326259927	Optimal
#        19	0.1838771741980736	Optimal
#        19	0.4342635696811298	Optimal
#         5	0.2634427628817360	Not feasible
#         2	0.7025140343512959	Not feasible
#         3	0.3512570171756479	Not feasible
#        15	0.2139614887337016	Not feasible
#        20	0.1838798540764395	Optimal
#        15	0.1285484054556387	Not feasible
#        20	0.4342662495594957	Optimal
#        21	0.1838811940156225	Not feasible
#        16	0.1285055274017843	Not feasible
#        21	0.4342675894986786	Optimal
#         6	0.2195356357347800	Not feasible
#        16	0.2139186106798471	Optimal
#        22	0.1838805240460310	Optimal
# Building (20 threads):   2%|▏         | 9/495 [02:40<1:26:21, 10.66s/it]
#        22	0.4342682594682701	Optimal
#        17	0.1284840883748571	Optimal
# Building (20 threads):   2%|▏         | 10/495 [02:40<1:01:18,  7.59s/it]
#         7	0.0219535635734780	Not feasible
#        17	0.2139400497067744	Not feasible
#         2	0.7025140343512959	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpiajewevd.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpf2uaylxx.lp
# Reading time = 0.01 seconds
# : 1117 rows, 2510 columns, 10880 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpd18468xj.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmps1jgfkwm.lp
# Reading time = 0.00 seconds
# : 940 rows, 2010 columns, 8560 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         2	0.7025140343512959	Not feasible
#        18	0.1284948078883207	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmpi9e64d1_.lp
# Reading time = 0.01 seconds
# : 1137 rows, 2508 columns, 10710 nonzeros
# Read LP format model from file /tmp/tmpm0z0716v.lp
# Reading time = 0.00 seconds
# : 965 rows, 2008 columns, 8440 nonzeros
#        18	0.2139293301933107	Not feasible
#         6	0.0439071271469560	Not feasible
#        19	0.1285001676450525	Not feasible
#         3	0.3512570171756479	Not feasible
#        19	0.2139239704365789	Not feasible
#         5	0.0878142542939120	Optimal
#         7	0.1975820721613020	Optimal
#        20	0.1284974877666866	Not feasible
#        21	0.1284961478275036	Optimal
#        22	0.1284968177970951	Not feasible
# Building (20 threads):   2%|▏         | 11/495 [02:48<1:02:32,  7.75s/it]
#        20	0.2139212905582130	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpgwv_y7tm.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpltk57oxq.lp
# Reading time = 0.01 seconds
# : 994 rows, 2216 columns, 9424 nonzeros
#         8	0.2085588539480410	Optimal
#         3	0.3512570171756479	Not feasible
# Read LP format model from file /tmp/tmpzerh7l91.lp
# Reading time = 0.01 seconds
# : 1019 rows, 2214 columns, 9304 nonzeros
#         3	0.3512570171756479	Not feasible
#         2	0.7025140343512959	Not feasible
#        21	0.2139226304973960	Optimal
#         3	0.3512570171756479	Not feasible
#         6	0.1317213814408680	Not feasible
#         5	0.0878142542939120	Optimal
#         4	0.1756285085878240	Not feasible
#         8	0.0109767817867390	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         9	0.2140472448414105	Optimal
#        22	0.2139233004669874	Optimal
# Building (20 threads):   2%|▏         | 12/495 [02:56<1:02:19,  7.74s/it]
#         6	0.1317213814408680	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpok6i3lua.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpurfeb6wf.lp
# Reading time = 0.00 seconds
# : 943 rows, 2030 columns, 8706 nonzeros
#        10	0.2167914402880952	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmpga0qq4uq.lp
# Reading time = 0.00 seconds
# : 966 rows, 2028 columns, 8584 nonzeros
#         7	0.1097678178673900	Optimal
#         4	0.1756285085878240	Not feasible
#         7	0.1536749450143460	Optimal
#         7	0.0219535635734780	Not feasible
#        11	0.2181635380114376	Not feasible
#         8	0.1646517268010850	Optimal
#        12	0.2174774891497664	Optimal
#         4	0.1756285085878240	Not feasible
#         8	0.1207445996541290	Not feasible
#        13	0.2178205135806020	Not feasible
#         5	0.0878142542939120	Not feasible
#         2	0.7025140343512959	Not feasible
#         5	0.0878142542939120	Not feasible
#         9	0.0054883908933695	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        14	0.2176490013651842	Not feasible
#         9	0.1701401176944545	Optimal
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         4	0.1756285085878240	Not feasible
#         1	1.4050280687025918	Not feasible
#        15	0.2175632452574753	Not feasible
#         6	0.0439071271469560	Not feasible
#         9	0.1152562087607595	Optimal
# Iteration	 Solution to check	Solver Status        8	0.0109767817867390	Not feasible
#
# ---------	------------------	-------------
#        16	0.2175203672036208	Optimal
#         4	0.1756285085878240	Not feasible
#         5	0.0878142542939120	Not feasible
#         1	1.4050280687025918	Not feasible
#        17	0.2175418062305481	Optimal
#        10	0.1180004042074442	Optimal
#        10	0.1728843131411392	Not feasible
#         3	0.3512570171756479	Not feasible
#         6	0.0439071271469560	Not feasible
#         2	0.7025140343512959	Not feasible
#        11	0.1193725019307866	Not feasible
#        18	0.2175525257440117	Not feasible
#         7	0.0219535635734780	Not feasible
#        12	0.1186864530691154	Not feasible
#        10	0.0027441954466847	Optimal
#        19	0.2175471659872799	Optimal
#         2	0.7025140343512959	Not feasible
#        11	0.0041162931700271	Not feasible
#        11	0.1715122154177968	Not feasible
#        13	0.1183434286382798	Optimal
#         6	0.0439071271469560	Not feasible
#        20	0.2175498458656458	Not feasible
#         2	0.7025140343512959	Not feasible
#         5	0.0878142542939120	Optimal
#        12	0.0034302443083559	Optimal
#        12	0.1708261665561256	Not feasible
#        21	0.2175485059264628	Not feasible
#        14	0.1185149408536976	Not feasible
#        13	0.0037732687391915	Optimal
#         8	0.0109767817867390	Optimal
#         6	0.1317213814408680	Optimal
#        15	0.1184291847459887	Not feasible
#         7	0.0219535635734780	Not feasible
#        22	0.2175478359568713	Not feasible
# Building (20 threads):   3%|▎         | 13/495 [03:33<2:13:01, 16.56s/it]
#         9	0.0164651726801085	Optimal
#        13	0.1704831421252901	Not feasible
#         9	0.0054883908933695	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpej171kvo.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpon7lc6q8.lp
# Reading time = 0.00 seconds
# : 915 rows, 1964 columns, 8588 nonzeros
#         7	0.1536749450143460	Optimal
# Read LP format model from file /tmp/tmp8s4ht6uz.lp
# Reading time = 0.01 seconds
# : 940 rows, 1962 columns, 8468 nonzeros
#        16	0.1183863066921343	Optimal
#        10	0.0192093681267932	Not feasible
#        14	0.0039447809546093	Not feasible
#         1	1.4050280687025918	Not feasible
#         3	0.3512570171756479	Not feasible
#        14	0.1703116299098723	Not feasible
#         1	1.4050280687025918	Not feasible
#        15	0.0038590248469004	Not feasible
#        17	0.1184077457190615	Optimal
#         2	0.7025140343512959	Not feasible
#        16	0.0038161467930460	Not feasible
#        15	0.1702258738021634	Optimal
#         8	0.1646517268010850	Optimal
#        17	0.0037947077661188	Not feasible
#        18	0.1184184652325251	Not feasible
#        18	0.0037839882526551	Not feasible
#        11	0.0178372704034509	Not feasible
#         7	0.0219535635734780	Not feasible
#         9	0.1701401176944545	Not feasible
#        16	0.1702687518560178	Not feasible
#        19	0.1184131054757933	Not feasible
#         3	0.3512570171756479	Not feasible
#        19	0.0037786284959233	Not feasible
#        12	0.0171512215417797	Not feasible
#        20	0.0037759486175574	Not feasible
#         3	0.3512570171756479	Not feasible
#        20	0.1184104255974274	Not feasible
#        10	0.1673959222477697	Optimal
#        17	0.1702473128290906	Optimal
#        21	0.0037746086783745	Not feasible
#        22	0.0037739387087830	Not feasible
#        21	0.1184090856582444	Optimal
# Building (20 threads):   3%|▎         | 14/495 [03:45<2:01:22, 15.14s/it]
#        13	0.0168081971109441	Not feasible
#         1	1.4050280687025918	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpphxvi5ea.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpjpyc1omm.lp
# Reading time = 0.00 seconds
# : 962 rows, 2104 columns, 9128 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        18	0.1702580323425542	Optimal
#        11	0.1687680199711121	Not feasible
# Read LP format model from file /tmp/tmpcyvqe61p.lp
# Reading time = 0.00 seconds
# : 981 rows, 2102 columns, 8958 nonzeros
#        22	0.1184097556278359	Optimal
# Building (20 threads):   3%|▎         | 15/495 [03:47<1:29:50, 11.23s/it]
#        14	0.0166366848955263	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpb_1rke3u.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         8	0.0109767817867390	Optimal
#        12	0.1680819711094409	Not feasible
# Read LP format model from file /tmp/tmpgtdpkga1.lp
# Reading time = 0.00 seconds
# : 950 rows, 2130 columns, 9244 nonzeros
#        15	0.0165509287878174	Optimal
#         9	0.0164651726801085	Not feasible
#        19	0.1702633920992860	Not feasible
# Read LP format model from file /tmp/tmpk2__u3wt.lp
# Reading time = 0.01 seconds
# : 977 rows, 2128 columns, 9124 nonzeros
#        10	0.0137209772334237	Optimal
#        16	0.0165938068416718	Not feasible
#         4	0.1756285085878240	Not feasible
#         1	1.4050280687025918	Not feasible
#        13	0.1677389466786053	Optimal
#        11	0.0150930749567661	Not feasible
#        17	0.0165723678147446	Optimal
#         8	0.0109767817867390	Not feasible
#        12	0.0144070260950949	Not feasible
#        18	0.0165830873282082	Not feasible
#        10	0.0027441954466847	Optimal
#        14	0.1679104588940231	Not feasible
#         4	0.1756285085878240	Not feasible
#        13	0.0140640016642593	Not feasible
#        20	0.1702607122209201	Optimal
#        19	0.0165777275714764	Optimal
#        14	0.0138924894488415	Optimal
#        11	0.0041162931700271	Not feasible
#        20	0.0165804074498423	Optimal
#        15	0.0139782455565504	Optimal
#        15	0.1678247027863142	Not feasible
#        21	0.0165817473890253	Not feasible
#        12	0.0034302443083559	Not feasible
#        16	0.0140211236104049	Optimal
#         4	0.1756285085878240	Not feasible
#        21	0.1702620521601030	Optimal
#        22	0.0165810774194338	Optimal
#        17	0.0140425626373321	Not feasible
# Building (20 threads):   3%|▎         | 16/495 [03:56<1:24:21, 10.57s/it]
#         2	0.7025140343512959	Not feasible
#        13	0.0030872198775203	Not feasible
#        16	0.1677818247324598	Not feasible
#        18	0.0140318431238685	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         5	0.0878142542939120	Optimal
#        19	0.0140264833671367	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp5b90bsv8.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpufsmavzo.lp
# Reading time = 0.01 seconds
# : 1301 rows, 3418 columns, 14612 nonzeros
#        20	0.0140291632455026	Optimal
#        17	0.1677603857055325	Optimal
#        14	0.0029157076621025	Optimal
#        22	0.1702627221296945	Not feasible
# Building (20 threads):   3%|▎         | 17/495 [03:59<1:06:33,  8.35s/it]
#        21	0.0140305031846856	Not feasible
# Read LP format model from file /tmp/tmpsrb15da9.lp
# Reading time = 0.01 seconds
# : 1340 rows, 3416 columns, 14492 nonzeros
#        22	0.0140298332150941	Optimal
# Building (20 threads):   4%|▎         | 18/495 [04:00<49:00,  6.16s/it]
#         3	0.3512570171756479	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpsmwcm3xe.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpwe5bmbqd.lp
# Reading time = 0.01 seconds
# : 1175 rows, 2762 columns, 12098 nonzeros
#        18	0.1677711052189962	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpaur_tjc6.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpbdq5au6v.lp
# Reading time = 0.00 seconds
# : 732 rows, 1608 columns, 6748 nonzeros
#        15	0.0030014637698114	Not feasible
#         5	0.0878142542939120	Not feasible
# Read LP format model from file /tmp/tmpn_9lzsgi.lp
# Reading time = 0.00 seconds
# : 732 rows, 1606 columns, 6628 nonzeros
#         9	0.0054883908933695	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmpirf7nc_j.lp
# Reading time = 0.00 seconds
# : 1189 rows, 2760 columns, 11898 nonzeros
#         2	0.7025140343512959	Not feasible
#        16	0.0029585857159570	Not feasible
#         6	0.1317213814408680	Optimal
#        10	0.0082325863400542	Optimal
#        19	0.1677764649757280	Optimal
#        17	0.0029371466890298	Not feasible
#        11	0.0096046840633966	Optimal
#         1	1.4050280687025918	Not feasible
#        18	0.0029264271755662	Not feasible
#         5	0.0878142542939120	Not feasible
#        19	0.0029210674188344	Not feasible
#        20	0.1677791448540939	Not feasible
#        20	0.0029183875404684	Not feasible
#        12	0.0102907329250678	Not feasible
#         5	0.0878142542939120	Not feasible
#        21	0.0029170476012855	Not feasible
#        21	0.1677778049149109	Optimal
#         2	0.7025140343512959	Not feasible
#        22	0.0029163776316940	Not feasible
# Building (20 threads):   4%|▍         | 19/495 [04:10<57:54,  7.30s/it]
#        13	0.0099477084942322	Optimal
#         3	0.3512570171756479	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp_6xc7hp0.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpltxrnewb.lp
# Reading time = 0.00 seconds
# : 899 rows, 1920 columns, 8238 nonzeros
#         6	0.0439071271469560	Optimal
# Read LP format model from file /tmp/tmp3nckuwqr.lp
# Reading time = 0.00 seconds
# : 924 rows, 1918 columns, 8068 nonzeros
#         4	0.1756285085878240	Not feasible
#        22	0.1677784748845024	Optimal
# Building (20 threads):   4%|▍         | 20/495 [04:13<46:31,  5.88s/it]
#         3	0.3512570171756479	Not feasible
#        14	0.0101192207096500	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpcdy3l2_z.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         4	0.5268855257634719	Not feasible
# Read LP format model from file /tmp/tmpc5d5x9wh.lp
# Reading time = 0.00 seconds
# : 894 rows, 1888 columns, 8124 nonzeros
#         7	0.1536749450143460	Not feasible
# Read LP format model from file /tmp/tmp5ac9j7m1.lp
# Reading time = 0.00 seconds
# : 927 rows, 1886 columns, 7954 nonzeros
#         2	0.7025140343512959	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         7	0.0658606907204340	Not feasible
#         5	0.4390712714695599	Not feasible
#         8	0.0548839089336950	Not feasible
#         1	1.4050280687025918	Not feasible
#         6	0.3951641443226039	Not feasible
#        15	0.0102049768173589	Optimal
#         6	0.0439071271469560	Not feasible
#        16	0.0102478548712134	Not feasible
#         2	0.7025140343512959	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         9	0.0493955180403255	Optimal
#        17	0.0102264158442861	Optimal
#         6	0.0439071271469560	Optimal
#         7	0.3732105807491259	Not feasible
#         3	0.3512570171756479	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         8	0.1426981632276070	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        10	0.0521397134870102	Optimal
#        18	0.0102371353577497	Optimal
#         3	0.3512570171756479	Not feasible
#         7	0.0658606907204340	Optimal
#         8	0.3622337989623869	Not feasible
#        11	0.0535118112103526	Optimal
#         1	1.4050280687025918	Not feasible
#        19	0.0102424951144816	Not feasible
#        12	0.0541978600720238	Optimal
#         8	0.0768374725071730	Optimal
#         9	0.3567454080690174	Not feasible
#        20	0.0102398152361157	Optimal
#         9	0.0823258634005425	Not feasible
#         2	0.7025140343512959	Not feasible
#         3	0.3512570171756479	Not feasible
#         1	1.4050280687025918	Not feasible
#        21	0.0102411551752986	Not feasible
#        10	0.3540012126223327	Not feasible
#        10	0.0795816679538577	Optimal
#         9	0.1372097723342375	Optimal
#        13	0.0545408845028594	Optimal
#         7	0.0219535635734780	Optimal
#         4	0.1756285085878240	Not feasible
#        22	0.0102404852057071	Not feasible
# Building (20 threads):   4%|▍         | 21/495 [04:36<1:26:47, 10.99s/it]
#         2	0.7025140343512959	Not feasible
#        11	0.3526291148989903	Optimal
#        11	0.0809537656772001	Optimal
#         4	0.1756285085878240	Optimal
#        14	0.0547123967182772	Not feasible
#         8	0.0329303453602170	Not feasible
#        12	0.0816398145388713	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp690mmrn9.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp9ueh1_2o.lp
# Reading time = 0.01 seconds
# : 1181 rows, 2776 columns, 12060 nonzeros
#         9	0.0274419544668475	Not feasible
#         5	0.2634427628817360	Not feasible
#        15	0.0546266406105683	Not feasible
# Read LP format model from file /tmp/tmp8i0hluek.lp
# Reading time = 0.00 seconds
# : 1195 rows, 2774 columns, 11860 nonzeros
#        13	0.0812967901080357	Not feasible
#        12	0.3533151637606615	Not feasible
#        10	0.1399539677809222	Optimal
#         6	0.2195356357347800	Not feasible
#        10	0.0246977590201627	Optimal
#        16	0.0545837625567138	Optimal
#        14	0.0811252778926179	Not feasible
#         1	1.4050280687025918	Not feasible
#        15	0.0810395217849090	Not feasible
#         7	0.1975820721613020	Not feasible
#        11	0.0260698567435051	Optimal
#         1	1.4050280687025918	Not feasible
#        17	0.0546052015836411	Optimal
#         4	0.1756285085878240	Not feasible
#        13	0.3529721393298259	Not feasible
#        16	0.0809966437310546	Not feasible
#         5	0.0878142542939120	Not feasible
#        12	0.0267559056051763	Optimal
#        18	0.0546159210971047	Optimal
#        13	0.0270989300360119	Optimal
#         3	0.3512570171756479	Not feasible
#        11	0.1413260655042646	Not feasible
#         8	0.1866052903745630	Optimal
#        17	0.0809752047041273	Optimal
#        19	0.0546212808538365	Not feasible
#         2	0.7025140343512959	Not feasible
#        14	0.0272704422514297	Optimal
#        18	0.0809859242175909	Not feasible
#        14	0.3528006271144081	Optimal
#         9	0.1920936812679325	Not feasible
#        20	0.0546186009754706	Optimal
#         3	0.3512570171756479	Not feasible
#        21	0.0546199409146535	Optimal
#        19	0.0809805644608591	Optimal
#        10	0.1893494858212477	Optimal
#         2	0.7025140343512959	Not feasible
#        20	0.0809832443392250	Not feasible
#        22	0.0546206108842450	Not feasible
#        15	0.0273561983591386	Optimal
# Building (20 threads):   4%|▍         | 22/495 [04:52<1:39:29, 12.62s/it]
#        15	0.3528863832221170	Not feasible
#         4	0.1756285085878240	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp42c9ub0o.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpmr3yry1j.lp
# Reading time = 0.00 seconds
# : 870 rows, 1894 columns, 8234 nonzeros
#        21	0.0809819044000421	Not feasible
#        16	0.0273990764129930	Optimal
#         2	0.7025140343512959	Not feasible
# Read LP format model from file /tmp/tmph7zzg6kt.lp
# Reading time = 0.00 seconds
# : 896 rows, 1892 columns, 8114 nonzeros
#        11	0.1907215835445901	Optimal
#         6	0.0439071271469560	Not feasible
#        17	0.0274205154399203	Optimal
#         5	0.0878142542939120	Not feasible
#        12	0.1914076324062613	Not feasible
#        18	0.0274312349533839	Not feasible
#        16	0.3528435051682625	Optimal
#        22	0.0809812344304506	Optimal
# Building (20 threads):   5%|▍         | 23/495 [04:57<1:20:39, 10.25s/it]
#        19	0.0274258751966521	Optimal
#        12	0.1406400166425934	Optimal
#        13	0.1910646079754257	Optimal
#        20	0.0274285550750180	Not feasible
# Set parameter Username
# ...
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpmtrfiy8h.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp4671roa8.lp
# Reading time = 0.00 seconds
# : 829 rows, 1686 columns, 7170 nonzeros
#         5	0.0878142542939120	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmpvlelpyew.lp
# Reading time = 0.00 seconds
# : 831 rows, 1684 columns, 7050 nonzeros
#         9	0.3347918444955394	Optimal
#         3	0.3512570171756479	Not feasible
#         8	0.0768374725071730	Not feasible
#        21	0.1885361427371962	Not feasible
#        11	0.3142103786454038	Not feasible
#         5	0.0878142542939120	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        10	0.3375360399422242	Not feasible
#         4	0.5268855257634719	Optimal
#        22	0.1885354727676047	Not feasible        9	0.0713490816138035	Not feasible
# Building (20 threads):  96%|█████████▌| 476/495 [1:16:36<02:04,  6.55s/it]
#        10	0.3375360399422242	Optimal
#        11	0.3361639422188818	Optimal
#        10	0.0686048861671187	Not feasible
#         9	0.4884667895098854	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         4	0.1756285085878240	Not feasible
#        11	0.0672327884437764	Not feasible
#        12	0.3135243297837326	Optimal
#        12	0.3368499910805530	Optimal
#        12	0.0583141532420509	Not feasible
#        12	0.0665467395821052	Not feasible
#        11	0.3389081376655666	Not feasible
#         5	0.0878142542939120	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         5	0.6146997800573839	Optimal
#        13	0.3371930155113886	Optimal
#        13	0.0662037151512696	Optimal
#        13	0.0579711288112153	Optimal
#        13	0.3138673542145682	Not feasible
#        12	0.3382220888038954	Optimal
#        10	0.4857225940632007	Optimal
#        14	0.0663752273666874	Not feasible
#         6	0.0439071271469560	Optimal
#        14	0.3373645277268064	Optimal
#        13	0.3385651132347310	Not feasible
#        15	0.0662894712589785	Not feasible
#        14	0.0581426410266331	Not feasible
#         6	0.0439071271469560	Optimal
#        15	0.3374502838345153	Not feasible
#        14	0.3383936010193132	Optimal
#        11	0.4870946917865431	Not feasible
#         7	0.0658606907204340	Not feasible
#         7	0.0658606907204340	Not feasible
#        16	0.0662465932051240	Optimal
#        15	0.0580568849189242	Not feasible
#        16	0.3374074057806608	Optimal
#         6	0.0439071271469560	Not feasible
#        14	0.3136958419991505	Not feasible
#        15	0.3384793571270220	Not feasible
#        17	0.0662680322320512	Not feasible
#        17	0.3374288448075881	Not feasible
#         8	0.0548839089336950	Optimal
#         6	0.6586069072043399	Optimal
#        16	0.0580140068650698	Optimal
#         5	0.0878142542939120	Optimal
#        12	0.4864086429248718	Not feasible
#         8	0.0548839089336950	Optimal
#        18	0.3374181252941244	Not feasible
#         9	0.0603722998270645	Not feasible
#        16	0.3384364790731676	Optimal
#        18	0.0662573127185876	Optimal
#        19	0.3374127655373926	Not feasible
#         1	1.4050280687025918	Not feasible
#        17	0.0580354458919970	Optimal
#        10	0.0576281043803797	Not feasible
#         9	0.0603722998270645	Optimal
#        15	0.3136100858914416	Not feasible
#         6	0.1317213814408680	Optimal
#         1	1.4050280687025918	Not feasible
#        20	0.3374100856590267	Not feasible
#        17	0.3384579181000948	Optimal
#         7	0.6805604707778179	Not feasible
#        13	0.4860656184940363	Optimal
#        10	0.0631164952737492	Optimal
#        21	0.3374087457198438	Not feasible
#        19	0.0662626724753194	Optimal
#         7	0.0219535635734780	Not feasible
#        11	0.0562560066570374	Optimal
#        18	0.0580461654054606	Optimal
#        18	0.3384686376135584	Not feasible
#        22	0.3374080757502523	Not feasible
# Building (20 threads):  96%|█████████▋| 477/495 [1:16:58<03:23, 11.29s/it]
#        11	0.0644885929970916	Not feasible
#        12	0.0569420555187086	Not feasible
#         1	1.4050280687025918	Not feasible
#        19	0.3384632778568266	Not feasible
#        19	0.0580515251621924	Not feasible
#        20	0.0662653523536853	Optimal
#        14	0.4862371307094541	Optimal
#         7	0.0219535635734780	Not feasible
#         7	0.1536749450143460	Not feasible
#        13	0.0565990310878730	Optimal
#        16	0.3135672078375871	Optimal
#        12	0.0638025441354204	Optimal
#        20	0.3384605979784607	Optimal
#         1	1.4050280687025918	Not feasible
#        14	0.0567705433032908	Not feasible
#        20	0.0580488452838265	Optimal
#        21	0.0662666922928683	Optimal
#        21	0.3384619379176437	Not feasible
#        15	0.0566847871955819	Not feasible
#         2	0.7025140343512959	Not feasible
#         8	0.6695836889910789	Not feasible
#         2	0.7025140343512959	Not feasible
#        13	0.0641455685662560	Not feasible
#         8	0.1426981632276070	Optimal
#        16	0.0566419091417274	Not feasible
#        22	0.0662673622624598	Not feasible
#        14	0.0639740563508382	Not feasible
# Building (20 threads):  97%|█████████▋| 478/495 [1:17:05<02:51, 10.07s/it]
#        22	0.3384612679480522	Optimal
# Building (20 threads):  97%|█████████▋| 479/495 [1:17:06<01:54,  7.16s/it]
#        21	0.0580501852230095	Not feasible
#        15	0.4863228868171630	Not feasible
#        15	0.0638883002431293	Not feasible
#        17	0.0566204701148002	Not feasible
#        17	0.3135886468645143	Not feasible
#         9	0.1481865541209765	Not feasible
#         8	0.0109767817867390	Not feasible
#        16	0.0638454221892749	Optimal
#         9	0.6640952980977094	Optimal
#        22	0.0580495152534180	Optimal
# Building (20 threads):  97%|█████████▋| 480/495 [1:17:09<01:30,  6.06s/it]
#        18	0.0566097506013366	Optimal
#         2	0.7025140343512959	Not feasible
#        17	0.0638668612162021	Optimal
#        16	0.4862800087633085	Not feasible
#        18	0.0638775807296657	Optimal
#        19	0.0566151103580684	Optimal
#        10	0.1454423586742917	Optimal
#        19	0.0638829404863975	Optimal
#        20	0.0566177902364343	Not feasible
#        18	0.3135779273510507	Not feasible
#         4	0.1756285085878240	Not feasible
#        21	0.0566164502972513	Not feasible
#        10	0.6668394935443942	Not feasible
#        20	0.0638856203647634	Not feasible
#         3	0.3512570171756479	Not feasible
#        22	0.0566157803276599	Not feasible
# Building (20 threads):  97%|█████████▋| 481/495 [1:17:15<01:22,  5.92s/it]
#         2	0.7025140343512959	Not feasible
#        21	0.0638842804255805	Not feasible
#        11	0.1468144563976341	Optimal
#         3	0.3512570171756479	Not feasible
#        17	0.4862585697363813	Not feasible
#        22	0.0638836104559890	Optimal
# Building (20 threads):  97%|█████████▋| 482/495 [1:17:17<01:01,  4.73s/it]
#        11	0.6654673958210517	Not feasible
#        19	0.3135725675943189	Not feasible
#        12	0.1475005052593053	Not feasible
#         3	0.3512570171756479	Not feasible
#        12	0.6647813469593806	Optimal
#         9	0.0054883908933695	Optimal
#        13	0.1471574808284697	Not feasible
#        18	0.4862478502229177	Not feasible
#        20	0.3135698877159530	Optimal
#        10	0.0082325863400542	Optimal
#         4	0.1756285085878240	Not feasible
#         8	0.0109767817867390	Not feasible
#        14	0.1469859686130519	Optimal
#        11	0.0096046840633966	Not feasible
#        13	0.6651243713902162	Not feasible
#        12	0.0089186352017254	Not feasible
#         3	0.3512570171756479	Not feasible
#         4	0.1756285085878240	Not feasible
#        13	0.0085756107708898	Optimal
#        21	0.3135712276551359	Optimal
#        14	0.0087471229863076	Not feasible
#        15	0.1470717247207608	Not feasible
#        15	0.0086613668785987	Optimal
#        14	0.6649528591747984	Not feasible
#         4	0.1756285085878240	Not feasible
#        16	0.0087042449324532	Optimal
#        19	0.4862424904661858	Not feasible
#        16	0.1470288466669064	Not feasible
#        17	0.0087256839593804	Not feasible
#        22	0.3135718976247274	Not feasible
#        18	0.0087149644459168	Optimal
# Building (20 threads):  98%|█████████▊| 483/495 [1:17:30<01:26,  7.22s/it]
#        19	0.0087203242026486	Not feasible
#        17	0.1470074076399791	Not feasible
#        15	0.6648671030670895	Not feasible
#        20	0.0087176443242827	Not feasible
#        21	0.0087163043850998	Optimal
#        18	0.1469966881265155	Not feasible
#         5	0.0878142542939120	Optimal
#        22	0.0087169743546912	Optimal
#        20	0.4862398105878200	Not feasible
# Building (20 threads):  98%|█████████▊| 484/495 [1:17:33<01:05,  5.95s/it]
#        16	0.6648242250132350	Optimal
#        19	0.1469913283697837	Optimal
#         4	0.1756285085878240	Not feasible
#         6	0.1317213814408680	Not feasible
#        20	0.1469940082481496	Optimal
#        17	0.6648456640401623	Optimal
#         5	0.0878142542939120	Not feasible
#        21	0.4862384706486370	Not feasible
#         5	0.0878142542939120	Not feasible
#         7	0.1097678178673900	Optimal
#        21	0.1469953481873326	Not feasible
#         8	0.1207445996541290	Not feasible
#        22	0.1469946782177411	Not feasible
# Building (20 threads):  98%|█████████▊| 485/495 [1:17:39<01:02,  6.21s/it]
#         9	0.1152562087607595	Optimal
#        18	0.6648563835536259	Not feasible
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         9	0.0054883908933695	Not feasible
#        22	0.4862378006790455	Not feasible
#        10	0.1180004042074442	Not feasible
# Building (20 threads):  98%|█████████▊| 486/495 [1:17:42<00:44,  4.97s/it]
#        19	0.6648510237968941	Not feasible
#         6	0.0439071271469560	Not feasible
#        11	0.1166283064841019	Not feasible
#         5	0.0878142542939120	Not feasible
#        12	0.1159422576224307	Not feasible
#        13	0.1155992331915951	Optimal
#        20	0.6648483439185282	Optimal
#        14	0.1157707454070129	Optimal
#        15	0.1158565015147218	Not feasible
#         6	0.0439071271469560	Not feasible
#        16	0.1158136234608673	Not feasible
#        21	0.6648496838577111	Not feasible
#        17	0.1157921844339401	Not feasible
#        18	0.1157814649204765	Not feasible
#        19	0.1157761051637447	Optimal
#        20	0.1157787850421106	Optimal
#         7	0.0219535635734780	Optimal
#        22	0.6648490138881197	Not feasible
# Building (20 threads):  98%|█████████▊| 487/495 [1:17:53<00:55,  6.90s/it]
#        21	0.1157801249812935	Not feasible
#         8	0.0329303453602170	Optimal
#        22	0.1157794550117021	Not feasible
# Building (20 threads):  99%|█████████▊| 488/495 [1:17:54<00:36,  5.21s/it]
#         9	0.0384187362535865	Not feasible
#         6	0.0439071271469560	Not feasible
#        10	0.0356745408069017	Not feasible
#        11	0.0343024430835594	Not feasible
#         7	0.0219535635734780	Not feasible
#         5	0.0878142542939120	Not feasible
#        12	0.0336163942218882	Optimal
#        13	0.0339594186527238	Optimal
#        14	0.0341309308681416	Not feasible
#        15	0.0340451747604327	Not feasible
#        10	0.0027441954466847	Optimal
#        16	0.0340022967065782	Not feasible
#        11	0.0041162931700271	Optimal
#        17	0.0339808576796510	Not feasible
#        12	0.0048023420316983	Optimal
#         7	0.0219535635734780	Not feasible
#        18	0.0339701381661874	Optimal
#         8	0.0109767817867390	Optimal
#        19	0.0339754979229192	Optimal
#         9	0.0164651726801085	Optimal
#         2	0.7025140343512959	Not feasible
#        13	0.0051453664625339	Optimal
#        20	0.0339781778012851	Optimal
#        10	0.0192093681267932	Optimal
#        21	0.0339795177404681	Not feasible
#        11	0.0205814658501356	Optimal
#        14	0.0053168786779517	Optimal
#        22	0.0339788477708766	Optimal
# Building (20 threads):  99%|█████████▉| 489/495 [1:18:10<00:49,  8.28s/it]
#        12	0.0212675147118068	Optimal
#        13	0.0216105391426424	Not feasible
#        15	0.0054026347856606	Optimal
#        14	0.0214390269272246	Optimal
#        16	0.0054455128395150	Optimal
#        15	0.0215247830349335	Not feasible
#        17	0.0054669518664423	Optimal
#        16	0.0214819049810791	Not feasible
#         8	0.0109767817867390	Not feasible
#         2	0.7025140343512959	Not feasible
#        17	0.0214604659541518	Optimal
#        18	0.0054776713799059	Optimal
#        18	0.0214711854676154	Not feasible
#        19	0.0054830311366377	Optimal
#        19	0.0214658257108836	Not feasible
#        20	0.0054857110150036	Optimal
#        20	0.0214631458325177	Optimal
#        21	0.0054870509541865	Optimal
#        21	0.0214644857717007	Optimal
#        22	0.0214651557412922	Optimal
# Building (20 threads):  99%|█████████▉| 490/495 [1:18:22<00:47,  9.50s/it]
#        22	0.0054877209237780	Optimal
# Building (20 threads):  99%|█████████▉| 491/495 [1:18:22<00:26,  6.70s/it]
#         9	0.0054883908933695	Optimal
#        10	0.0082325863400542	Optimal
#        11	0.0096046840633966	Not feasible
#         6	0.0439071271469560	Not feasible
#         3	0.3512570171756479	Not feasible
#        12	0.0089186352017254	Not feasible
#        13	0.0085756107708898	Not feasible
#         3	0.3512570171756479	Not feasible
#        14	0.0084040985554720	Not feasible
#        15	0.0083183424477631	Not feasible
#        16	0.0082754643939087	Optimal
#        17	0.0082969034208359	Optimal
#        18	0.0083076229342995	Optimal
#        19	0.0083129826910313	Not feasible
#        20	0.0083103028126654	Optimal
#        21	0.0083116427518484	Not feasible
#        22	0.0083109727822569	Optimal
# Building (20 threads):  99%|█████████▉| 492/495 [1:18:47<00:36, 12.23s/it]
#         7	0.0219535635734780	Not feasible
#         4	0.1756285085878240	Optimal
#         4	0.1756285085878240	Optimal
#         5	0.2634427628817360	Not feasible
#         5	0.2634427628817360	Not feasible
#         6	0.2195356357347800	Not feasible
#         6	0.2195356357347800	Optimal
#         8	0.0109767817867390	Not feasible
#         7	0.2414891993082580	Not feasible
#         7	0.1975820721613020	Not feasible
#         8	0.2305124175215190	Optimal
#         9	0.2360008084148885	Not feasible
#         8	0.1866052903745630	Not feasible
#        10	0.2332566129682037	Optimal
#         9	0.0054883908933695	Not feasible
#        11	0.2346287106915461	Not feasible
#        12	0.2339426618298749	Not feasible
#         9	0.1811168994811935	Not feasible
#        13	0.2335996373990393	Not feasible
#        14	0.2334281251836215	Optimal
#        10	0.1783727040345087	Optimal
#        15	0.2335138812913304	Not feasible
#        16	0.2334710032374759	Not feasible
#        17	0.2334495642105487	Optimal
#        10	0.0027441954466847	Optimal
#        11	0.0041162931700271	Optimal
#        12	0.0048023420316983	Optimal
#        13	0.0051453664625339	Optimal
#        11	0.1797448017578511	Optimal
#        18	0.2334602837240123	Optimal
#        14	0.0053168786779517	Not feasible
#        15	0.0052311225702428	Not feasible
#        19	0.2334656434807441	Not feasible
#        16	0.0051882445163884	Not feasible
#        17	0.0051668054894611	Not feasible
#        12	0.1804308506195223	Optimal
#        18	0.0051560859759975	Not feasible
#        19	0.0051507262192657	Not feasible
#        20	0.2334629636023782	Optimal
#        20	0.0051480463408998	Not feasible
#        21	0.0051467064017169	Not feasible
#        13	0.1807738750503579	Optimal
#        22	0.0051460364321254	Not feasible
#        21	0.2334643035415612	Not feasible
# Building (20 threads): 100%|█████████▉| 493/495 [1:20:17<01:11, 35.54s/it]
#        14	0.1809453872657757	Not feasible
#        22	0.2334636335719697	Optimal
# Building (20 threads): 100%|█████████▉| 494/495 [1:20:22<00:26, 26.45s/it]
#        15	0.1808596311580668	Not feasible
#        16	0.1808167531042124	Optimal
#        17	0.1808381921311396	Not feasible
#        18	0.1808274726176760	Optimal
#        19	0.1808328323744078	Not feasible
#        20	0.1808301524960419	Not feasible
#        21	0.1808288125568589	Not feasible
#        22	0.1808281425872674	Not feasible
# Building (20 threads): 100%|██████████| 495/495 [1:20:59<00:00, 29.54s/it]
