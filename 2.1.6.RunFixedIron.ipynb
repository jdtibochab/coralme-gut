# %%
import glob
import numpy
import pandas
import seaborn
import matplotlib.pyplot as plt
from tqdm import tqdm
import multiprocessing as mp
import os
from build import build_model

# %%
from IPython.display import display, HTML, Math, Markdown
display(HTML("<style>.container { width:95% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# !bash report.sh
organisms = set(pandas.read_csv("biomass_constrained.txt",index_col=0,header=None).index.to_list())

# %%
run_for = organisms
len(run_for)
# Out:
# 495

# %%
# protein
exchanges = ["EX_fe2(e)","EX_fe3(e)","TS_2fe2s_c","TS_4fe4s_c","TS_fe3_c"]

# %%
from diets import load_model,constrain_exchanges,get_bounds
from overflow import get_overflow
import coralme

conditions = ["fixed"]
metabolite = "iron"

for c in conditions:
    name = "{}_{}".format(c,metabolite)
    fluxdir = "./cases/fluxes/{}".format(name)
    overflowdir = "./cases/overflow/{}".format(name)
    if not os.path.isdir(fluxdir):
        os.makedirs(fluxdir)
        os.makedirs(overflowdir)

def run(org):
    model = coralme.io.pickle.load_pickle_me_model("./me-models/{}/MEModel-BIO-{}-ME-TS.pkl".format(org,org))
    sol0 = model.solution
    df0 = sol0.to_frame()
    # Exchanges
    rlist = exchanges
    # Run for all conditions
    for condition in conditions:
        name = "{}_{}".format(condition,metabolite)
        dct = {k:-1e-8 for k in rlist if k in model.reactions}
        constrain_exchanges(model,dct)
        model.optimize()
        model.solution.to_frame().to_csv("cases/fluxes/{}/{}.csv".format(name,org))
        get_overflow(model).to_csv("./cases/overflow/{}/{}.csv".format(name,org))

# %%
NP = min([10,len(run_for)])
pool = mp.Pool(NP,maxtasksperchild=1)
pbar = tqdm(total=len(run_for),position=0,leave=True)
pbar.set_description('Building ({} threads)'.format(NP))
def collect_result(result):
    pbar.update(1)

for org in run_for:
    args = ([org])
    pool.apply_async(run,args, callback=collect_result)
pool.close()
pool.join()
# Out:
# Building (10 threads):   0%|                                                          | 0/497 [00:00<?, ?it/s]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpehv3cy9v.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpqjhjloh3.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpcyd93ux6.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpqxlco_bs.lp
# Reading time = 0.00 seconds
# : 1122 rows, 2626 columns, 11096 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp6zgl2w56.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp0f8cez7_.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp4w5_tp4n.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpr9obhxlo.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp60rm_9v1.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpa7lqf8l1.lp
# Reading time = 0.00 seconds
# : 982 rows, 2176 columns, 9416 nonzeros
# Read LP format model from file /tmp/tmp60x21s0g.lp
# Reading time = 0.00 seconds
# : 1147 rows, 2624 columns, 10926 nonzeros
# Read LP format model from file /tmp/tmpev4nhbjj.lp
# Reading time = 0.00 seconds
# : 982 rows, 2174 columns, 9246 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpr6m7rsvl.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpqh87su0_.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmp1p4uemsc.lp
# Reading time = 0.00 seconds
# : 1051 rows, 2470 columns, 10490 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmpew096rup.lp
# Reading time = 0.01 seconds
# : 913 rows, 1928 columns, 8298 nonzeros
#         1	1.4050280687025918	Not feasible
# Read LP format model from file /tmp/tmpf1og6nqu.lp
# Reading time = 0.00 seconds
# : 851 rows, 1830 columns, 7776 nonzeros
# Read LP format model from file /tmp/tmp9op5f_sg.lp
# Reading time = 0.01 seconds
# : 1012 rows, 2232 columns, 9656 nonzeros
# Read LP format model from file /tmp/tmpm9o7x17a.lp
# Reading time = 0.00 seconds
# : 909 rows, 1886 columns, 8182 nonzeros
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
# Read LP format model from file /tmp/tmpk3hjsqzu.lp
# Reading time = 0.01 seconds
# : 946 rows, 1926 columns, 8128 nonzeros
#         3	0.3512570171756479	Not feasible
# Read LP format model from file /tmp/tmp0u1z2d0f.lp
# Reading time = 0.01 seconds
# : 1155 rows, 2638 columns, 11326 nonzeros
# Read LP format model from file /tmp/tmppnenwxy2.lp
# Reading time = 0.00 seconds
# : 1074 rows, 2468 columns, 10290 nonzeros
# Read LP format model from file /tmp/tmphkl33ip6.lp
# Reading time = 0.00 seconds
# : 852 rows, 1828 columns, 7656 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         2	0.7025140343512959	Not feasible
#         4	0.1756285085878240	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmptomnbheq.lp
# Reading time = 0.00 seconds
# : 1037 rows, 2230 columns, 9486 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	1.4050280687025918	Not feasible
# Read LP format model from file /tmp/tmp6coi2nq7.lp
# Reading time = 0.01 seconds
# : 932 rows, 1884 columns, 8062 nonzeros
#         5	0.0878142542939120	Optimal
#         6	0.1317213814408680	Optimal
#         2	0.7025140343512959	Not feasible
#         7	0.1536749450143460	Not feasible
#         3	0.3512570171756479	Not feasible
#         8	0.1426981632276070	Optimal
# Read LP format model from file /tmp/tmp4a5pqi3z.lp
# Reading time = 0.01 seconds
# : 1291 rows, 3042 columns, 13452 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         9	0.1481865541209765	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        10	0.1454423586742917	Not feasible
# Read LP format model from file /tmp/tmpdzvblxx4.lp
# Reading time = 0.00 seconds
# : 829 rows, 1686 columns, 7170 nonzeros
#         1	1.4050280687025918	Not feasible
# Read LP format model from file /tmp/tmpw1crj5z3.lp
# Reading time = 0.01 seconds
# : 1172 rows, 2636 columns, 11156 nonzeros
#        11	0.1440702609509494	Not feasible
#         3	0.3512570171756479	Not feasible
#        12	0.1433842120892782	Optimal
#        13	0.1437272365201138	Optimal
#        14	0.1438987487355315	Optimal
#        15	0.1439845048432404	Optimal
# Read LP format model from file /tmp/tmpt3vhs6es.lp
# Reading time = 0.01 seconds
# : 831 rows, 1684 columns, 7050 nonzeros
#        16	0.1440273828970949	Not feasible
#        17	0.1440059438701677	Optimal
#         4	0.1756285085878240	Not feasible
#        18	0.1440166633836313	Optimal
#         1	1.4050280687025918	Not feasible        4	0.1756285085878240	Not feasible
#
#         2	0.7025140343512959	Not feasible
#        19	0.1440220231403631	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        20	0.1440193432619972	Not feasible
# Read LP format model from file /tmp/tmpfjgfr0ba.lp
# Reading time = 0.01 seconds
# : 1292 rows, 3040 columns, 13282 nonzeros
#        21	0.1440180033228142	Optimal
#        22	0.1440186732924057	Not feasible
# Building (10 threads):   0%|                                              | 1/497 [01:51<15:23:27, 111.71s/it]
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp0zhynoki.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         5	0.0878142542939120	Optimal
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         6	0.1317213814408680	Not feasible
#         7	0.1097678178673900	Not feasible
#         3	0.3512570171756479	Not feasible
#         8	0.0987910360806510	Optimal
#         9	0.1042794269740205	Optimal
#        10	0.1070236224207052	Optimal
# Read LP format model from file /tmp/tmpckmnolv7.lp
# Reading time = 0.00 seconds
# : 1053 rows, 2310 columns, 10004 nonzeros
#        11	0.1083957201440476	Not feasible
#         5	0.0878142542939120	Optimal
#        12	0.1077096712823764	Optimal
#        13	0.1080526957132120	Optimal
#        14	0.1082242079286298	Optimal
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
#        15	0.1083099640363387	Optimal
#         2	0.7025140343512959	Not feasible
#         2	0.7025140343512959	Not feasible
#        16	0.1083528420901932	Not feasible
# Read LP format model from file /tmp/tmpmujph2_a.lp
# Reading time = 0.01 seconds
# : 1081 rows, 2308 columns, 9834 nonzeros
#         6	0.1317213814408680	Not feasible
#        17	0.1083314030632659	Not feasible
#         4	0.1756285085878240	Not feasible
#        18	0.1083206835498023	Not feasible
#        19	0.1083153237930705	Not feasible
#        20	0.1083126439147046	Optimal
#        21	0.1083139838538876	Not feasible
#         7	0.1097678178673900	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        22	0.1083133138842961	Optimal
# Building (10 threads):   0%|▏                                               | 2/497 [02:18<8:28:09, 61.59s/it]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpf_jedhgf.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         2	0.7025140343512959	Not feasible
#         8	0.1207445996541290	Optimal
#         1	1.4050280687025918	Not feasible
#         3	0.3512570171756479	Not feasible
#         9	0.1262329905474985	Optimal
#        10	0.1289771859941832	Optimal
# Read LP format model from file /tmp/tmpn4_lc39_.lp
# Reading time = 0.00 seconds
# : 889 rows, 2010 columns, 8336 nonzeros
#        11	0.1303492837175256	Not feasible
#         5	0.0878142542939120	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        12	0.1296632348558544	Optimal
#         3	0.3512570171756479	Not feasible
#        13	0.1300062592866900	Not feasible
# Read LP format model from file /tmp/tmpto2veye7.lp
# Reading time = 0.00 seconds
# : 890 rows, 2008 columns, 8216 nonzeros
#        14	0.1298347470712722	Not feasible
#         4	0.1756285085878240	Not feasible
#        15	0.1297489909635633	Optimal
#         3	0.3512570171756479	Not feasible
#        16	0.1297918690174177	Optimal
#        17	0.1298133080443450	Optimal
#         6	0.0439071271469560	Optimal
#        18	0.1298240275578086	Not feasible
#         3	0.3512570171756479	Not feasible
#         7	0.0658606907204340	Not feasible
#        19	0.1298186678010768	Optimal
#        20	0.1298213476794427	Optimal
#         8	0.0548839089336950	Optimal
#         4	0.1756285085878240	Not feasible
#         4	0.1756285085878240	Not feasible
#        21	0.1298226876186256	Optimal
#         9	0.0603722998270645	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         2	0.7025140343512959	Not feasible
#         5	0.0878142542939120	Not feasible
#        10	0.0576281043803797	Not feasible
#        22	0.1298233575882171	Optimal
# Building (10 threads):   1%|▎                                               | 3/497 [02:49<6:34:50, 47.96s/it]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpq71beqqe.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        11	0.0562560066570374	Optimal
#        12	0.0569420555187086	Optimal
#        13	0.0572850799495441	Not feasible
#        14	0.0571135677341263	Optimal
#        15	0.0571993238418353	Optimal
#         5	0.0878142542939120	Optimal
#        16	0.0572422018956897	Optimal
#        17	0.0572636409226169	Not feasible
#         1	1.4050280687025918	Not feasible
#        18	0.0572529214091533	Optimal
#        19	0.0572582811658851	Not feasible
#         6	0.1317213814408680	Not feasible
#        20	0.0572556012875192	Not feasible
#         6	0.0439071271469560	Optimal
# Read LP format model from file /tmp/tmpc06qxlp7.lp
# Reading time = 0.01 seconds
# : 1043 rows, 2398 columns, 10058 nonzeros
#        21	0.0572542613483363	Not feasible
#         7	0.0658606907204340	Optimal
#        22	0.0572535913787448	Optimal
# Building (10 threads):   1%|▍                                               | 4/497 [03:04<4:46:09, 34.83s/it]
#         5	0.0878142542939120	Optimal
#         7	0.1097678178673900	Optimal
#         8	0.0768374725071730	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpu_3i6ff4.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         8	0.1207445996541290	Optimal
#         4	0.1756285085878240	Not feasible
#         6	0.1317213814408680	Optimal
#         9	0.1262329905474985	Not feasible        9	0.0823258634005425	Optimal
#
#         1	1.4050280687025918	Not feasible
#        10	0.1234887951008137	Not feasible
#         7	0.1536749450143460	Not feasible
#         3	0.3512570171756479	Not feasible
#        11	0.1221166973774714	Optimal
#        10	0.0850700588472272	Not feasible
#         8	0.1426981632276070	Not feasible
# Read LP format model from file /tmp/tmp1hmi21_k.lp
# Reading time = 0.00 seconds
# : 1068 rows, 2396 columns, 9938 nonzeros
#        12	0.1228027462391425	Optimal
#        13	0.1231457706699781	Optimal
#        11	0.0836979611238849	Optimal
#         9	0.1372097723342375	Optimal
#        14	0.1233172828853959	Optimal
# Read LP format model from file /tmp/tmp6_52lsgj.lp
# Reading time = 0.00 seconds
# : 945 rows, 2030 columns, 8674 nonzeros
#        12	0.0843840099855560	Not feasible
#        15	0.1234030389931048	Optimal
#        10	0.1399539677809222	Not feasible
#        13	0.0840409855547204	Not feasible
#        16	0.1234459170469593	Not feasible
#         2	0.7025140343512959	Not feasible
#         2	0.7025140343512959	Not feasible
#        17	0.1234244780200321	Optimal
#        14	0.0838694733393027	Not feasible
#        11	0.1385818700575799	Not feasible
#        18	0.1234351975334957	Not feasible
#        15	0.0837837172315938	Optimal
#        19	0.1234298377767639	Optimal
#        12	0.1378958211959087	Optimal
#        20	0.1234325176551298	Not feasible
#        16	0.0838265952854482	Not feasible
#        21	0.1234311777159468	Optimal
#        17	0.0838051562585210	Not feasible
#        13	0.1382388456267443	Not feasible
#        22	0.1234318476855383	Optimal
# Building (10 threads):   1%|▍                                               | 5/497 [03:25<4:04:05, 29.77s/it]
#        18	0.0837944367450574	Not feasible
#        14	0.1380673334113265	Not feasible
#        19	0.0837890769883256	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpv5t13si3.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        20	0.0837917568666915	Optimal
#        15	0.1379815773036175	Not feasible
# Read LP format model from file /tmp/tmp24857peu.lp
# Reading time = 0.00 seconds
# : 968 rows, 2028 columns, 8554 nonzeros
#        21	0.0837930968058744	Not feasible
#        16	0.1379386992497631	Not feasible
#        22	0.0837924268362829	Optimal
# Building (10 threads):   1%|▌                                               | 6/497 [03:30<2:54:51, 21.37s/it]
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        17	0.1379172602228359	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp5azs8rdw.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         5	0.0878142542939120	Not feasible
#        18	0.1379065407093722	Not feasible
#         1	1.4050280687025918	Not feasible
#         3	0.3512570171756479	Not feasible
#        19	0.1379011809526405	Not feasible
#        20	0.1378985010742745	Optimal
#         4	0.1756285085878240	Not feasible
# Read LP format model from file /tmp/tmpxl74tvmi.lp
# Reading time = 0.01 seconds
# : 1042 rows, 2384 columns, 10034 nonzeros
#        21	0.1378998410134575	Not feasible
#        22	0.1378991710438660	Optimal
# Building (10 threads):   1%|▋                                               | 7/497 [03:40<2:24:56, 17.75s/it]
#         3	0.3512570171756479	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpwx7gb05z.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmppa3i0xh9.lp
# Reading time = 0.00 seconds
# : 946 rows, 2022 columns, 8716 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         4	0.1756285085878240	Not feasible
# Read LP format model from file /tmp/tmpjl04qin3.lp
# Reading time = 0.01 seconds
# : 1067 rows, 2382 columns, 9912 nonzeros
# Read LP format model from file /tmp/tmpekxuf8w2.lp
# Reading time = 0.00 seconds
# : 927 rows, 1990 columns, 8496 nonzeros
#         6	0.0439071271469560	Not feasible
# Read LP format model from file /tmp/tmp3z2_alvl.lp
# Reading time = 0.00 seconds
# : 947 rows, 2020 columns, 8596 nonzeros
#         4	0.1756285085878240	Optimal
# Read LP format model from file /tmp/tmpcyahluh8.lp
# Reading time = 0.01 seconds
# : 949 rows, 1988 columns, 8376 nonzeros
#         5	0.2634427628817360	Not feasible
#         5	0.0878142542939120	Not feasible
#         6	0.2195356357347800	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         5	0.0878142542939120	Optimal
#         7	0.2414891993082580	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         8	0.2524659810949970	Optimal
#         1	1.4050280687025918	Not feasible
#         6	0.1317213814408680	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	1.4050280687025918	Not feasible
#         9	0.2579543719883665	Not feasible
#         7	0.1097678178673900	Optimal
#         7	0.0219535635734780	Not feasible
#        10	0.2552101765416817	Optimal
#         8	0.1207445996541290	Not feasible
#        11	0.2565822742650241	Not feasible
#         9	0.1152562087607595	Not feasible
#        12	0.2558962254033529	Optimal
#        10	0.1125120133140747	Not feasible
#         6	0.0439071271469560	Not feasible
#        13	0.2562392498341885	Not feasible
#        11	0.1111399155907324	Optimal
#         2	0.7025140343512959	Not feasible
#        14	0.2560677376187707	Not feasible
#         2	0.7025140343512959	Not feasible
#        15	0.2559819815110618	Optimal
#        12	0.1118259644524035	Optimal
#        16	0.2560248595649162	Not feasible
#        13	0.1121689888832391	Optimal
#        17	0.2560034205379890	Optimal
#        18	0.2560141400514526	Not feasible
#         1	1.4050280687025918	Not feasible
#        14	0.1123405010986569	Not feasible
#        19	0.2560087802947208	Not feasible
#         2	0.7025140343512959	Not feasible
#        15	0.1122547449909480	Optimal
#        20	0.2560061004163549	Not feasible
#        21	0.2560047604771719	Optimal
#        16	0.1122976230448025	Not feasible
#         1	1.4050280687025918	Not feasible
#        22	0.2560054304467634	Not feasible
# Building (10 threads):   2%|▊                                               | 8/497 [04:36<4:01:57, 29.69s/it]
#        17	0.1122761840178753	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp8eslu3fh.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         8	0.0109767817867390	Not feasible
#        18	0.1122869035313389	Not feasible
#         3	0.3512570171756479	Not feasible
#        19	0.1122815437746071	Optimal
#        20	0.1122842236529730	Not feasible
#         2	0.7025140343512959	Not feasible
#        21	0.1122828837137900	Not feasible
#         1	1.4050280687025918	Not feasible
#        22	0.1122822137441985	Optimal
# Building (10 threads):   2%|▊                                               | 9/497 [04:45<3:09:04, 23.25s/it]
#         7	0.0219535635734780	Not feasible
# Read LP format model from file /tmp/tmp5dpm1ch6.lp
# Reading time = 0.00 seconds
# : 855 rows, 1772 columns, 7780 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp65zi97y8.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         2	0.7025140343512959	Not feasible
#         3	0.3512570171756479	Not feasible
# Read LP format model from file /tmp/tmp3oq1w6bo.lp
# Reading time = 0.00 seconds
# : 886 rows, 1770 columns, 7660 nonzeros
#         3	0.3512570171756479	Not feasible
#         2	0.7025140343512959	Not feasible
# Read LP format model from file /tmp/tmp8zdrpqjc.lp
# Reading time = 0.00 seconds
# : 965 rows, 2096 columns, 9118 nonzeros
#         4	0.1756285085878240	Not feasible
#         3	0.3512570171756479	Not feasible
# Read LP format model from file /tmp/tmp5xbpw10k.lp
# Reading time = 0.00 seconds
# : 995 rows, 2094 columns, 8918 nonzeros
#         9	0.0054883908933695	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         8	0.0109767817867390	Not feasible
#         3	0.3512570171756479	Not feasible
#         4	0.1756285085878240	Not feasible
#         5	0.0878142542939120	Not feasible
#         4	0.1756285085878240	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         3	0.3512570171756479	Not feasible
#         4	0.1756285085878240	Not feasible
#         5	0.0878142542939120	Not feasible
#         6	0.0439071271469560	Optimal
#         1	1.4050280687025918	Not feasible
#         9	0.0054883908933695	Not feasible
#         7	0.0658606907204340	Optimal
#        10	0.0027441954466847	Not feasible
#         8	0.0768374725071730	Not feasible
#         5	0.0878142542939120	Optimal
#         9	0.0713490816138035	Not feasible
#         5	0.0878142542939120	Optimal
#         1	1.4050280687025918	Not feasible
#         6	0.0439071271469560	Optimal
#         6	0.1317213814408680	Optimal
#         2	0.7025140343512959	Not feasible
#         4	0.1756285085878240	Not feasible
#        10	0.0686048861671187	Optimal
#         6	0.1317213814408680	Not feasible
#         7	0.1536749450143460	Optimal
#         7	0.0658606907204340	Not feasible
#         7	0.1097678178673900	Optimal
#        11	0.0699769838904611	Optimal
#         8	0.1646517268010850	Not feasible
#         8	0.0548839089336950	Not feasible
#         4	0.1756285085878240	Not feasible
#        12	0.0706630327521323	Not feasible
#         9	0.0493955180403255	Optimal
#         8	0.1207445996541290	Optimal
#         3	0.3512570171756479	Not feasible
#         2	0.7025140343512959	Not feasible
#         9	0.1591633359077155	Not feasible
#        13	0.0703200083212967	Optimal
#        14	0.0704915205367145	Not feasible
#         9	0.1262329905474985	Not feasible
#        15	0.0704057644290056	Optimal
#        10	0.1564191404610307	Optimal
#        16	0.0704486424828601	Optimal
#        10	0.1234887951008137	Optimal
#        10	0.0521397134870102	Not feasible
#        17	0.0704700815097873	Not feasible
#        11	0.1577912381843731	Not feasible
#        18	0.0704593619963237	Optimal
#        11	0.1248608928241561	Optimal
#        11	0.0013720977233424	Not feasible
#        19	0.0704647217530555	Not feasible
#        11	0.0507676157636679	Not feasible
#        12	0.1255469416858273	Optimal
#        12	0.1571051893227019	Optimal
#        20	0.0704620418746896	Optimal
#        10	0.0027441954466847	Not feasible
#        12	0.0500815669019967	Not feasible
#         5	0.0878142542939120	Optimal
#        21	0.0704633818138725	Not feasible
#        13	0.1574482137535375	Not feasible
#        13	0.1258899661166629	Not feasible
#         4	0.1756285085878240	Not feasible
#        13	0.0497385424711611	Optimal
#         3	0.3512570171756479	Not feasible
#        14	0.1572767015381197	Optimal
#        22	0.0704627118442810	Optimal
# Building (10 threads):   2%|▉                                              | 10/497 [06:01<5:21:27, 39.60s/it]
#        14	0.0499100546865789	Not feasible
#        14	0.1257184539012451	Optimal
#        15	0.1573624576458286	Not feasible
#        15	0.0498242985788700	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp3h081hk7.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         6	0.1317213814408680	Optimal
#        16	0.1573195795919742	Not feasible
#        16	0.0497814205250155	Optimal
#        15	0.1258042100089540	Not feasible
#        17	0.1572981405650469	Not feasible
#         7	0.1536749450143460	Not feasible
#        17	0.0498028595519428	Optimal
#        18	0.1572874210515833	Optimal
#        16	0.1257613319550995	Not feasible
#         8	0.1426981632276070	Not feasible
#        18	0.0498135790654064	Optimal
#        19	0.1572927808083151	Optimal
#        20	0.1572954606866810	Not feasible
#        19	0.0498189388221382	Not feasible
#        17	0.1257398929281723	Not feasible
#        21	0.1572941207474981	Not feasible
#        20	0.0498162589437723	Not feasible
# Read LP format model from file /tmp/tmpfspewyhb.lp
# Reading time = 0.00 seconds
# : 851 rows, 1908 columns, 8054 nonzeros
#         5	0.0878142542939120	Not feasible
#         9	0.1372097723342375	Optimal
#        18	0.1257291734147087	Not feasible
#        22	0.1572934507779066	Not feasible
# Building (10 threads):   2%|█                                              | 11/497 [06:12<4:09:05, 30.75s/it]
#        21	0.0498149190045893	Not feasible
#        10	0.1399539677809222	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmppbal3_cc.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp8vfuom4a.lp
# Reading time = 0.00 seconds
# : 868 rows, 1912 columns, 8180 nonzeros
#        19	0.1257238136579769	Not feasible
#        22	0.0498142490349978	Not feasible
# Building (10 threads):   2%|█▏                                             | 12/497 [06:14<2:57:47, 22.00s/it]
#         4	0.1756285085878240	Not feasible
# Read LP format model from file /tmp/tmplf699x63.lp
# Reading time = 0.00 seconds
# : 868 rows, 1910 columns, 8010 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp3fuh_nc4.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        20	0.1257211337796110	Not feasible
#        11	0.1385818700575799	Optimal
#        21	0.1257197938404280	Optimal
#        12	0.1392679189192511	Optimal
# Read LP format model from file /tmp/tmpebydipe0.lp
# Reading time = 0.01 seconds
# : 852 rows, 1906 columns, 7934 nonzeros
#        12	0.0006860488616712	Not feasible
#        22	0.1257204638100195	Optimal
# Building (10 threads):   3%|█▏                                             | 13/497 [06:19<2:18:13, 17.14s/it]
#        13	0.1396109433500866	Optimal
#        11	0.0013720977233424	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpja3ualp5.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpgg_swjyy.lp
# Reading time = 0.00 seconds
# : 1081 rows, 2506 columns, 10714 nonzeros
#        14	0.1397824555655044	Optimal
# Read LP format model from file /tmp/tmp4rihy77h.lp
# Reading time = 0.00 seconds
# : 1096 rows, 2504 columns, 10514 nonzeros
#         6	0.0439071271469560	Not feasible
# Read LP format model from file /tmp/tmp98by3jkt.lp
# Reading time = 0.01 seconds
# : 1005 rows, 2380 columns, 10216 nonzeros
#        15	0.1398682116732133	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         5	0.0878142542939120	Not feasible
#        16	0.1398253336193589	Not feasible
#        17	0.1398038945924317	Optimal
#        18	0.1398146141058953	Optimal
#         5	0.0878142542939120	Not feasible
#        19	0.1398199738626271	Optimal
# Read LP format model from file /tmp/tmpfyq5o53w.lp
# Reading time = 0.00 seconds
# : 1006 rows, 2378 columns, 10016 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        20	0.1398226537409930	Optimal
#        21	0.1398239936801760	Optimal
#         7	0.0219535635734780	Optimal
#        22	0.1398246636497674	Optimal
# Building (10 threads):   3%|█▎                                             | 14/497 [06:35<2:14:02, 16.65s/it]
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpwr9x99q9.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         8	0.0329303453602170	Not feasible
#         6	0.0439071271469560	Not feasible
#         9	0.0274419544668475	Optimal
#        10	0.0301861499135322	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        11	0.0315582476368746	Optimal
# Read LP format model from file /tmp/tmpq0i97w6j.lp
# Reading time = 0.00 seconds
# : 907 rows, 2006 columns, 8512 nonzeros
#        13	0.0003430244308356	Not feasible
#        12	0.0006860488616712	Not feasible
#        12	0.0322442964985458	Optimal
#         1	1.4050280687025918	Not feasible
# Read LP format model from file /tmp/tmpam26ggii.lp
# Reading time = 0.00 seconds
# : 907 rows, 2004 columns, 8342 nonzeros
#        13	0.0325873209293814	Not feasible
#        14	0.0324158087139636	Optimal
#        15	0.0325015648216725	Optimal
#         7	0.0219535635734780	Optimal
#        16	0.0325444428755269	Not feasible
#        17	0.0325230038485997	Not feasible
#         1	1.4050280687025918	Not feasible
#         8	0.0329303453602170	Optimal
#        18	0.0325122843351361	Not feasible
#        19	0.0325069245784043	Optimal
#        20	0.0325096044567702	Not feasible
#        21	0.0325082645175873	Not feasible
#         9	0.0384187362535865	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        22	0.0325075945479958	Not feasible
#         2	0.7025140343512959	Not feasible
# Building (10 threads):   3%|█▍                                             | 15/497 [06:58<2:30:05, 18.68s/it]
#        10	0.0356745408069017	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpu4bjvimq.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpnd9fcrfr.lp
# Reading time = 0.01 seconds
# : 1027 rows, 2408 columns, 10182 nonzeros
#         2	0.7025140343512959	Not feasible
# Read LP format model from file /tmp/tmpriz4p_6b.lp
# Reading time = 0.01 seconds
# : 1050 rows, 2406 columns, 9982 nonzeros
#        11	0.0343024430835594	Optimal
#        12	0.0349884919452306	Optimal
#        13	0.0353315163760662	Not feasible
#        13	0.0003430244308356	Not feasible
#        14	0.0351600041606484	Optimal
#        15	0.0352457602683573	Optimal
#         6	0.0439071271469560	Not feasible
#        16	0.0352886383222117	Optimal
#        17	0.0353100773491389	Not feasible
#         1	1.4050280687025918	Not feasible
#        18	0.0352993578356753	Not feasible
#         3	0.3512570171756479	Not feasible
#        19	0.0352939980789435	Not feasible
#        14	0.0001715122154178	Not feasible
#        20	0.0352913182005776	Optimal
#         1	1.4050280687025918	Not feasible
#        21	0.0352926581397606	Optimal
#        22	0.0352933281093520	Not feasible
# Building (10 threads):   3%|█▌                                             | 16/497 [07:16<2:26:24, 18.26s/it]
#         3	0.3512570171756479	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp3amsujzb.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         1	1.4050280687025918	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmpkkhx0c16.lp
# Reading time = 0.01 seconds
# : 1065 rows, 2476 columns, 10534 nonzeros
#         2	0.7025140343512959	Not feasible
#         2	0.7025140343512959	Not feasible
#         4	0.1756285085878240	Not feasible
#         4	0.1756285085878240	Not feasible
#         2	0.7025140343512959	Not feasible
#        14	0.0001715122154178	Not feasible
# Read LP format model from file /tmp/tmp8pqej1a7.lp
# Reading time = 0.01 seconds
# : 1088 rows, 2474 columns, 10334 nonzeros
#         3	0.3512570171756479	Not feasible
#        15	0.0000857561077089	Not feasible
#         5	0.0878142542939120	Not feasible
#         5	0.0878142542939120	Not feasible
#         3	0.3512570171756479	Not feasible
#         7	0.0219535635734780	Not feasible
#         3	0.3512570171756479	Not feasible
#         4	0.1756285085878240	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         6	0.0439071271469560	Not feasible
#         1	1.4050280687025918	Not feasible
#        15	0.0000857561077089	Not feasible
#         6	0.0439071271469560	Optimal
#         7	0.0658606907204340	Not feasible
#         5	0.0878142542939120	Not feasible
#         7	0.0219535635734780	Optimal
#         8	0.0548839089336950	Not feasible
#         8	0.0329303453602170	Optimal
#         4	0.1756285085878240	Optimal
#         9	0.0493955180403255	Optimal
#         9	0.0384187362535865	Not feasible
#         4	0.1756285085878240	Not feasible
#        16	0.0000428780538544	Not feasible
#        10	0.0521397134870102	Not feasible
#         5	0.2634427628817360	Not feasible
#         6	0.0439071271469560	Optimal
#        10	0.0356745408069017	Optimal
#        11	0.0507676157636679	Not feasible
#         2	0.7025140343512959	Not feasible
#         7	0.0658606907204340	Not feasible
#        11	0.0370466385302441	Optimal
#         1	1.4050280687025918	Not feasible
#        12	0.0500815669019967	Not feasible
#         6	0.2195356357347800	Not feasible
#        13	0.0497385424711611	Optimal
#         8	0.0548839089336950	Not feasible
#        14	0.0499100546865789	Not feasible
#        15	0.0498242985788700	Optimal
#         7	0.1975820721613020	Optimal
#        12	0.0377326873919153	Not feasible
#        16	0.0498671766327244	Not feasible
#         9	0.0493955180403255	Optimal
#        17	0.0498457376057972	Optimal
#        16	0.0000428780538544	Not feasible
#         8	0.2085588539480410	Optimal
#        10	0.0521397134870102	Optimal
#        18	0.0498564571192608	Optimal
#        13	0.0373896629610797	Optimal
#        11	0.0535118112103526	Optimal
#        19	0.0498618168759926	Not feasible
#        14	0.0375611751764975	Not feasible
#        20	0.0498591369976267	Not feasible
#         9	0.2140472448414105	Not feasible
#        15	0.0374754190687886	Not feasible
#        21	0.0498577970584438	Not feasible
#        12	0.0541978600720238	Optimal
#        16	0.0374325410149342	Optimal
#        22	0.0498571270888523	Optimal
# Building (10 threads):   3%|█▌                                             | 17/497 [08:24<4:27:03, 33.38s/it]
#        13	0.0545408845028594	Optimal
#        17	0.0374539800418614	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp1mjrhr7h.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        10	0.2113030493947257	Optimal
#        17	0.0000214390269272	Not feasible
#         5	0.0878142542939120	Not feasible
#        14	0.0547123967182772	Not feasible
#        18	0.0374432605283978	Not feasible
#        15	0.0546266406105683	Optimal
#        11	0.2126751471180681	Optimal
#        19	0.0374379007716660	Optimal
#         2	0.7025140343512959	Not feasible
#        16	0.0546695186644227	Optimal
#        12	0.2133611959797393	Optimal
#         8	0.0109767817867390	Not feasible
#         3	0.3512570171756479	Not feasible
#        17	0.0546909576913500	Not feasible
#        20	0.0374405806500319	Optimal
#        13	0.2137042204105749	Optimal
#        18	0.0546802381778864	Optimal
#        21	0.0374419205892148	Not feasible
#        14	0.2138757326259927	Optimal
#        19	0.0546855979346182	Optimal
# Read LP format model from file /tmp/tmpee8c0g04.lp
# Reading time = 0.00 seconds
# : 905 rows, 2058 columns, 8942 nonzeros
#        22	0.0374412506196233	Optimal
# Building (10 threads):   4%|█▋                                             | 18/497 [08:35<3:31:07, 26.45s/it]
#        15	0.2139614887337016	Optimal
#        20	0.0546882778129841	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp_5p_jhm9.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        21	0.0546896177521670	Not feasible
#        16	0.2140043667875560	Not feasible
#        22	0.0546889477825755	Optimal
#        17	0.0000214390269272	Not feasible
# Building (10 threads):   4%|█▊                                             | 19/497 [08:39<2:37:13, 19.74s/it]
#        17	0.2139829277606288	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpq7zq8w0p.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        18	0.2139936472740924	Optimal
#        19	0.2139990070308242	Not feasible
#        20	0.2139963271524583	Not feasible
#        21	0.2139949872132754	Optimal
# Read LP format model from file /tmp/tmpq7fp5ir3.lp
# Reading time = 0.00 seconds
# : 907 rows, 2056 columns, 8742 nonzeros
#        22	0.2139956571828668	Optimal
# Building (10 threads):   4%|█▉                                             | 20/497 [08:46<2:07:14, 16.01s/it]
#         6	0.0439071271469560	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpjbllcmt1.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         3	0.3512570171756479	Not feasible
# Read LP format model from file /tmp/tmpn7sepnec.lp
# Reading time = 0.01 seconds
# : 1047 rows, 2364 columns, 10174 nonzeros
# Read LP format model from file /tmp/tmp7u8sy_82.lp
# Reading time = 0.01 seconds
# : 887 rows, 2018 columns, 8744 nonzeros
#        18	0.0000107195134636	Not feasible
#         4	0.1756285085878240	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmpkahqo8lj.lp
# Reading time = 0.01 seconds
# : 914 rows, 2016 columns, 8624 nonzeros
# Read LP format model from file /tmp/tmpgaa2l6_f.lp
# Reading time = 0.00 seconds
# : 958 rows, 2038 columns, 8752 nonzeros
# Read LP format model from file /tmp/tmplr6fl2hg.lp
# Reading time = 0.01 seconds
# : 1063 rows, 2362 columns, 9974 nonzeros
#         7	0.0219535635734780	Not feasible
#         4	0.1756285085878240	Not feasible
#         9	0.0054883908933695	Not feasible
# Read LP format model from file /tmp/tmp1bggwj46.lp
# Reading time = 0.00 seconds
# : 988 rows, 2036 columns, 8632 nonzeros
#        18	0.0000107195134636	Not feasible
#         5	0.0878142542939120	Not feasible
#        19	0.0000053597567318	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	1.4050280687025918	Not feasible
#         5	0.0878142542939120	Not feasible
#         8	0.0109767817867390	Not feasible
#         6	0.0439071271469560	Not feasible
#         2	0.7025140343512959	Not feasible
#        19	0.0000053597567318	Not feasible
#         1	1.4050280687025918	Not feasible
#         6	0.0439071271469560	Not feasible
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#        20	0.0000026798783659	Not feasible
#         9	0.0054883908933695	Not feasible
#         7	0.0219535635734780	Not feasible
#        10	0.0027441954466847	Not feasible
#         2	0.7025140343512959	Not feasible
#         3	0.3512570171756479	Not feasible
#         7	0.0219535635734780	Not feasible
#        21	0.0000013399391830	Not feasible
#         2	0.7025140343512959	Not feasible
#         2	0.7025140343512959	Not feasible
#         3	0.3512570171756479	Not feasible
#         8	0.0109767817867390	Not feasible
#         4	0.1756285085878240	Not feasible
#        20	0.0000026798783659	Not feasible
#        10	0.0027441954466847	Not feasible
#         4	0.1756285085878240	Not feasible
#         8	0.0109767817867390	Not feasible
#         3	0.3512570171756479	Not feasible
#         5	0.0878142542939120	Not feasible
#         3	0.3512570171756479	Not feasible
#         5	0.0878142542939120	Not feasible
#        22	0.0000006699695915	Not feasible
#        11	0.0013720977233424	Not feasible
#         9	0.0054883908933695	Not feasible
#        21	0.0000013399391830	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpqbe574pg.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        11	0.0013720977233424	Not feasible
#         6	0.0439071271469560	Not feasible
#         4	0.1756285085878240	Not feasible
#         9	0.0054883908933695	Not feasible
#         4	0.1756285085878240	Not feasible
#         6	0.0439071271469560	Optimal
#         7	0.0658606907204340	Optimal
#         8	0.0768374725071730	Not feasible
#         9	0.0713490816138035	Not feasible
#        10	0.0686048861671187	Optimal
#        12	0.0006860488616712	Not feasible
#        11	0.0699769838904611	Optimal
#         7	0.0219535635734780	Not feasible
#         5	0.0878142542939120	Not feasible
#         5	0.0878142542939120	Optimal
#        12	0.0706630327521323	Optimal
#        10	0.0027441954466847	Not feasible
#        13	0.0710060571829679	Not feasible
#         6	0.1317213814408680	Optimal
#        14	0.0708345449675501	Not feasible
#        15	0.0707487888598412	Not feasible
#         7	0.1536749450143460	Optimal
#        22	0.0000006699695915	Not feasible
#        16	0.0707059108059868	Not feasible
#        10	0.0027441954466847	Not feasible
#        17	0.0706844717790595	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpnm5v0m0n.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         8	0.1646517268010850	Not feasible
#        18	0.0706951912925231	Not feasible
# Read LP format model from file /tmp/tmpivmuyzpp.lp
# Reading time = 0.01 seconds
# : 1152 rows, 2940 columns, 12628 nonzeros
#        19	0.0706898315357913	Optimal
#        20	0.0706925114141572	Optimal
#        21	0.0706938513533402	Optimal
#         6	0.0439071271469560	Not feasible
#         9	0.1591633359077155	Optimal
#        22	0.0706945213229317	Optimal
# Building (10 threads):   4%|█▉                                             | 21/497 [11:07<7:04:42, 53.53s/it]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpyie6wqb5.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         8	0.0109767817867390	Not feasible
#        10	0.1619075313544002	Not feasible
# Read LP format model from file /tmp/tmpum7467uo.lp
# Reading time = 0.02 seconds
# : 951 rows, 2096 columns, 8786 nonzeros
#        11	0.1605354336310579	Not feasible
#        12	0.1598493847693866	Not feasible
#        13	0.0003430244308356	Not feasible
#        13	0.1595063603385511	Not feasible
#        14	0.1593348481231333	Not feasible
#        11	0.0013720977233424	Not feasible
# Read LP format model from file /tmp/tmphup4zq31.lp
# Reading time = 0.00 seconds
# : 994 rows, 2218 columns, 9490 nonzeros
# Read LP format model from file /tmp/tmpbvr_rp0t.lp
# Reading time = 0.00 seconds
# : 968 rows, 2094 columns, 8586 nonzeros
#        15	0.1592490920154244	Optimal
#        16	0.1592919700692788	Not feasible
#        11	0.0013720977233424	Not feasible
#        17	0.1592705310423516	Optimal
#         7	0.0219535635734780	Not feasible
#        12	0.0006860488616712	Not feasible
# Read LP format model from file /tmp/tmp7dlkmmcw.lp
# Reading time = 0.01 seconds
# : 995 rows, 2216 columns, 9320 nonzeros
#        18	0.1592812505558152	Optimal
#         9	0.0054883908933695	Not feasible
#        14	0.0001715122154178	Not feasible
#        19	0.1592866103125470	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        20	0.1592839304341811	Optimal
#        21	0.1592852703733640	Optimal
#        22	0.1592859403429555	Not feasible
# Building (10 threads):   4%|██                                             | 22/497 [11:37<6:06:53, 46.34s/it]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpmne7r9gb.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmpth_s1eef.lp
# Reading time = 0.01 seconds
# : 1189 rows, 2938 columns, 12508 nonzeros
#        12	0.0006860488616712	Not feasible
#         8	0.0109767817867390	Optimal
#        12	0.0006860488616712	Not feasible
#        10	0.0027441954466847	Not feasible
#         9	0.0164651726801085	Optimal
#        10	0.0192093681267932	Optimal
