# %%
import glob
import numpy
import pandas
import seaborn
import matplotlib.pyplot as plt
from tqdm import tqdm
import multiprocessing as mp
import os
from build import build_model

# %%
from IPython.display import display, HTML, Math, Markdown
display(HTML("<style>.container { width:95% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# !bash report.sh
organisms = set(pandas.read_csv("biomass_constrained.txt",index_col=0,header=None).index.to_list())
done = {i.split(".csv")[0] for i in os.listdir("./cases/fluxes/high-1.5_lipid/")}

# %%
run_for = organisms - done
len(run_for)
# Out:
# 495

# %%
# exchanges = ["EX_ac(e)","EX_but(e)","EX_ppa(e)"]

# %%
exchanges = ["EX_arachd(e)",
            "EX_chsterol(e)",
            "EX_glyc(e)",
            "EX_hdca(e)",
            "EX_hdcea(e)",
            "EX_lnlc(e)",
            "EX_lnlnca(e)",
            "EX_lnlncg(e)",
            "EX_ocdca(e)",
            "EX_ocdcea(e)",
            "EX_octa(e)",
            "EX_ttdca(e)"]

# %%
from diets import load_model,constrain_exchanges,get_bounds
from overflow import get_overflow
import coralme

conditions = ["high-1.5"]
metabolite = "lipid"
# metabolite = "FA"

for c in conditions:
    name = "{}_{}".format(c,metabolite)
    fluxdir = "./cases/fluxes/{}".format(name)
    overflowdir = "./cases/overflow/{}".format(name)
    if not os.path.isdir(fluxdir):
        os.makedirs(fluxdir)
        os.makedirs(overflowdir)

def run(org):
    model = coralme.io.pickle.load_pickle_me_model("./me-models/{}/MEModel-BIO-{}-ME-TS.pkl".format(org,org))
    # return model
    sol0 = model.solution
    df0 = sol0.to_frame()
    # Exchanges
    rlist = [r for r in exchanges if model.reactions.has_id(r)]
    # Run for all conditions
    for condition in conditions:
        name = "{}_{}".format(condition,metabolite)
        # dct = {k:-0.5 for k in rlist if k in model.reactions}
        dct = get_bounds(sol0,rlist,multiplier=1.5) # high
        constrain_exchanges(model,dct)
        model.optimize()
        model.solution.to_frame().to_csv("cases/fluxes/{}/{}.csv".format(name,org))
        get_overflow(model).to_csv("./cases/overflow/{}/{}.csv".format(name,org))

# %%
NP = min([20,len(run_for)])
pool = mp.Pool(NP,maxtasksperchild=1)
pbar = tqdm(total=len(run_for),position=0,leave=True)
pbar.set_description('Building ({} threads)'.format(NP))
def collect_result(result):
    pbar.update(1)

for org in run_for:
    args = ([org])
    pool.apply_async(run,args, callback=collect_result)
pool.close()
pool.join()
# Out:
# Building (20 threads):   0%|          | 0/495 [00:00<?, ?it/s]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp6bq17dhk.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpdbydvw3r.lp
# Reading time = 0.00 seconds
# : 848 rows, 1830 columns, 7744 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmptyo2xf4k.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Read LP format model from file /tmp/tmp5ch1a_i_.lp
# Reading time = 0.00 seconds
# : 1042 rows, 2392 columns, 10236 nonzeros
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpxy9jhcyb.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpra4nefme.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpk_ovtt2k.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpz8or87pc.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp_qogimea.lp
# Reading time = 0.00 seconds
# : 768 rows, 1556 columns, 6634 nonzeros
# Read LP format model from file /tmp/tmpzvz8cswh.lp
# Reading time = 0.00 seconds
# : 919 rows, 2054 columns, 8932 nonzeros
# Set parameter Username
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpd4yffacr.lp
# Read LP format model from file /tmp/tmp9k8mwoni.lp
# Reading time = 0.00 seconds
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpigipvq79.lp
# : 0 rows, 0 columns, 0 nonzeros
# Reading time = 0.00 seconds
# : 857 rows, 1776 columns, 7608 nonzeros
# Read LP format model from file /tmp/tmpvz9tjnz4.lp
# Reading time = 0.01 seconds
# : 982 rows, 2176 columns, 9416 nonzeros
# Set parameter Username
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpms3kbps3.lp
# Read LP format model from file /tmp/tmp3bkbuqhk.lp
# Reading time = 0.00 seconds
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp0upjh9de.lp
# Set parameter Username
# Reading time = 0.00 seconds
# : 1142 rows, 2714 columns, 11686 nonzeros
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpl5c4lklu.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp6ulb9c1t.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmphvl_3ws4.lp
# Reading time = 0.00 seconds
# : 848 rows, 1828 columns, 7622 nonzeros
# Read LP format model from file /tmp/tmp2wipgjso.lp
# Reading time = 0.01 seconds
# : 897 rows, 1902 columns, 8248 nonzeros
# Read LP format model from file /tmp/tmp4mdok3a7.lp
# Set parameter Username
# Reading time = 0.01 seconds
# : 1142 rows, 2616 columns, 11340 nonzeros
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmphwvtjn5d.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpcx3yybcb.lp
# Reading time = 0.00 seconds
# : 1077 rows, 2422 columns, 10470 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpad52dwrk.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpiuxjyn9m.lp
# Reading time = 0.01 seconds
# : 990 rows, 2202 columns, 9496 nonzeros
# Set parameter Username
# Read LP format model from file /tmp/tmphk2vtzaf.lp
# Academic license - for non-commercial use only - expires 2025-09-03
# Reading time = 0.00 seconds
# Read LP format model from file /tmp/tmppa3pzmnk.lp
# Reading time = 0.00 seconds
# : 1015 rows, 2226 columns, 9662 nonzeros
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpsukb1q0c.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpu2obqsgc.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpmipd1t4n.lp
# Reading time = 0.01 seconds
# : 1078 rows, 2390 columns, 10252 nonzeros
# Read LP format model from file /tmp/tmp1wyj9v3z.lp
# Reading time = 0.01 seconds
# : 1021 rows, 2270 columns, 9602 nonzeros
# Read LP format model from file /tmp/tmpmly7rn44.lp
# Reading time = 0.01 seconds
# : 1075 rows, 2460 columns, 10634 nonzeros
# Read LP format model from file /tmp/tmpt61_cstq.lp
# Reading time = 0.00 seconds
# : 1343 rows, 3202 columns, 13882 nonzeros
# Read LP format model from file /tmp/tmpqs4lj9vx.lp
# Reading time = 0.01 seconds
# : 1061 rows, 2590 columns, 11398 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpgul5d996.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpbie2isz7.lp
# Reading time = 0.00 seconds
# : 1044 rows, 2390 columns, 10036 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpahj608lf.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp1mzh8u02.lp
# Reading time = 0.00 seconds
# : 769 rows, 1554 columns, 6514 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp0tsz1jto.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpzjvo27f8.lp
# Reading time = 0.00 seconds
# : 880 rows, 1774 columns, 7486 nonzeros
# Read LP format model from file /tmp/tmpvucp68l_.lp
# Reading time = 0.00 seconds
# : 1153 rows, 2712 columns, 11486 nonzeros
# Read LP format model from file /tmp/tmpoj0mvjkc.lp
# Reading time = 0.01 seconds
# : 1222 rows, 2918 columns, 13046 nonzeros
# Read LP format model from file /tmp/tmp91tw8x0a.lp
# Reading time = 0.00 seconds
# : 930 rows, 1900 columns, 8128 nonzeros
# Read LP format model from file /tmp/tmpqldnb4zv.lp
# Reading time = 0.01 seconds
# : 1285 rows, 3134 columns, 13726 nonzeros
# Read LP format model from file /tmp/tmpjckc7zdi.lp
# Reading time = 0.01 seconds
# : 947 rows, 2052 columns, 8762 nonzeros
# Read LP format model from file /tmp/tmphkr6rsbl.lp
# Reading time = 0.01 seconds
# : 1354 rows, 3352 columns, 14510 nonzeros
# Read LP format model from file /tmp/tmpv5b_5rub.lp
# Reading time = 0.01 seconds
# : 982 rows, 2174 columns, 9246 nonzeros
# Read LP format model from file /tmp/tmptvih_x8q.lp
# Reading time = 0.00 seconds
# : 1038 rows, 2224 columns, 9462 nonzeros
# Read LP format model from file /tmp/tmpd_1cx5sa.lp
# Reading time = 0.01 seconds
# : 1015 rows, 2200 columns, 9326 nonzeros
# Read LP format model from file /tmp/tmpi4xo9zng.lp
# Reading time = 0.00 seconds
# : 1355 rows, 3200 columns, 13712 nonzeros
# Read LP format model from file /tmp/tmp3fxph7f0.lp
# Reading time = 0.01 seconds
# : 1144 rows, 2614 columns, 11170 nonzeros
# Read LP format model from file /tmp/tmp060jl5n3.lp
# Reading time = 0.01 seconds
# : 1087 rows, 2420 columns, 10270 nonzeros
# Read LP format model from file /tmp/tmphhaj65on.lp
# Reading time = 0.01 seconds
# : 1044 rows, 2268 columns, 9482 nonzeros
# Read LP format model from file /tmp/tmp04jzw6vt.lp
# Reading time = 0.01 seconds
# : 1106 rows, 2388 columns, 10082 nonzeros
# Read LP format model from file /tmp/tmp_k1g0gbu.lp
# Reading time = 0.01 seconds
# : 1100 rows, 2458 columns, 10514 nonzeros
# Read LP format model from file /tmp/tmpjzgq4s72.lp
# Reading time = 0.01 seconds
# : 1089 rows, 2588 columns, 11278 nonzeros
# Read LP format model from file /tmp/tmps01scr_z.lp
# Reading time = 0.01 seconds
# : 1223 rows, 2916 columns, 12846 nonzeros
# Read LP format model from file /tmp/tmpmwfl5b3k.lp
# Reading time = 0.01 seconds
# : 1301 rows, 3132 columns, 13526 nonzeros
# Read LP format model from file /tmp/tmpjl7vme58.lp
# Reading time = 0.01 seconds
# : 1379 rows, 3350 columns, 14340 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
#         2	0.7025140343512959	Not feasible
#         1	1.4050280687025918	Not feasible
#         3	0.3512570171756479	Not feasible
#         2	0.7025140343512959	Not feasible
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
#         2	0.7025140343512959	Not feasible
#         3	0.3512570171756479	Not feasible
#         3	0.3512570171756479	Not feasible
#         2	0.7025140343512959	Not feasible
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
#         3	0.3512570171756479	Not feasible
#         4	0.1756285085878240	Optimal
#         5	0.2634427628817360	Not feasible
#         3	0.3512570171756479	Not feasible
#         3	0.3512570171756479	Not feasible
#         6	0.2195356357347800	Optimal
#         1	1.4050280687025918	Not feasible
#         4	0.1756285085878240	Not feasible
#         2	0.7025140343512959	Not feasible
#         3	0.3512570171756479	Not feasible
#         4	0.1756285085878240	Optimal
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
#         5	0.2634427628817360	Not feasible
#         3	0.3512570171756479	Optimal
#         2	0.7025140343512959	Not feasible
#         4	0.1756285085878240	Not feasible
#         2	0.7025140343512959	Not feasible
#         7	0.2414891993082580	Not feasible
#         6	0.2195356357347800	Not feasible
#         4	0.5268855257634719	Not feasible
#         4	0.1756285085878240	Not feasible
#         1	1.4050280687025918	Not feasible
#         2	0.7025140343512959	Not feasible
#         7	0.1975820721613020	Optimal
#         8	0.2305124175215190	Not feasible
#         5	0.0878142542939120	Not feasible
#         5	0.4390712714695599	Not feasible
#         8	0.2085588539480410	Optimal
#         3	0.3512570171756479	Not feasible
#         4	0.1756285085878240	Not feasible
#         9	0.2250240266281495	Not feasible
#         4	0.1756285085878240	Not feasible
#         9	0.2140472448414105	Not feasible
#        10	0.2222798311814647	Not feasible
#        10	0.2113030493947257	Not feasible
#         6	0.3951641443226039	Optimal
#        11	0.2209077334581223	Not feasible
#        11	0.2099309516713833	Not feasible
#        12	0.2202216845964511	Optimal
#        12	0.2092449028097121	Not feasible
#        13	0.2205647090272868	Not feasible
#         5	0.0878142542939120	Optimal
#         3	0.3512570171756479	Not feasible
#         7	0.4171177078960819	Not feasible
#        13	0.2089018783788766	Not feasible
#        14	0.2203931968118689	Not feasible
#         5	0.0878142542939120	Optimal
#        15	0.2203074407041600	Optimal
#        14	0.2087303661634587	Not feasible
#         1	1.4050280687025918	Not feasible
#         6	0.1317213814408680	Not feasible
#         8	0.4061409261093429	Not feasible
#         6	0.1317213814408680	Optimal
#        16	0.2203503187580145	Not feasible
#        15	0.2086446100557499	Optimal
#         7	0.1536749450143460	Optimal
#        17	0.2203288797310873	Optimal
#         7	0.1097678178673900	Optimal
#        16	0.2086874881096043	Optimal
#         6	0.0439071271469560	Not feasible
#         8	0.1646517268010850	Optimal
#        18	0.2203395992445509	Optimal
#         9	0.4006525352159734	Optimal
#         2	0.7025140343512959	Not feasible
#         3	0.3512570171756479	Not feasible
#         5	0.0878142542939120	Not feasible
#        19	0.2203449590012827	Optimal
#         5	0.0878142542939120	Optimal
#         9	0.1701401176944545	Optimal
#        17	0.2087089271365315	Not feasible
#         8	0.1207445996541290	Not feasible
#        20	0.2203476388796486	Optimal
#         6	0.1317213814408680	Not feasible
#        10	0.1728843131411392	Not feasible
#        21	0.2203489788188315	Optimal
#        10	0.4033967306626582	Optimal
#         3	0.3512570171756479	Not feasible
#         7	0.1097678178673900	Not feasible       18	0.2086982076230679	Optimal
#
#         9	0.1152562087607595	Optimal
#         3	0.3512570171756479	Not feasible
#         3	0.3512570171756479	Not feasible
#         4	0.1756285085878240	Not feasible
#         8	0.0987910360806510	Not feasible
#        11	0.1715122154177968	Optimal
#        22	0.2203496487884230	Not feasible
# Building (20 threads):   0%|          | 1/495 [01:36<13:15:46, 96.65s/it]
#         2	0.7025140343512959	Not feasible
#        10	0.1180004042074442	Not feasible
#        19	0.2087035673797997	Optimal
#         9	0.0933026451872815	Not feasible
#        11	0.4047688283860006	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpl1je9ssg.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmplpozx68q.lp
# Reading time = 0.00 seconds
# : 960 rows, 2116 columns, 9036 nonzeros
#        10	0.0905584497405967	Optimal
# Read LP format model from file /tmp/tmp2o7p1xmk.lp
# Reading time = 0.00 seconds
# : 971 rows, 2114 columns, 8836 nonzeros
#        11	0.1166283064841019	Optimal
#        20	0.2087062472581656	Not feasible
#        12	0.4054548772476718	Optimal
#        12	0.1721982642794680	Optimal
#        12	0.1173143553457730	Not feasible
#        11	0.0919305474639391	Not feasible
#        21	0.2087049073189827	Optimal
#        13	0.1169713309149374	Not feasible
#        13	0.1725412887103036	Not feasible
#        13	0.4057979016785074	Not feasible
#         4	0.1756285085878240	Optimal
#        12	0.0912444986022679	Optimal
#         7	0.0219535635734780	Not feasible
#        14	0.1167998186995197	Not feasible
#         6	0.0439071271469560	Not feasible
#        14	0.1723697764948858	Not feasible
#        22	0.2087055772885741	Optimal
#        13	0.0915875230331035	Not feasible
# Building (20 threads):   0%|          | 2/495 [01:43<5:59:36, 43.77s/it]
#         1	1.4050280687025918	Not feasible
#        14	0.4056263894630896	Not feasible
#        15	0.1167140625918107	Not feasible
#        15	0.1722840203871769	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpl420_2el.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpr83b_jw8.lp
# Reading time = 0.01 seconds
# : 1094 rows, 2616 columns, 11564 nonzeros
#         5	0.2634427628817360	Optimal
#        16	0.1166711845379563	Not feasible
#        14	0.0914160108176857	Optimal
#        16	0.1722411423333225	Not feasible
#        15	0.4055406333553807	Not feasible
# Read LP format model from file /tmp/tmpo2bgwuin.lp
# Reading time = 0.01 seconds
# : 1106 rows, 2614 columns, 11394 nonzeros
#         2	0.7025140343512959	Not feasible
#        17	0.1166497455110291	Optimal
#        15	0.0915017669253946	Not feasible
#        17	0.1722197033063953	Optimal
#        18	0.1166604650244927	Not feasible
#        16	0.4054977553015262	Not feasible
#        18	0.1722304228198589	Optimal
#        19	0.1166551052677609	Not feasible
#        16	0.0914588888715402	Optimal
#         4	0.1756285085878240	Optimal
#         6	0.3073498900286920	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        20	0.1166524253893950	Optimal
#        17	0.4054763162745990	Optimal
#        19	0.1722357825765907	Not feasible
#         4	0.1756285085878240	Not feasible
#        21	0.1166537653285779	Optimal
#         5	0.2634427628817360	Optimal
#        17	0.0914803278984674	Not feasible
#         7	0.0219535635734780	Not feasible
#        22	0.1166544352981694	Not feasible
# Building (20 threads):   1%|          | 3/495 [01:52<3:49:20, 27.97s/it]
#        18	0.4054870357880626	Optimal
#        20	0.1722331026982248	Not feasible
#        18	0.0914696083850038	Optimal
#         7	0.2853963264552140	Optimal
#         6	0.3073498900286920	Optimal
#         5	0.0878142542939120	Not feasible
#         1	1.4050280687025918	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmptbq3dgba.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp2ca6tz1z.lp
# Reading time = 0.01 seconds
# : 1297 rows, 3258 columns, 14028 nonzeros
#        19	0.4054923955447944	Optimal
#        21	0.1722317627590418	Optimal
#        19	0.0914749681417356	Optimal
#         2	0.7025140343512959	Not feasible
# Read LP format model from file /tmp/tmpzans0va6.lp
# Reading time = 0.01 seconds
# : 1330 rows, 3256 columns, 13858 nonzeros
#         8	0.0109767817867390	Not feasible
#         7	0.3293034536021699	Optimal
#         4	0.1756285085878240	Not feasible
#        22	0.1722324327286333	Optimal
# Building (20 threads):   1%|          | 4/495 [01:56<2:32:24, 18.62s/it]
#        20	0.4054950754231603	Optimal
#         8	0.2963731082419530	Not feasible
#        20	0.0914776480201015	Not feasible
#         8	0.3402802353889089	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp2y4y8zqv.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpbb7kvtnj.lp
# Reading time = 0.01 seconds
# : 1108 rows, 2464 columns, 10728 nonzeros
#         4	0.1756285085878240	Not feasible
#         9	0.2908847173485835	Optimal
#        21	0.4054964153623433	Optimal
# Read LP format model from file /tmp/tmpumno5nha.lp
# Reading time = 0.01 seconds
# : 1119 rows, 2462 columns, 10528 nonzeros
#        21	0.0914763080809185	Optimal
#        22	0.4054970853319347	Not feasible
# Building (20 threads):   1%|          | 5/495 [02:01<1:51:12, 13.62s/it]
#        10	0.2936289127952682	Not feasible
#         3	0.3512570171756479	Not feasible
#        22	0.0914769780505100	Optimal
# Building (20 threads):   1%|          | 6/495 [02:02<1:15:13,  9.23s/it]
#         9	0.3457686262822784	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmppxefbtnk.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpc591blmt.lp
# Reading time = 0.01 seconds
# : 1233 rows, 2908 columns, 12694 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp2kwcejho.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpijh497t6.lp
# Reading time = 0.00 seconds
# : 928 rows, 2032 columns, 8658 nonzeros
#        11	0.2922568150719258	Optimal
# Read LP format model from file /tmp/tmpoqpmnhvi.lp
# Reading time = 0.00 seconds
# : 950 rows, 2030 columns, 8538 nonzeros
# Read LP format model from file /tmp/tmpz6zey9kx.lp
# Reading time = 0.01 seconds
# : 1247 rows, 2906 columns, 12494 nonzeros
#         8	0.0109767817867390	Not feasible
#        12	0.2929428639335970	Not feasible
#         3	0.3512570171756479	Optimal
#        13	0.2925998395027614	Not feasible
#         1	1.4050280687025918	Not feasible
#        10	0.3485128217289632	Not feasible
#        14	0.2924283272873436	Not feasible
#         5	0.0878142542939120	Not feasible
#        15	0.2923425711796347	Optimal
#         6	0.0439071271469560	Optimal
#        11	0.3471407240056208	Not feasible
#         9	0.0054883908933695	Optimal
#        16	0.2923854492334891	Optimal
#         4	0.5268855257634719	Not feasible
#        12	0.3464546751439496	Not feasible
#        10	0.0082325863400542	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        17	0.2924068882604164	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         7	0.0658606907204340	Not feasible
#         2	0.7025140343512959	Not feasible
#        18	0.2924176077738800	Not feasible
#        13	0.3461116507131140	Optimal
#         5	0.0878142542939120	Optimal
#        11	0.0068604886167119	Optimal
#         9	0.0054883908933695	Not feasible
#        12	0.0075465374783831	Optimal
#        19	0.2924122480171482	Not feasible
#         5	0.4390712714695599	Optimal
#        14	0.3462831629285318	Not feasible
#         5	0.0878142542939120	Optimal
#         2	0.7025140343512959	Not feasible
#         8	0.0548839089336950	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         6	0.1317213814408680	Optimal
#        13	0.0078895619092187	Optimal
#        20	0.2924095681387823	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         3	0.3512570171756479	Not feasible
#        14	0.0080610741246365	Optimal
#        21	0.2924109080779652	Optimal
#        15	0.3461974068208229	Optimal
#         6	0.1317213814408680	Optimal
#         9	0.0603722998270645	Not feasible
#        15	0.0081468302323454	Not feasible
#         7	0.1536749450143460	Not feasible
#         3	0.3512570171756479	Not feasible
#         3	0.3512570171756479	Not feasible
#        22	0.2924115780475567	Optimal
# Building (20 threads):   1%|▏         | 7/495 [02:26<1:54:11, 14.04s/it]
#        10	0.0576281043803797	Not feasible
#        16	0.0081039521784909	Not feasible
#        16	0.3462402848746773	Optimal
#         6	0.4829783986165159	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp8yva6vbh.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpouv257m7.lp
# Reading time = 0.01 seconds
# : 1013 rows, 2204 columns, 9416 nonzeros
#        17	0.0080825131515637	Optimal
#         7	0.1536749450143460	Not feasible
# Read LP format model from file /tmp/tmpnp1wux98.lp
# Reading time = 0.00 seconds
# : 1035 rows, 2202 columns, 9246 nonzeros
#         4	0.1756285085878240	Not feasible
#        11	0.0562560066570374	Optimal
#        18	0.0080932326650273	Optimal
#        17	0.3462617239016046	Optimal
#        12	0.0569420555187086	Not feasible
#         8	0.1426981632276070	Optimal
#        19	0.0080985924217591	Not feasible
#         7	0.4610248350430379	Optimal
#         6	0.0439071271469560	Optimal
#        18	0.3462724434150682	Not feasible
#        20	0.0080959125433932	Optimal
#         8	0.1426981632276070	Optimal
#        13	0.0565990310878730	Not feasible
#        21	0.0080972524825761	Optimal
#         7	0.0658606907204340	Optimal
#         4	0.1756285085878240	Not feasible
#        14	0.0564275188724552	Optimal
#        19	0.3462670836583364	Not feasible
#         9	0.1481865541209765	Not feasible
#        22	0.0080979224521676	Optimal
# Building (20 threads):   2%|▏         | 8/495 [02:36<1:44:00, 12.81s/it]
#        15	0.0565132749801641	Not feasible
#         9	0.1481865541209765	Not feasible
#        10	0.0027441954466847	Optimal
#         1	1.4050280687025918	Not feasible
#         8	0.4720016168297769	Not feasible
#         1	1.4050280687025918	Not feasible
#        16	0.0564703969263096	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp20kr8dn5.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpgqtxxcoj.lp
# Reading time = 0.00 seconds
# : 963 rows, 2116 columns, 8958 nonzeros
#        11	0.0041162931700271	Optimal
#        17	0.0564918359532368	Not feasible
#        20	0.3462644037799705	Not feasible
# Read LP format model from file /tmp/tmp447r0bvs.lp
# Reading time = 0.00 seconds
# : 986 rows, 2114 columns, 8838 nonzeros
#        10	0.1454423586742917	Not feasible
#         8	0.0768374725071730	Not feasible
#        18	0.0564811164397732	Not feasible
#         9	0.4665132259364074	Optimal
#        19	0.0564757566830414	Optimal
#        12	0.0048023420316983	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        20	0.0564784365614073	Optimal
#        11	0.1440702609509494	Optimal
#        21	0.3462630638407875	Optimal
#        10	0.1454423586742917	Optimal
#         2	0.7025140343512959	Not feasible
#        21	0.0564797765005903	Optimal
#         9	0.0713490816138035	Optimal
#        13	0.0044593176008627	Optimal
#        10	0.4692574213830922	Not feasible
#        22	0.0564804464701818	Optimal
# Building (20 threads):   2%|▏         | 9/495 [02:44<1:31:51, 11.34s/it]
#        22	0.3462637338103790	Not feasible
#        12	0.1447563098126206	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpkbfo73r0.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpx04agumf.lp
# Reading time = 0.00 seconds
# : 722 rows, 1452 columns, 6300 nonzeros
# Building (20 threads):   2%|▏         | 10/495 [02:45<1:04:59,  8.04s/it]
# Read LP format model from file /tmp/tmp6u7newyq.lp
# Reading time = 0.00 seconds
# : 747 rows, 1450 columns, 6180 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp8amcaoyl.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpv51641lp.lp
# Reading time = 0.00 seconds
# : 839 rows, 1804 columns, 7692 nonzeros
#        14	0.0046308298162805	Optimal
#        10	0.0740932770604882	Not feasible
#         2	0.7025140343512959	Not feasible
# Read LP format model from file /tmp/tmprvf8fhph.lp
# Reading time = 0.00 seconds
# : 840 rows, 1802 columns, 7572 nonzeros
#        11	0.4678853236597498	Optimal
#        13	0.1450993342434561	Not feasible
#        11	0.1468144563976341	Not feasible
#         5	0.0878142542939120	Optimal
#        11	0.0727211793371459	Optimal
#        15	0.0047165859239894	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         6	0.1317213814408680	Optimal
#        12	0.4685713725214210	Optimal
#        12	0.1461284075359629	Not feasible
#        14	0.1449278220280383	Not feasible
#        16	0.0046737078701350	Optimal
#        12	0.0734072281988171	Optimal
#         7	0.1536749450143460	Not feasible
#        13	0.4689143969522566	Optimal
#        13	0.1457853831051273	Optimal
#        13	0.0737502526296527	Optimal
#         1	1.4050280687025918	Not feasible
#         1	1.4050280687025918	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         5	0.0878142542939120	Optimal
#         8	0.1426981632276070	Optimal
#        15	0.1448420659203294	Optimal
#        17	0.0046951468970622	Optimal
#        14	0.0739217648450704	Not feasible
#        14	0.4690859091676743	Optimal
#         2	0.7025140343512959	Not feasible
#         9	0.1481865541209765	Not feasible
#        15	0.0738360087373615	Not feasible
#        18	0.0047058664105258	Not feasible
#        10	0.1454423586742917	Optimal
#        16	0.1448849439741839	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        11	0.1468144563976341	Not feasible
#         3	0.3512570171756479	Not feasible
#         6	0.1317213814408680	Optimal
#         3	0.3512570171756479	Not feasible
#        16	0.0737931306835071	Optimal
#        19	0.0047005066537940	Not feasible
#        15	0.4691716652753832	Optimal
#        12	0.1461284075359629	Optimal
#         4	0.1756285085878240	Not feasible
#        14	0.1459568953205451	Not feasible
#        17	0.1449063830011111	Optimal
#        13	0.1464714319667985	Optimal
#         4	0.1756285085878240	Not feasible
#         7	0.1536749450143460	Optimal
#        20	0.0046978267754281	Optimal
#         2	0.7025140343512959	Not feasible
#        14	0.1466429441822163	Not feasible
#        17	0.0738145697104343	Not feasible
#         5	0.0878142542939120	Not feasible
#        21	0.0046991667146110	Optimal
#        15	0.1465571880745074	Not feasible
#         3	0.3512570171756479	Optimal
#        22	0.0046998366842025	Not feasible
#        16	0.1465143100206530	Not feasible
# Building (20 threads):   2%|▏         | 11/495 [03:03<1:29:20, 11.08s/it]
#        18	0.0738038501969707	Not feasible
#        18	0.1449171025145747	Optimal
#        16	0.4692145433292377	Optimal
#         6	0.0439071271469560	Not feasible
#        17	0.1464928709937257	Optimal
#        15	0.1458711392128362	Not feasible
#        18	0.1465035905071894	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpps60o7us.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmphd9xli2t.lp
# Reading time = 0.01 seconds
# : 1335 rows, 3370 columns, 14506 nonzeros
#        19	0.1449224622713065	Optimal
#        19	0.0737984904402389	Not feasible
#         7	0.0219535635734780	Optimal
#        19	0.1464982307504575	Optimal
#         8	0.1646517268010850	Not feasible
#         8	0.0329303453602170	Not feasible
#         9	0.0274419544668475	Optimal
# Read LP format model from file /tmp/tmpm_6x047d.lp
# Reading time = 0.01 seconds
# : 1360 rows, 3368 columns, 14336 nonzeros
#        10	0.0301861499135322	Not feasible
#        20	0.1465009106288234	Not feasible
#        17	0.4692359823561649	Not feasible
#        11	0.0288140521901899	Not feasible
#        20	0.0737958105618730	Optimal
#        20	0.1449251421496724	Not feasible
#         4	0.1756285085878240	Not feasible
#        12	0.0281280033285187	Optimal
#        21	0.1464995706896405	Not feasible
#        13	0.0284710277593543	Optimal
#         9	0.1591633359077155	Not feasible
#        14	0.0286425399747721	Not feasible
#        15	0.0285567838670632	Not feasible
#        22	0.1464989007200490	Not feasible
# Building (20 threads):   2%|▏         | 12/495 [03:09<1:17:08,  9.58s/it]
#        16	0.0285139058132087	Optimal
#        17	0.0285353448401360	Not feasible
#        21	0.0737971505010560	Optimal
#        18	0.0285246253266723	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpfr6v98s2.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        19	0.0285192655699405	Optimal
#         1	1.4050280687025918	Not feasible
# Read LP format model from file /tmp/tmpek92o5yj.lp
# Reading time = 0.00 seconds
# : 1013 rows, 2276 columns, 9774 nonzeros
#         1	1.4050280687025918	Not feasible
#        20	0.0285219454483064	Optimal
#        21	0.0285232853874894	Not feasible
# Read LP format model from file /tmp/tmpa1yvdi35.lp
# Reading time = 0.00 seconds
# : 1035 rows, 2274 columns, 9604 nonzeros
#        16	0.1458282611589818	Not feasible
#        21	0.1449238022104895	Not feasible
#        22	0.0285226154178979	Not feasible
# Building (20 threads):   3%|▎         | 13/495 [03:11<58:39,  7.30s/it]
#        18	0.4692252628427013	Optimal
#        10	0.1564191404610307	Optimal
#        22	0.0737978204706474	Not feasible
# Building (20 threads):   3%|▎         | 14/495 [03:12<43:08,  5.38s/it]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpuorlo3ww.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpqj2pt1od.lp
# Reading time = 0.01 seconds
# : 883 rows, 1958 columns, 8312 nonzeros
# Read LP format model from file /tmp/tmpl14sxdg2.lp
# Reading time = 0.00 seconds
# : 883 rows, 1956 columns, 8142 nonzeros
#         4	0.1756285085878240	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpff2grr5r.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpdwcmmj43.lp
# Reading time = 0.01 seconds
# : 1027 rows, 2408 columns, 10182 nonzeros
#        22	0.1449231322408980	Not feasible
# Building (20 threads):   3%|▎         | 15/495 [03:14<35:30,  4.44s/it]
# Read LP format model from file /tmp/tmp3u0b4k_x.lp
# Reading time = 0.01 seconds
# : 1050 rows, 2406 columns, 9982 nonzeros
#         4	0.5268855257634719	Not feasible
#        19	0.4692306225994332	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpg_qcjhfv.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp2xbhzx7r.lp
# Reading time = 0.00 seconds
# : 942 rows, 2114 columns, 9036 nonzeros
# Read LP format model from file /tmp/tmpe04xe4v6.lp
# Reading time = 0.00 seconds
# : 964 rows, 2112 columns, 8836 nonzeros
#         2	0.7025140343512959	Not feasible
#        17	0.1458068221320545	Not feasible
#        11	0.1577912381843731	Not feasible
#        20	0.4692279427210673	Not feasible
#         3	0.3512570171756479	Not feasible
#         1	1.4050280687025918	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        12	0.1571051893227019	Not feasible
#         2	0.7025140343512959	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        21	0.4692266027818843	Not feasible
#        18	0.1457961026185909	Optimal
#         5	0.4390712714695599	Not feasible
#         1	1.4050280687025918	Not feasible
#        22	0.4692259328122929	Optimal
# Building (20 threads):   3%|▎         | 16/495 [03:27<56:58,  7.14s/it]
#         5	0.0878142542939120	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        13	0.1567621648918663	Optimal
#         3	0.3512570171756479	Not feasible
#        19	0.1458014623753227	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpleda0gf0.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp22dz_afh.lp
# Reading time = 0.01 seconds
# : 1264 rows, 3184 columns, 13512 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmpz8llc0k7.lp
# Reading time = 0.01 seconds
# : 1301 rows, 3182 columns, 13392 nonzeros
#        14	0.1569336771072841	Not feasible
#         2	0.7025140343512959	Not feasible
#         2	0.7025140343512959	Not feasible
#        20	0.1457987824969568	Not feasible
#         5	0.0878142542939120	Not feasible
#         6	0.3951641443226039	Not feasible
#        15	0.1568479209995752	Not feasible
#         1	1.4050280687025918	Not feasible
#         6	0.0439071271469560	Optimal
#         3	0.3512570171756479	Optimal
#         3	0.3512570171756479	Not feasible
#        16	0.1568050429457208	Optimal
#         2	0.7025140343512959	Not feasible
#         7	0.0658606907204340	Optimal
#        21	0.1457974425577739	Optimal
#         8	0.0768374725071730	Optimal
#         5	0.0878142542939120	Optimal
#         1	1.4050280687025918	Not feasible
#        17	0.1568264819726480	Optimal
#         2	0.7025140343512959	Not feasible
#         4	0.5268855257634719	Not feasible
#        22	0.1457981125273654	Optimal
# Building (20 threads):   3%|▎         | 17/495 [03:47<1:26:30, 10.86s/it]
#         9	0.0823258634005425	Optimal
#         7	0.3732105807491259	Optimal
#        18	0.1568372014861116	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp7psys1xr.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpgh6ccod4.lp
# Reading time = 0.00 seconds
# : 1001 rows, 2188 columns, 9416 nonzeros
# Read LP format model from file /tmp/tmpt2rlpj1_.lp
# Reading time = 0.00 seconds
# : 1026 rows, 2186 columns, 9216 nonzeros
#         3	0.3512570171756479	Not feasible
#         5	0.4390712714695599	Not feasible
#         4	0.1756285085878240	Not feasible
#         1	1.4050280687025918	Not feasible
#        19	0.1568318417293798	Not feasible
#        10	0.0850700588472272	Not feasible
#         1	1.4050280687025918	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         3	0.3512570171756479	Not feasible
#         6	0.3951641443226039	Not feasible
#        20	0.1568291618510139	Not feasible
#         1	1.4050280687025918	Not feasible
#         6	0.1317213814408680	Not feasible
#         4	0.1756285085878240	Not feasible
#         3	0.3512570171756479	Optimal
#         8	0.3841873625358649	Not feasible
#        11	0.0836979611238849	Not feasible
#         6	0.0439071271469560	Not feasible
#         3	0.3512570171756479	Not feasible
#        21	0.1568278219118310	Optimal
#        12	0.0830119122622137	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         7	0.3732105807491259	Optimal
#        13	0.0826688878313781	Not feasible
#        22	0.1568284918814224	Optimal
# Building (20 threads):   4%|▎         | 18/495 [04:03<1:39:31, 12.52s/it]
#         4	0.1756285085878240	Not feasible
#         4	0.5268855257634719	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpuru4uvh9.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpyihkflei.lp
# Reading time = 0.01 seconds
# : 1090 rows, 2590 columns, 11210 nonzeros
#         2	0.7025140343512959	Not feasible
#         4	0.1756285085878240	Optimal
#         4	0.1756285085878240	Not feasible
#         9	0.3786989716424954	Optimal
#        14	0.0824973756159603	Not feasible
#         7	0.1097678178673900	Optimal
# Read LP format model from file /tmp/tmpenmz7_d1.lp
# Reading time = 0.00 seconds
# : 1115 rows, 2588 columns, 11010 nonzeros
#         2	0.7025140343512959	Not feasible
#         8	0.3841873625358649	Optimal
#        15	0.0824116195082514	Optimal
#         8	0.1207445996541290	Optimal
#         5	0.4390712714695599	Not feasible
#        16	0.0824544975621058	Optimal
#         9	0.3896757534292344	Optimal
#         5	0.0878142542939120	Optimal
#        17	0.0824759365890330	Optimal
#         6	0.1317213814408680	Optimal
#        10	0.3924199488759192	Not feasible
#         5	0.0878142542939120	Not feasible
#        18	0.0824866561024967	Optimal
#        10	0.3814431670891802	Optimal
#         2	0.7025140343512959	Not feasible
#         6	0.3951641443226039	Optimal
#         7	0.1536749450143460	Not feasible
#        11	0.3910478511525768	Not feasible
#         9	0.1262329905474985	Optimal
#        19	0.0824920158592285	Optimal
#         4	0.1756285085878240	Not feasible
#         5	0.0878142542939120	Not feasible
#         8	0.1426981632276070	Not feasible
#         5	0.0878142542939120	Not feasible
#         3	0.3512570171756479	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        11	0.3828152648125226	Not feasible
#         5	0.2634427628817360	Optimal
#        20	0.0824946957375944	Not feasible
#        12	0.3903618022909056	Not feasible
#         9	0.1372097723342375	Optimal
#         7	0.4171177078960819	Not feasible
#        10	0.1399539677809222	Optimal
#        21	0.0824933557984114	Optimal
#         3	0.3512570171756479	Not feasible
#        13	0.3900187778600700	Not feasible
#        12	0.3821292159508514	Optimal
#        11	0.1413260655042646	Optimal
#        22	0.0824940257680029	Optimal
# Building (20 threads):   4%|▍         | 19/495 [04:25<1:59:51, 15.11s/it]
#        14	0.3898472656446522	Not feasible
#         1	1.4050280687025918	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpgtnq692y.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp0evcooc3.lp
# Reading time = 0.01 seconds
# : 1064 rows, 2490 columns, 10616 nonzeros
#        12	0.1420121143659358	Optimal
#         8	0.4061409261093429	Optimal
# Read LP format model from file /tmp/tmpaorrm0q4.lp
# Reading time = 0.01 seconds
# : 1066 rows, 2488 columns, 10416 nonzeros
#         7	0.0219535635734780	Not feasible
#        15	0.3897615095369433	Optimal
#        13	0.1423551387967714	Not feasible
#        13	0.3824722403816870	Not feasible
#         6	0.0439071271469560	Optimal
#         6	0.3073498900286920	Optimal
#         6	0.0439071271469560	Optimal
#        14	0.1421836265813536	Not feasible
#        16	0.3898043875907978	Optimal
#        10	0.1289771859941832	Not feasible
#         7	0.0658606907204340	Optimal
#         9	0.4116293170027124	Optimal
#        15	0.1420978704736447	Not feasible
#         5	0.0878142542939120	Optimal
#        14	0.3823007281662691	Optimal
#        17	0.3898258266177250	Not feasible
#         8	0.0768374725071730	Not feasible
#        16	0.1420549924197902	Optimal
#         3	0.3512570171756479	Not feasible
#         7	0.0658606907204340	Not feasible
#         6	0.1317213814408680	Optimal
#         9	0.0713490816138035	Not feasible
#         2	0.7025140343512959	Not feasible
#        18	0.3898151071042614	Optimal
#        17	0.1420764314467175	Optimal
#         4	0.1756285085878240	Optimal
#        10	0.0686048861671187	Not feasible
#        11	0.1276050882708409	Not feasible
#        15	0.3823864842739780	Not feasible
#         7	0.3293034536021699	Optimal
#         8	0.0548839089336950	Not feasible
#         2	0.7025140343512959	Not feasible
#         4	0.1756285085878240	Not feasible
#        11	0.0672327884437764	Optimal
#        18	0.1420871509601811	Optimal
#         6	0.0439071271469560	Optimal
#         7	0.1536749450143460	Not feasible
#        10	0.4143735124493972	Optimal
#        19	0.3898204668609932	Not feasible
#        12	0.0679188373054476	Optimal
#         5	0.2634427628817360	Not feasible
#        19	0.1420925107169129	Not feasible
#         9	0.0493955180403255	Not feasible
#        13	0.0682618617362832	Not feasible
#        14	0.0680903495208653	Not feasible
#        20	0.1420898308385470	Not feasible
#        16	0.3823436062201236	Optimal
#        20	0.3898177869826273	Not feasible
#        12	0.1269190394091697	Optimal
#         8	0.1426981632276070	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         6	0.2195356357347800	Optimal
#        15	0.0680045934131565	Not feasible
#         7	0.0658606907204340	Not feasible
#        21	0.1420884908993640	Not feasible
#        16	0.0679617153593020	Not feasible
#        11	0.4157456101727396	Optimal
#        10	0.0466513225936407	Optimal
#        21	0.3898164470434443	Optimal
#         7	0.2414891993082580	Not feasible
#        22	0.1420878209297726	Optimal
#        17	0.0679402763323748	Optimal
# Building (20 threads):   4%|▍         | 20/495 [04:43<2:08:48, 16.27s/it]
#         9	0.1481865541209765	Not feasible
#        17	0.3823650452470508	Optimal
#        18	0.0679509958458384	Optimal
#        13	0.1272620638400053	Optimal
#        11	0.0480234203169831	Not feasible
#         8	0.2305124175215190	Optimal
#        10	0.1454423586742917	Optimal
#        19	0.0679563556025702	Optimal
#        22	0.3898171170130358	Not feasible
# Building (20 threads):   4%|▍         | 21/495 [04:46<1:35:08, 12.04s/it]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpf085wlde.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpezq8jtpm.lp
# Reading time = 0.01 seconds
# : 1380 rows, 3496 columns, 15100 nonzeros
#        20	0.0679590354809361	Not feasible
#        12	0.0473373714553119	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmpny9md377.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp5pykixsy.lp
#         9	0.2360008084148885	OptimalReading time = 0.00 seconds
#
# : 935 rows, 2058 columns, 8700 nonzeros
# Read LP format model from file /tmp/tmp28c09abe.lp
# Reading time = 0.00 seconds
# : 960 rows, 2056 columns, 8580 nonzeros
# Read LP format model from file /tmp/tmpgolvuxse.lp
# Reading time = 0.01 seconds
# : 1405 rows, 3494 columns, 14930 nonzeros
#        21	0.0679576955417532	Optimal
#        13	0.0476803958861475	Optimal
#         3	0.3512570171756479	Not feasible
#        11	0.1468144563976341	Not feasible
#        18	0.3823757647605144	Not feasible
#         8	0.3402802353889089	Not feasible
#         8	0.0548839089336950	Optimal
#        22	0.0679583655113446	Not feasible
#        10	0.2387450038615732	Not feasible
# Building (20 threads):   4%|▍         | 22/495 [04:49<1:13:40,  9.35s/it]
#        14	0.0478519081015653	Not feasible
#        11	0.2373729061382308	Optimal
#        12	0.1461284075359629	Not feasible
#        15	0.0477661519938564	Not feasible       14	0.1274335760554230	Not feasible
#
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-03
# Read LP format model from file /tmp/tmp68qeinpr.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpp2383nbi.lp
# Reading time = 0.00 seconds
# : 996 rows, 2228 columns, 9454 nonzeros
#         4	0.1756285085878240	Not feasible
#        12	0.2380589549999020	Not feasible
#        12	0.4164316590344108	Not feasible
#        13	0.1457853831051273	Not feasible
#        16	0.0477232739400020	Optimal
# Read LP format model from file /tmp/tmpa002daok.lp
# Reading time = 0.01 seconds
# : 1021 rows, 2226 columns, 9334 nonzeros
#        13	0.2377159305690664	Optimal
#        19	0.3823704050037826	Optimal
#        14	0.1456138708897095	Optimal
#        17	0.0477447129669292	Not feasible
#        14	0.2378874427844842	Optimal
# ...
# : 1138 rows, 2634 columns, 11384 nonzeros
#        13	0.2384019794307376	Optimal
#        22	0.1461987543430678	Optimal
# Building (20 threads):  96%|█████████▌| 476/495 [1:15:54<02:23,  7.55s/it]
# Read LP format model from file /tmp/tmp0zczhxme.lp
# Reading time = 0.01 seconds
# : 1152 rows, 2632 columns, 11184 nonzeros
#         5	0.0878142542939120	Optimal
#        14	0.2385734916461554	Not feasible
#         6	0.4829783986165159	Not feasible
#        11	0.4047688283860006	Not feasible
#         7	0.1536749450143460	Not feasible
#         3	0.3512570171756479	Not feasible
#        15	0.2384877355384465	Optimal
#         6	0.1317213814408680	Optimal
#         2	0.7025140343512959	Not feasible
#         1	1.4050280687025918	Not feasible
#        16	0.2385306135923010	Optimal
#         2	0.7025140343512959	Not feasible
#         1	1.4050280687025918	Not feasible
#         7	0.1536749450143460	Optimal
#        12	0.4040827795243294	Not feasible       17	0.2385520526192282	Not feasible
#
#         3	0.3512570171756479	Optimal
#         8	0.1426981632276070	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         4	0.1756285085878240	Not feasible
#        18	0.2385413331057646	Optimal
#         5	0.0878142542939120	Optimal
#        12	0.4315247339911769	Optimal
#         8	0.1646517268010850	Optimal
#        19	0.2385466928624964	Not feasible
#         9	0.1481865541209765	Optimal
#         4	0.5268855257634719	Not feasible
#        20	0.2385440129841305	Not feasible
#         6	0.1317213814408680	Not feasible
#        13	0.4037397550934938	Not feasible
#        10	0.1509307495676612	Optimal
#        21	0.2385426730449475	Optimal
#         7	0.1097678178673900	Not feasible
#         9	0.1701401176944545	Not feasible
#         7	0.4610248350430379	Optimal
#         5	0.4390712714695599	Not feasible
#        22	0.2385433430145390	Optimal
# Building (20 threads):  96%|█████████▋| 477/495 [1:16:07<02:43,  9.07s/it]
#        11	0.1523028472910036	Optimal
#         8	0.0987910360806510	Optimal
#         6	0.3951641443226039	Not feasible
#        14	0.4035682428780760	Optimal
#        10	0.1673959222477697	Optimal
#        12	0.1529888961526748	Optimal
#         9	0.1042794269740205	Optimal
#        13	0.1533319205835104	Not feasible
#         2	0.7025140343512959	Not feasible
#        11	0.1687680199711121	Not feasible
#        10	0.1070236224207052	Optimal
#        13	0.4318677584220125	Not feasible
#         1	1.4050280687025918	Not feasible
#         8	0.4720016168297769	Optimal
#        14	0.1531604083680926	Not feasible
#         7	0.3732105807491259	Not feasible
#        11	0.1083957201440476	Not feasible
#        12	0.1680819711094409	Optimal
#        15	0.1530746522603837	Not feasible
#        15	0.4036539989857849	Optimal
#        13	0.1684249955402765	Not feasible
#        12	0.1077096712823764	Optimal
#        16	0.1530317742065292	Not feasible
#         4	0.1756285085878240	Not feasible
#         8	0.3622337989623869	Optimal
#        14	0.1682534833248587	Optimal
#        13	0.1080526957132120	Optimal
#        14	0.1082242079286298	Not feasible
#        17	0.1530103351796020	Optimal
#         9	0.3677221898557564	Optimal
#        15	0.1081384518209209	Not feasible
#        15	0.1683392394325676	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        18	0.1530210546930657	Not feasible
#        16	0.1080955737670665	Not feasible
#        19	0.1530156949363338	Optimal
#        16	0.4036968770396394	Not feasible
#        17	0.1080741347401392	Not feasible
#        16	0.1683821174864221	Optimal
#        18	0.1080634152266756	Not feasible
#        10	0.3704663853024412	Not feasible
#        20	0.1530183748146997	Optimal
#        19	0.1080580554699438	Not feasible
#        17	0.1684035565133493	Optimal
#        21	0.1530197147538827	Optimal
#        20	0.1080553755915779	Optimal
#        17	0.4036754380127121	Optimal
#        21	0.1080567155307609	Optimal
#        22	0.1530203847234742	Not feasible
#         2	0.7025140343512959	Not feasible
#        18	0.1684142760268129	Not feasible
# Building (20 threads):  97%|█████████▋| 478/495 [1:16:20<02:54, 10.24s/it]
#         9	0.4774900077231464	Optimal
#        11	0.3690942875790988	Not feasible
#         2	0.7025140343512959	Not feasible
#        14	0.4316962462065946	Not feasible
#        22	0.1080573855003523	Not feasible
# Building (20 threads):  97%|█████████▋| 479/495 [1:16:21<01:59,  7.49s/it]
#         3	0.3512570171756479	Not feasible
#        19	0.1684089162700811	Not feasible
#        12	0.3684082387174276	Optimal
#        18	0.4036861575261758	Optimal
#        20	0.1684062363917152	Optimal
#         3	0.3512570171756479	Not feasible
#        21	0.1684075763308981	Optimal
#        10	0.4802342031698312	Not feasible
#        13	0.3687512631482632	Not feasible
#        19	0.4036915172829075	Optimal
#         3	0.3512570171756479	Not feasible
#        22	0.1684082463004896	Optimal
# Building (20 threads):  97%|█████████▋| 480/495 [1:16:26<01:41,  6.77s/it]
#         5	0.0878142542939120	Optimal
#        20	0.4036941971612734	Optimal
#        11	0.4788621054464888	Optimal
#         2	0.7025140343512959	Not feasible
#        14	0.3685797509328455	Not feasible
#        15	0.4316104900988857	Optimal
#         6	0.1317213814408680	Optimal
#        12	0.4795481543081600	Optimal
#        21	0.4036955371004564	Optimal
#        15	0.3684939948251366	Not feasible
#         5	0.0878142542939120	Not feasible
#         1	1.4050280687025918	Not feasible
#        13	0.4798911787389956	Not feasible
#        16	0.3684511167712821	Not feasible
#         7	0.1536749450143460	Not feasible
#        22	0.4036962070700478	Not feasible
# Building (20 threads):  97%|█████████▋| 481/495 [1:16:37<01:50,  7.91s/it]
#         4	0.1756285085878240	Optimal
#        17	0.3684296777443549	Optimal
#        14	0.4797196665235778	Not feasible
#         3	0.3512570171756479	Not feasible
#        16	0.4316533681527402	Optimal
#        18	0.3684403972578185	Optimal
#        15	0.4796339104158689	Optimal
#         4	0.1756285085878240	Not feasible
#         5	0.2634427628817360	Optimal
#        19	0.3684457570145503	Optimal
#        16	0.4796767884697233	Optimal
#         3	0.3512570171756479	Not feasible
#         8	0.1426981632276070	Optimal
#         4	0.1756285085878240	Optimal
#         6	0.3073498900286920	Optimal
#        17	0.4796982274966506	Not feasible
#        20	0.3684484368929162	Not feasible
#        17	0.4316748071796674	Optimal
#         1	1.4050280687025918	Not feasible
#         5	0.2634427628817360	Optimal
#        18	0.4796875079831869	Not feasible
#         9	0.1481865541209765	Optimal
#         7	0.3293034536021699	Not feasible
#        21	0.3684470969537332	Not feasible
#         2	0.7025140343512959	Not feasible
#        19	0.4796821482264552	Not feasible
#         4	0.1756285085878240	Not feasible
#         6	0.0439071271469560	Optimal
#         6	0.3073498900286920	Not feasible
#         8	0.3183266718154310	Not feasible
#        22	0.3684464269841418	Not feasible
# Building (20 threads):  97%|█████████▋| 482/495 [1:16:53<02:14, 10.35s/it]
#         1	1.4050280687025918	Not feasible
#        10	0.1509307495676612	Not feasible
#        20	0.4796794683480893	Not feasible
#         7	0.0658606907204340	Optimal
#         5	0.0878142542939120	Not feasible
#        11	0.1495586518443189	Optimal
#         4	0.1756285085878240	Not feasible
#         7	0.2853963264552140	Optimal
#         8	0.0768374725071730	Not feasible
#         9	0.3128382809220615	Optimal
#        18	0.4316855266931310	Not feasible
#        21	0.4796781284089063	Not feasible
#         9	0.0713490816138035	Optimal
#        12	0.1502447007059901	Optimal
#        10	0.3155824763687462	Not feasible
#         8	0.2963731082419530	Optimal
#        22	0.4796774584393149	Not feasible
# Building (20 threads):  98%|█████████▊| 483/495 [1:17:01<01:54,  9.56s/it]
#         3	0.3512570171756479	Not feasible
#        13	0.1505877251368256	Not feasible
#        11	0.3142103786454038	Optimal
#        10	0.0740932770604882	Not feasible
#         9	0.3018614991353225	Optimal
#        12	0.3148964275070750	Not feasible
#         3	0.3512570171756479	Optimal
#        14	0.1504162129214078	Not feasible
#         2	0.7025140343512959	Not feasible
#        19	0.4316801669363992	Not feasible
#        13	0.3145534030762394	Not feasible
#        10	0.3046056945820072	Not feasible
#        15	0.1503304568136989	Optimal
#         5	0.0878142542939120	Optimal
#        14	0.3143818908608216	Optimal
#        11	0.3032335968586648	Optimal
#        15	0.3144676469685305	Optimal
#        16	0.1503733348675534	Not feasible
#         6	0.0439071271469560	Optimal
#        12	0.3039196457203360	Optimal
#        16	0.3145105250223850	Not feasible
#         6	0.1317213814408680	Not feasible
#         5	0.0878142542939120	Not feasible
#         7	0.0658606907204340	Optimal
#         4	0.5268855257634719	Optimal
#        17	0.1503518958406262	Not feasible
#        17	0.3144890859954577	Not feasible
#        13	0.3042626701511716	Optimal
#        20	0.4316774870580333	Optimal
#         7	0.1097678178673900	Not feasible
#        18	0.3144783664819941	Not feasible
#        11	0.0727211793371459	Not feasible
#        14	0.3044341823665894	Not feasible
#        18	0.1503411763271625	Not feasible
#         4	0.1756285085878240	Not feasible
#        19	0.3144730067252623	Optimal
#        12	0.0720351304754747	Not feasible
#         8	0.0768374725071730	Not feasible
#         2	0.7025140343512959	Not feasible
#        15	0.3043484262588805	Optimal
#         8	0.0987910360806510	Optimal
#        19	0.1503358165704307	Not feasible
#        20	0.3144756866036282	Not feasible
#        13	0.0716921060446391	Optimal
#         9	0.0713490816138035	Not feasible
#        21	0.3144743466644453	Optimal
#        16	0.3043913043127349	Not feasible
#        14	0.0718636182600569	Not feasible
#         9	0.1042794269740205	Not feasible
#        20	0.1503331366920648	Optimal
#        21	0.4316788269972163	Optimal
#        22	0.3144750166340368	Not feasible
#        10	0.0686048861671187	Optimal
# Building (20 threads):  98%|█████████▊| 484/495 [1:17:19<02:14, 12.26s/it]
#         5	0.6146997800573839	Not feasible
#        15	0.0717778621523480	Not feasible
#        17	0.3043698652858077	Not feasible
#        10	0.1015352315273357	Optimal
#        16	0.0717349840984935	Optimal
#        21	0.1503344766312478	Optimal
#        11	0.0699769838904611	Not feasible
#        18	0.3043591457723441	Not feasible
#        11	0.1029073292506781	Not feasible
#        17	0.0717564231254207	Optimal
#        12	0.0692909350287899	Optimal
#        19	0.3043537860156122	Optimal
#        22	0.1503351466008392	Optimal
# Building (20 threads):  98%|█████████▊| 485/495 [1:17:24<01:39,  9.92s/it]
#        18	0.0717671426388844	Not feasible
#        13	0.0696339594596255	Not feasible
#        12	0.1022212803890069	Optimal
#         3	0.3512570171756479	Not feasible
#         6	0.0439071271469560	Optimal
#        20	0.3043564658939781	Not feasible
#        19	0.0717617828821526	Optimal
#        14	0.0694624472442077	Optimal
#        13	0.1025643048198425	Optimal
#        22	0.4316794969668077	Optimal
#         5	0.0878142542939120	Optimal
# Building (20 threads):  98%|█████████▊| 486/495 [1:17:26<01:10,  7.81s/it]
#         7	0.0658606907204340	Optimal
#        15	0.0695482033519166	Optimal
#        20	0.0717644627605185	Not feasible
#        21	0.3043551259547952	Not feasible
#         6	0.5707926529104279	Not feasible
#         6	0.1317213814408680	Optimal
#        14	0.1027358170352603	Not feasible
#         8	0.0768374725071730	Optimal
#        16	0.0695910814057711	Optimal
#        21	0.0717631228213355	Not feasible
#        22	0.3043544559852037	Not feasible
# Building (20 threads):  98%|█████████▊| 487/495 [1:17:29<00:50,  6.26s/it]
#        22	0.0717624528517440	Not feasible
#        15	0.1026500609275514	Optimal
#        17	0.0696125204326983	Optimal
# Building (20 threads):  99%|█████████▊| 488/495 [1:17:30<00:32,  4.62s/it]
#         9	0.0823258634005425	Optimal
#         7	0.1536749450143460	Not feasible
#        18	0.0696232399461619	Not feasible
#        16	0.1026929389814059	Not feasible
#        10	0.0850700588472272	Optimal
#        19	0.0696178801894301	Optimal
#         8	0.1426981632276070	Optimal
#        17	0.1026714999544786	Not feasible
#        20	0.0696205600677960	Optimal
#         7	0.5488390893369499	Optimal
#        18	0.1026607804410150	Optimal
#         9	0.1481865541209765	Not feasible
#        11	0.0864421565705696	Not feasible
#        21	0.0696219000069790	Optimal
#        10	0.1454423586742917	Optimal
#        12	0.0857561077088984	Not feasible
#        19	0.1026661401977468	Optimal
#        22	0.0696225699765704	Not feasible
# Building (20 threads):  99%|█████████▉| 489/495 [1:17:38<00:34,  5.74s/it]
#        13	0.0854130832780628	Optimal
#        11	0.1468144563976341	Not feasible
#        20	0.1026688200761127	Not feasible
#        14	0.0855845954934806	Optimal
#         3	0.3512570171756479	Not feasible
#        12	0.1461284075359629	Optimal
#         8	0.5598158711236889	Not feasible
#        15	0.0856703516011895	Not feasible
#        21	0.1026674801369298	Not feasible
#        16	0.0856274735473351	Not feasible
#        13	0.1464714319667985	Optimal
#         9	0.5543274802303194	Optimal
#        17	0.0856060345204079	Not feasible
#        22	0.1026668101673383	Optimal
# Building (20 threads):  99%|█████████▉| 490/495 [1:17:43<00:27,  5.50s/it]
#        18	0.0855953150069442	Optimal
#        14	0.1466429441822163	Optimal
#        19	0.0856006747636761	Optimal
#        15	0.1467287002899252	Optimal
#        20	0.0856033546420420	Optimal
#        10	0.5570716756770042	Not feasible
#         4	0.1756285085878240	Not feasible
#        21	0.0856046945812249	Optimal
#        16	0.1467715783437796	Optimal
#        22	0.0856053645508164	Optimal
# Building (20 threads):  99%|█████████▉| 491/495 [1:17:48<00:20,  5.18s/it]
#        11	0.5556995779536618	Optimal
#        17	0.1467930173707069	Not feasible
#        18	0.1467822978572433	Optimal
#        12	0.5563856268153330	Not feasible
#        19	0.1467876576139751	Not feasible
#        20	0.1467849777356092	Optimal
#        13	0.5560426023844973	Optimal
#        21	0.1467863176747921	Not feasible
#        22	0.1467856477052006	Optimal
# Building (20 threads):  99%|█████████▉| 492/495 [1:17:57<00:19,  6.38s/it]
#        14	0.5562141145999151	Optimal
#        15	0.5562998707076241	Not feasible
#         4	0.1756285085878240	Optimal
#         5	0.0878142542939120	Optimal
#        16	0.5562569926537696	Not feasible
#         5	0.2634427628817360	Optimal
#         6	0.1317213814408680	Optimal
#        17	0.5562355536268424	Not feasible
#         6	0.3073498900286920	Not feasible
#        18	0.5562248341133788	Optimal
#         7	0.1536749450143460	Not feasible
#         7	0.2853963264552140	Optimal
#        19	0.5562301938701106	Optimal
#         8	0.1426981632276070	Not feasible
#         8	0.2963731082419530	Optimal
#        20	0.5562328737484765	Not feasible
#         9	0.3018614991353225	Optimal
#         9	0.1372097723342375	Optimal
#        21	0.5562315338092936	Not feasible
#        10	0.3046056945820072	Not feasible
#        10	0.1399539677809222	Optimal
#        22	0.5562308638397021	Not feasible
#        11	0.3032335968586648	Not feasible
# Building (20 threads): 100%|█████████▉| 493/495 [1:18:28<00:27, 13.82s/it]
#        12	0.3025475479969936	Optimal
#        11	0.1413260655042646	Optimal
#        13	0.3028905724278292	Not feasible
#        12	0.1420121143659358	Not feasible
#        14	0.3027190602124115	Not feasible
#        13	0.1416690899351002	Optimal
#        15	0.3026333041047026	Not feasible
#        14	0.1418406021505180	Not feasible
#        16	0.3025904260508481	Optimal
#        15	0.1417548460428091	Optimal
#        17	0.3026118650777753	Not feasible
#        16	0.1417977240966635	Not feasible
#        18	0.3026011455643117	Optimal
#        17	0.1417762850697363	Not feasible
#        19	0.3026065053210435	Not feasible
#        18	0.1417655655562727	Not feasible
#        20	0.3026038254426776	Not feasible
#        19	0.1417602057995409	Optimal
#        21	0.3026024855034947	Not feasible
#        20	0.1417628856779068	Optimal
#        22	0.3026018155339032	Not feasible
# Building (20 threads): 100%|█████████▉| 494/495 [1:18:50<00:16, 16.39s/it]
#        21	0.1417642256170897	Not feasible
#        22	0.1417635556474983	Not feasible
# Building (20 threads): 100%|██████████| 495/495 [1:18:53<00:00, 12.41s/it]
