# %%
import glob
import numpy
import pandas
import seaborn
import matplotlib.pyplot as plt
from tqdm import tqdm
import multiprocessing as mp
import os
from build import build_model
import coralme
plt.rcParams['svg.fonttype'] = 'none'

# %%
from IPython.display import display, HTML, Math, Markdown
display(HTML("<style>.container { width:95% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:95% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
growth = pandas.read_csv("./datasets/all_growth_rates.csv",index_col=0)
taxonomy = pandas.read_csv("./taxonomy.txt",index_col=0,sep='\t')
taxonomy = taxonomy[taxonomy["Kingdom"]=="Bacteria"]
growth = growth.loc[[i for i in taxonomy.index]]

# %%
(growth["low_iron"]/growth["base"]).sort_values().dropna()
# Out:
# Cronobacter_sakazakii_ATCC_BAA_894         0.008
# Methylobacterium_radiotolerans_JCM_2831    0.010
# Lactobacillus_sakei_subsp_sakei_23K        0.010
# Lactobacillus_rhamnosus_GG_ATCC_53103      0.010
# Lactobacillus_gasseri_ATCC_33323           0.010
#                                             ...
# Corynebacterium_tuberculostearicum_SK141   1.000
# Brevibacterium_casei_S18                   1.000
# Prevotella_bivia_DSM_20514                 1.000
# Acinetobacter_pittii_ANC_4052              1.000
# Bifidobacterium_bifidum_BGN4               1.000
# Length: 490, dtype: float64

# %% [markdown]
# ### Get ranks

# %%
rank = pandas.DataFrame()
for col in growth.columns:
    tmp = growth[col].sort_values()
    rank[col] = tmp.rank()
rank = rank.fillna(rank.shape[0])

# %%
df = pandas.concat([rank,taxonomy],axis=1)

# %% [markdown]
# ### Mann-Whitney test

# %%
TAXA = "Genus"

# %%
from scipy.stats import mannwhitneyu
def mannwhitney(taxa, col,alt="greater"):
    taxa_df = df[df[TAXA] == taxa]
    y = taxa_df["base"].values
    x = taxa_df[col].values
    return mannwhitneyu(x,y , method="exact", alternative=alt)

# %% [markdown]
# ### Mann-Whitney test for advantaged

# %%
dct = {}
for col in growth.drop("base",axis=1).columns:
    dct[col] = {}
    for taxa in df[TAXA].unique():
        U1, p = mannwhitney(taxa,col,alt="greater")
        dct[col][taxa] = p
adv = pandas.DataFrame.from_dict(dct)

# %%
pandas.options.display.float_format = '{:,.3f}'.format

# %%
import seaborn as sns
cmap_df = adv.copy()
cmap_df = cmap_df[(cmap_df<0.1).any(axis=1)] # Only significant
cmap_df = -numpy.log10(cmap_df)
cmap = plt.cm.get_cmap('Reds').copy()
cmap.set_under('white')
vmin,vmax = (1.0,2)
cmap = sns.clustermap(cmap_df,
               row_cluster=True,
               col_cluster=False,
               vmin=vmin,
               vmax=vmax,
               annot=True,
               fmt=".1f",
               cmap=cmap,
               # annot_kws={'rotation': 90}
               figsize=(1.0*cmap_df.shape[1],(0.3)*cmap_df.shape[0]),
               # cbar=False,
              )
labels = [i.get_text() for i in cmap.ax_heatmap.yaxis.get_majorticklabels()]
# Out:
# /tmp/ipykernel_3828676/2185867131.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Reds').copy()

# %%
labels = pandas.Series({i:i.replace("unclassified ","") for i in labels}).sort_values().index

# %%
import seaborn as sns
fig,ax = plt.subplots(1,1, figsize=(1.0*cmap_df.shape[1],(0.3)*cmap_df.shape[0]))
cmap = plt.cm.get_cmap('Reds').copy()
# cmap.set_under('white')
cmap = sns.heatmap(cmap_df.loc[labels],
               vmin=vmin,
               vmax=vmax,
               annot=True,
               fmt=".1f",
               cmap=cmap,
               # annot_kws={'rotation': 90}
               # cbar=False,
              )
# cmap.ax_heatmap.set_xticklabels(cmap.ax_heatmap.get_xticklabels(), rotation=90)
# _=plt.setp(cmap.ax_heatmap.get_xticklabels(), rotation=80)

plt.savefig("./figures/2.3.3.MW-heatmap-greater.svg",format="SVG")
# Out:
# /tmp/ipykernel_3828676/1407705440.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Reds').copy()

# %% [markdown]
# ### Mann-Whitney test for disadvantaged

# %%
dct = {}
for col in growth.drop("base",axis=1).columns:
    dct[col] = {}
    for taxa in df[TAXA].unique():
        U1, p = mannwhitney(taxa,col,alt="less")
        dct[col][taxa] = p
dadv = pandas.DataFrame.from_dict(dct)

# %%
import seaborn as sns
cmap_df = dadv.copy()
cmap_df = cmap_df[(cmap_df<0.1).any(axis=1)] # Only significant
cmap_df = -numpy.log10(cmap_df)
cmap = plt.cm.get_cmap('Blues').copy()
cmap.set_under('white')
vmin,vmax = (1.0,2)
cmap = sns.clustermap(cmap_df,
               row_cluster=True,
               col_cluster=False,
               vmin=vmin,
               vmax=vmax,
               annot=True,
               fmt=".1f",
               cmap=cmap,
               # annot_kws={'rotation': 90}
               figsize=(1.0*cmap_df.shape[1],(0.3)*cmap_df.shape[0]),
               # cbar=False,
              )
labels = [i.get_text() for i in cmap.ax_heatmap.yaxis.get_majorticklabels()]
# Out:
# /tmp/ipykernel_3828676/2834304706.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Blues').copy()

# %%
labels = pandas.Series({i:i.replace("unclassified ","") for i in labels}).sort_values().index

# %%
import seaborn as sns
fig,ax = plt.subplots(1,1, figsize=(1.0*cmap_df.shape[1],(0.3)*cmap_df.shape[0]))
cmap = plt.cm.get_cmap('Blues').copy()
# cmap.set_under('white')
cmap = sns.heatmap(cmap_df.loc[labels],
               vmin=vmin,
               vmax=vmax,
               annot=True,
               fmt=".1f",
               cmap=cmap,
               # annot_kws={'rotation': 90}
               # cbar=False,
              )
# cmap.ax_heatmap.set_xticklabels(cmap.ax_heatmap.get_xticklabels(), rotation=90)
# _=plt.setp(cmap.ax_heatmap.get_xticklabels(), rotation=80)

plt.savefig("./figures/2.3.3.MW-heatmap-less.svg",format="SVG")
# Out:
# /tmp/ipykernel_3828676/630000351.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Blues').copy()

# %%
dadv[dadv["low_iron"] < 0.05].sort_index()
# Out:
#                 low_iron  low_zinc  high-1.5_lipid  high_carbs  high_prot  \
# Bacillus           0.000     1.000           0.439       0.561      0.561
# Lactobacillus      0.019     1.000           0.779       0.959      0.080
# Listeria           0.001     1.000           0.962       1.000      0.001
# Paenibacillus      0.014     0.900           0.657       0.829      0.557
# Staphylococcus     0.000     1.000           0.675       0.879      0.195
#
#                 micro_oxygen
# Bacillus               0.520
# Lactobacillus          0.287
# Listeria               0.860
# Paenibacillus          0.829
# Staphylococcus         0.711

# %%
numpy.log10(adv.loc["Bacillus"])
# Out:
# low_iron         -0.000
# low_zinc         -4.110
# high-1.5_lipid   -0.221
# high_carbs       -0.319
# high_prot        -0.319
# micro_oxygen     -0.284
# Name: Bacillus, dtype: float64

# %% [markdown]
# ### Save

# %%
adv.to_csv("./datasets/2.3.3.MW-greater.csv")
dadv.to_csv("./datasets/2.3.3.MW-less.csv")
