# %%
import glob
import numpy
import pandas
import seaborn
import matplotlib.pyplot as plt
from tqdm import tqdm
import multiprocessing as mp
import os
from build import build_model
import coralme

# %%
from IPython.display import display, HTML, Math, Markdown
display(HTML("<style>.container { width:95% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# !bash report.sh
organisms = set(pandas.read_csv("biomass_constrained.txt",index_col=0,header=None).index.to_list())
done = set(i.split(".csv")[0] for i in os.listdir("./cases/m/fluxes/IBD/") if "csv" in i)

# %%
len(done)
# Out:
# 495

# %% [markdown]
# ### Load

# %%
def load_data(path):
    try:
        df = pandas.read_csv(path,index_col=0)[["fluxes"]]
    except:
        df = pandas.DataFrame(columns=["fluxes"])
    df.columns = [org]
    return df

# %%
from tqdm import tqdm
conditions = ["nonIBD", "IBD"]

# %%
overflow = {i:pandas.DataFrame() for i in conditions}
growth = {i:{} for i in conditions}

# %%
# for org in tqdm(organisms):
#     for c in conditions:
#         tmp = load_data("./cases/overflow/{}/{}.csv".format(c,org))
#         overflow[c] = pandas.concat([overflow[c],tmp], axis=1).fillna(0)

# %%
for org in tqdm(organisms):
    for c in conditions:
        tmp = load_data("./cases/m/fluxes/{}/{}.csv".format(c,org))
        if tmp.empty:
            val = None
        else:
            val = tmp[org]["EX_biomass(e)"]
        growth[c][org] = val
growth = pandas.DataFrame.from_dict(growth)
# Out:
#   0%|          | 0/495 [00:00<?, ?it/s]
# 100%|██████████| 495/495 [00:00<00:00, 610.93it/s]

# %% [markdown]
# ### Save

# %%
growth.sort_index().to_csv("datasets/3.M_IBD_growth_rates.csv")

# %%
for c,df in overflow.items():
    df.to_csv("datasets/3.M_{}_overflow.csv".format(c))

# %%
growth = pandas.read_csv("datasets/3.M_IBD_growth_rates.csv",index_col=0)
growth
# Out:
#                                                    nonIBD       IBD
# Abiotrophia_defectiva_ATCC_49176                      0.0  0.004042
# Acidaminococcus_fermentans_DSM_20731                  0.0  0.005762
# Acidaminococcus_intestini_RyC_MR95                    0.0  0.061933
# Acidaminococcus_sp_D21                                0.0  0.080445
# Acinetobacter_calcoaceticus_PHEA_2                    0.0  0.001320
# ...                                                   ...       ...
# Yersinia_enterocolitica_subsp_enterocolitica_8081     0.0  0.002181
# Yersinia_frederiksenii_ATCC_33641                     0.0  0.004349
# Yersinia_kristensenii_ATCC_33638                      0.0  0.003647
# Yersinia_pseudotuberculosis_YPIII                     0.0  0.002594
# Yersinia_rohdei_ATCC_43380                            0.0  0.002785
#
# [495 rows x 2 columns]
