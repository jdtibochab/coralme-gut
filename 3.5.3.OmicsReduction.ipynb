# %%
from knockouts import *

# %%
from IPython.display import display, HTML, Math, Markdown
display(HTML("<style>.container { width:95% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2
# Out:
# <style>.container { width:95% !important; }</style>

# %%
condition = "nonIBD"
# condition = "IBD"
fluxdir = "./cases/fluxes/{}red".format(condition)
overflowdir = "./cases/overflow/{}red".format(condition)
if not os.path.isdir(fluxdir):
    os.makedirs(fluxdir)
if not os.path.isdir(overflowdir):
    os.makedirs(overflowdir)

# %%
log_format = '%(asctime)s %(message)s' #%(clientip)-15s %(user)-8s
import logging
from coralme.builder.main import ListHandler
log = logging.getLogger()
logging.basicConfig(filename = "./ibdmdb/reduction/solving_{}.log".format(condition), filemode = 'w', level = logging.WARNING, format = log_format)
logging.captureWarnings(True)

# %%
from overflow import get_overflow
def run(org):
    ListHandler.print_and_log("Loading {}".format(org))
    model = coralme.io.pickle.load_pickle_me_model("./me-models/{}/MEModel-BIO-{}-ME-TS.pkl".format(org,org))
    index_dct = {r.id : model.reactions.index(r) for r in model.reactions}
    met_index_dct = {m.id : model.metabolites.index(m) for m in model.metabolites}
    me_nlp = get_nlp(model)
    max_mu = model.solution.objective_value*2
    
    del model
    # Run for all conditions
    killable = pandas.read_csv("./ibdmdb/reduction/{}/{}_killable.txt".format(condition,org),header=None,index_col=0).index.to_list()
    for k in killable:
        knockout(index_dct,k,me_nlp,limit=lambda x:2.1917479162633475e-13)
    sol = optimize(index_dct,met_index_dct,me_nlp,max_mu=max_mu)
    # sol = model.solution.fluxes["biomass_dilution"] if hasattr(model,"solution") else "infeasible"
    ListHandler.print_and_log("Solution for {} : {}".format(org, sol))
    sol.to_frame().to_csv("cases/fluxes/{}red/{}.csv".format(condition,org))
    # get_overflow(model).to_csv("./cases/overflow/{}/{}.csv".format(condition,org))

# %%
survivors = set(pandas.read_csv("survivors.txt",index_col=0,header=None).index.to_list())
processed = set(i.split("_killable")[0] for i in os.listdir("./ibdmdb/reduction/{}".format(condition)) if "txt" in i)
done = set(i.split(".csv")[0] for i in os.listdir("./cases/fluxes/{}red/".format(condition)) if "csv" in i)
run_for = processed - done
len(run_for)
# Out:
# 495

# %%
NP = min([14,len(run_for)])
pool = mp.Pool(NP,maxtasksperchild=1)
pbar = tqdm(total=len(run_for),position=0,leave=True)
pbar.set_description('Building ({} threads)'.format(NP))
def collect_result(result):
    pbar.update(1)
        
for org in run_for:
    args = ([org])
    pool.apply_async(run,args, callback=collect_result)
pool.close()
pool.join()
# Out:
# Building (14 threads):   0%|          | 0/495 [00:00<?, ?it/s]
# Loading Clostridium_botulinum_A_str_ATCC_19397Loading Filifactor_alocis_ATCC_35896Loading Marvinbryantia_formatexigens_I_52_DSM_14469Loading Faecalibacterium_prausnitzii_M21_2Loading Actinomyces_viscosus_C505Loading Eubacterium_rectale_ATCC_33656Loading Bacteroides_sp_1_1_30Loading Enterobacter_asburiae_LF7aLoading Afipia_birgiae_34632Loading Escherichia_sp_4_1_40BLoading Arcobacter_butzleri_RM4018Loading Eubacterium_dolichum_DSM_3991Loading Listeria_monocytogenes_4a_L99Loading Lactobacillus_paracasei_subsp_paracasei_ATCC_25302
#
#
#
#
#
#
#
#
#
#
#
#
#
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpezvdki5g.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp69w85cih.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp6ior3uge.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp4uesyu8y.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpve7egml1.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmprkk7dhxi.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmphtp812b3.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpvs_pgvr9.lp
# Reading time = 0.00 seconds
# : 985 rows, 2180 columns, 9284 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpy1nk58an.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpo78figl8.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpdtoe0hys.lp
# Reading time = 0.00 seconds
# : 1081 rows, 2506 columns, 10714 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp8hj6mrze.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp09346v4h.lp
# Reading time = 0.00 seconds
# : 1010 rows, 2178 columns, 9164 nonzeros
# Read LP format model from file /tmp/tmp8lvbkyqg.lp
# Reading time = 0.00 seconds
# : 768 rows, 1556 columns, 6634 nonzeros
# Read LP format model from file /tmp/tmpyddajxw5.lp
# Reading time = 0.00 seconds
# : 1096 rows, 2504 columns, 10514 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp9n_ayobn.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp6rhcmn3z.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpn43uzpaj.lp
# Reading time = 0.00 seconds
# : 990 rows, 2162 columns, 9732 nonzeros
# Read LP format model from file /tmp/tmpj2pky9gg.lp
# Reading time = 0.00 seconds
# : 769 rows, 1554 columns, 6514 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpgejeoeuq.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmponsdr53t.lp
# Reading time = 0.00 seconds
# : 1012 rows, 2160 columns, 9562 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp4x6shsh_.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmpt0mo_16s.lp
# Reading time = 0.00 seconds
# : 933 rows, 2030 columns, 8942 nonzeros
#         1	0.2203489788188315	Not feasible
# Read LP format model from file /tmp/tmp46jgggch.lp
# Reading time = 0.00 seconds
# : 1330 rows, 3536 columns, 14976 nonzeros
# Read LP format model from file /tmp/tmpy9t7ilce.lp
# Reading time = 0.00 seconds
# : 1065 rows, 2476 columns, 10534 nonzeros
#         2	0.1101744894094158	Not feasible
# Read LP format model from file /tmp/tmp1_jtkhev.lp
# Reading time = 0.00 seconds
# : 1090 rows, 2590 columns, 11210 nonzeros
#         1	0.0032305933700962	Not feasible
# Read LP format model from file /tmp/tmptack5f25.lp
# Reading time = 0.00 seconds
# : 944 rows, 2028 columns, 8742 nonzeros
# Read LP format model from file /tmp/tmp8rtj95pm.lp
# Reading time = 0.00 seconds
# : 1087 rows, 2468 columns, 10670 nonzeros
#         1	0.5358517288061920	Not feasible
# Read LP format model from file /tmp/tmp_1e832_c.lp
# Reading time = 0.01 seconds
# : 1369 rows, 3534 columns, 14854 nonzeros
#         1	0.1420248437881738	Not feasible
#         3	0.0550872447047079	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmp3vrcy7u0.lp
# Reading time = 0.00 seconds
# : 982 rows, 2176 columns, 9220 nonzeros
#         4	0.0275436223523539	Not feasible
#         2	0.2679258644030960	Not feasible
#         2	0.0016152966850481	Not feasible
# Read LP format model from file /tmp/tmplmsmj8yf.lp
# Reading time = 0.01 seconds
# : 1257 rows, 2964 columns, 13012 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmp3t_ketvb.lp
# Reading time = 0.01 seconds
# : 1219 rows, 2870 columns, 12436 nonzeros
#         5	0.0137718111761770	Not feasible
#         1	0.0844476570967463	Not feasible
#         2	0.0710124218940869	Not feasible
#         3	0.1339629322015480	Not feasible
#         3	0.0008076483425240	Optimal
#         6	0.0068859055880885	Not feasible
#         4	0.0012114725137861	Not feasible
#         2	0.0422238285483731	Not feasible
#         5	0.0010095604281550	Not feasible
# Read LP format model from file /tmp/tmp3k1019t2.lp
# Reading time = 0.00 seconds
# : 1088 rows, 2474 columns, 10334 nonzeros
#         6	0.0009086043853395	Optimal
#         7	0.0009590824067473	Optimal
#         8	0.0009843214174512	Optimal
# Read LP format model from file /tmp/tmps5yzsns5.lp
# Reading time = 0.00 seconds
# : 1115 rows, 2588 columns, 11010 nonzeros
# Read LP format model from file /tmp/tmp57yzudsy.lp
# Reading time = 0.00 seconds
# : 1088 rows, 2466 columns, 10500 nonzeros
#         4	0.0669814661007740	Not feasible
#         7	0.0034429527940442	Not feasible
#         9	0.0009969409228031	Optimal
#         3	0.0211119142741866	Not feasible
#         3	0.0355062109470435	Not feasible
#        10	0.0010032506754791	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        11	0.0010064055518171	Not feasible
# Read LP format model from file /tmp/tmplsc7rx6o.lp
# Reading time = 0.01 seconds
# : 1423 rows, 3624 columns, 15602 nonzeros
#        12	0.0010048281136481	Not feasible
#         4	0.0105559571370933	Not feasible
#         8	0.0017214763970221	Not feasible
#        13	0.0010040393945636	Not feasible
# Solution for Arcobacter_butzleri_RM4018 : <Solution 0.001 at 0x7f213e347bb0>
# Building (14 threads):   0%|          | 1/495 [01:57<16:05:41, 117.29s/it]
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Loading Citrobacter_sp_30_2
#         5	0.0334907330503870	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmplfzx_d6t.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpa00_0row.lp
# Reading time = 0.00 seconds
# : 1348 rows, 3566 columns, 15180 nonzeros
# Read LP format model from file /tmp/tmp8w_186e3.lp
# Reading time = 0.00 seconds
# : 1387 rows, 3564 columns, 15060 nonzeros
# Read LP format model from file /tmp/tmpv55frhgy.lp
# Reading time = 0.00 seconds
# : 1005 rows, 2174 columns, 9098 nonzeros
#         4	0.0177531054735217	Not feasible
#         9	0.0008607381985111	Optimal
#        10	0.0012911072977666	Not feasible
#        11	0.0010759227481388	Not feasible
#         5	0.0052779785685466	Not feasible
#        12	0.0009683304733249	Optimal
# Read LP format model from file /tmp/tmpib_nr8fk.lp
# Reading time = 0.01 seconds
# : 1270 rows, 2962 columns, 12842 nonzeros
#        13	0.0010221266107319	Optimal
#        14	0.0010490246794354	Optimal
#         1	0.3017784229059794	Not feasible
#         6	0.0167453665251935	Not feasible
# Read LP format model from file /tmp/tmpu_89dz9n.lp
# Reading time = 0.01 seconds
# : 1234 rows, 2868 columns, 12236 nonzeros
#        15	0.0010624737137871	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        16	0.0010557491966112	Not feasible
#        17	0.0010523869380233	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        18	0.0010507058087293	Not feasible
#        19	0.0010498652440823	Not feasible
# Solution for Eubacterium_dolichum_DSM_3991 : <Solution 0.001 at 0x7f21267a0940>
# Building (14 threads):   0%|          | 2/495 [02:24<8:49:48, 64.48s/it]
# Loading Porphyromonas_somerae_DSM_23386
# Read LP format model from file /tmp/tmpvve4ua99.lp
# Reading time = 0.00 seconds
# : 945 rows, 2030 columns, 8674 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmps0a6iu5n.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         5	0.0088765527367609	Not feasible
# Read LP format model from file /tmp/tmpoz36wb_j.lp
# Reading time = 0.01 seconds
# : 1450 rows, 3622 columns, 15432 nonzeros
#         6	0.0026389892842733	Not feasible
#         2	0.1508892114529897	Not feasible
# Read LP format model from file /tmp/tmpsw8d9k6v.lp
# Reading time = 0.00 seconds
# : 964 rows, 2084 columns, 8952 nonzeros
#         7	0.0083726832625968	Not feasible
#         1	0.2335969575206734	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmp7371vv45.lp
# Reading time = 0.00 seconds
# : 968 rows, 2028 columns, 8554 nonzeros
# Read LP format model from file /tmp/tmpmavi2w46.lp
# Reading time = 0.00 seconds
# : 982 rows, 2082 columns, 8782 nonzeros
#         6	0.0044382763683804	Not feasible
#         1	0.1809963049547278	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         7	0.0013194946421367	Not feasible
#         3	0.0754446057264949	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         8	0.0041863416312984	Optimal
#         9	0.0062795124469476	Optimal
#        10	0.0073260978547722	Optimal
#         7	0.0022191381841902	Not feasible
#         2	0.1167984787603367	Not feasible
#        11	0.0078493905586845	Not feasible
#        12	0.0075877442067283	Optimal
#         4	0.0377223028632474	Not feasible
#        13	0.0077185673827064	Optimal
#        14	0.0077839789706954	Optimal
#        15	0.0078166847646899	Not feasible
#        16	0.0078003318676927	Optimal
#         1	0.1418184931539993	Not feasible
#         8	0.0006597473210683	Optimal
#        17	0.0078085083161913	Not feasible
#         1	0.1469940082481496	Not feasible
#        18	0.0078044200919420	Optimal
#         9	0.0009896209816025	Optimal
#        19	0.0078064642040666	Not feasible
#        10	0.0011545578118696	Not feasible
#        20	0.0078054421480043	Optimal
#        11	0.0010720893967360	Not feasible
#        12	0.0010308551891693	Not feasible
#         5	0.0188611514316237	Not feasible
#        21	0.0078059531760355	Not feasible
# Solution for Faecalibacterium_prausnitzii_M21_2 : <Solution 0.008 at 0x7f22c9f092a0>
# Building (14 threads):   1%|          | 3/495 [03:10<7:38:43, 55.94s/it]
# Loading Haemophilus_haemolyticus_M19501
#         2	0.0904981524773639	Not feasible
#         1	0.4688862582294145	Not feasible
#        13	0.0010102380853859	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp__dy17bw.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpyfg6xdzx.lp
# Reading time = 0.01 seconds
# : 1088 rows, 2480 columns, 10788 nonzeros
#        14	0.0010205466372776	Optimal
# Read LP format model from file /tmp/tmpb_j1cyua.lp
# Reading time = 0.00 seconds
# : 1114 rows, 2478 columns, 10618 nonzeros
#        15	0.0010257009132234	Optimal
#        16	0.0010282780511963	Not feasible
#         2	0.0709092465769997	Not feasible
#        17	0.0010269894822099	Not feasible
#        18	0.0010263451977167	Not feasible
# Solution for Filifactor_alocis_ATCC_35896 : <Solution 0.001 at 0x7f2157076f80>
# Building (14 threads):   1%|          | 4/495 [03:19<5:06:53, 37.50s/it]
#         2	0.0734970041240748	Not feasible
# Loading Streptococcus_sp_2_1_36FAA
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpvowcgt7u.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         3	0.0583992393801683	Not feasible
#         8	0.0011095690920951	Not feasible
#         6	0.0094305757158119	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmp6fsrq629.lp
# Reading time = 0.00 seconds
# : 922 rows, 2020 columns, 8696 nonzeros
#         3	0.0354546232884998	Not feasible
# Read LP format model from file /tmp/tmpngd5fyeg.lp
# Reading time = 0.00 seconds
# : 945 rows, 2018 columns, 8576 nonzeros
#         1	0.1041152844241089	Not feasible
#         7	0.0047152878579059	Not feasible
#         3	0.0367485020620374	Not feasible
#         3	0.0452490762386820	Not feasible
#         2	0.2344431291147073	Not feasible
#         4	0.0291996196900842	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         8	0.0023576439289530	Optimal
#         9	0.0035364658934294	Not feasible
#         4	0.0177273116442499	Not feasible
#        10	0.0029470549111912	Optimal
#        11	0.0032417604023103	Not feasible
#        12	0.0030944076567508	Not feasible
#        13	0.0030207312839710	Not feasible
#        14	0.0029838930975811	Not feasible
#        15	0.0029654740043862	Optimal
#         2	0.0520576422120545	Not feasible
#         9	0.0005547845460476	Optimal
#        16	0.0029746835509836	Optimal
#        17	0.0029792883242824	Not feasible
#        18	0.0029769859376330	Not feasible
#        19	0.0029758347443083	Optimal
#        20	0.0029764103409706	Optimal
# Solution for Eubacterium_rectale_ATCC_33656 : <Solution 0.003 at 0x7f22fdb202b0>
# Building (14 threads):   1%|          | 5/495 [03:54<4:58:50, 36.59s/it]
# Loading Dorea_formicigenerans_ATCC_27755
#        10	0.0008321768190713	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpsiylo5i4.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        11	0.0009708729555832	Optimal
#         5	0.0088636558221250	Not feasible
#         4	0.0183742510310187	Not feasible
#        12	0.0010402210238392	Optimal
#        13	0.0010748950579671	Not feasible
#        14	0.0010575580409031	Not feasible
#         3	0.0260288211060272	Not feasible
#        15	0.0010488895323712	Not feasible
#        16	0.0010445552781052	Optimal
# Read LP format model from file /tmp/tmp_qmcl3hn.lp
# Reading time = 0.01 seconds
# : 1122 rows, 2550 columns, 11172 nonzeros
#         1	0.1510667533947308	Not feasible
#         5	0.0145998098450421	Not feasible
#        17	0.0010467224052382	Not feasible
#        18	0.0010456388416717	Optimal
#        19	0.0010461806234549	Optimal
# Solution for Bacteroides_sp_1_1_30 : <Solution 0.001 at 0x7f218009b400>
# Building (14 threads):   1%|          | 6/495 [04:15<4:14:44, 31.26s/it]
# Loading Anaerofustis_stercorihominis_DSM_17244
#         1	0.0728940314917466	Not feasible
#         6	0.0044318279110625	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpt9pw3jr_.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmppjva_7ul.lp
# Reading time = 0.00 seconds
# : 922 rows, 1972 columns, 8604 nonzeros
# Read LP format model from file /tmp/tmp60lk5lpo.lp
# Reading time = 0.00 seconds
# : 947 rows, 1970 columns, 8404 nonzeros
# Read LP format model from file /tmp/tmp4tr7st20.lp
# Reading time = 0.00 seconds
# : 1145 rows, 2548 columns, 10972 nonzeros
#         1	0.0299603701612049	Not feasible
#         3	0.1172215645573536	Not feasible
#         5	0.0091871255155094	Not feasible
#         1	0.3055932297598425	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         7	0.0022159139555312	Not feasible
#         4	0.0130144105530136	Not feasible
#         4	0.0226245381193410	Not feasible
#         2	0.0364470157458733	Not feasible
#         2	0.0149801850806025	Not feasible
#         6	0.0072999049225210	Not feasible
#         8	0.0011079569777656	Not feasible
#         6	0.0045935627577547	Not feasible
#         1	0.4833770305234439	Not feasible
#         3	0.0074900925403012	Not feasible
#         2	0.1527966148799212	Not feasible
#         5	0.0113122690596705	Not feasible
#         3	0.0182235078729367	Not feasible
#         9	0.0005539784888828	Optimal
#         5	0.0065072052765068	Not feasible
#        10	0.0008309677333242	Optimal
#         1	0.0627547116943523	Not feasible
#        11	0.0009694623555449	Optimal
#        12	0.0010387096666553	Not feasible
#        13	0.0010040860111001	Optimal
#        14	0.0010213978388777	Not feasible
#        15	0.0010127419249889	Not feasible
#        16	0.0010084139680445	Optimal
#        17	0.0010105779465167	Not feasible
#        18	0.0010094959572806	Not feasible
#        19	0.0010089549626625	Not feasible
# Solution for Porphyromonas_somerae_DSM_23386 : <Solution 0.001 at 0x7f210ceb78b0>
# Building (14 threads):   1%|▏         | 7/495 [05:09<5:14:53, 38.72s/it]
# Loading Bacteroides_ovatus_SD_CMC_3f
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpfzh3fyql.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         7	0.0036499524612605	Not feasible
#         4	0.0586107822786768	Not feasible
#         4	0.0037450462701506	Not feasible
#         6	0.0056561345298352	Not feasible
#         3	0.0763983074399606	Not feasible
# Read LP format model from file /tmp/tmpnut09e3y.lp
# Reading time = 0.00 seconds
# : 1043 rows, 2398 columns, 10058 nonzeros
#         2	0.0755333766973654	Not feasible
#         6	0.0032536026382534	Not feasible
#         2	0.0313773558471762	Not feasible
#         7	0.0022967813788773	Not feasible
#         4	0.0091117539364683	Not feasible
# Read LP format model from file /tmp/tmplrlcajc7.lp
# Reading time = 0.00 seconds
# : 1068 rows, 2396 columns, 9938 nonzeros
#         1	0.5575748228402025	Not feasible
#         1	0.2253509717887896	Not feasible
#         5	0.0018725231350753	Not feasible
#         3	0.0156886779235881	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         7	0.0016268013191267	Not feasible
#         8	0.0018249762306303	Not feasible
#         7	0.0028280672649176	Not feasible
#         8	0.0011483906894387	Not feasible
#         6	0.0009362615675377	Optimal
#         3	0.0377666883486827	Not feasible
#         4	0.0078443389617940	Not feasible
#         2	0.1126754858943948	Not feasible
#         4	0.0381991537199803	Not feasible
#         7	0.0014043923513065	Not feasible
#         5	0.0045558769682342	Not feasible
#         8	0.0008134006595634	Optimal
#         5	0.0293053911393384	Not feasible
#         9	0.0012201009893450	Not feasible
#         8	0.0011703269594221	Not feasible
#        10	0.0010167508244542	Optimal
#        11	0.0011184259068996	Not feasible
#         9	0.0010532942634799	Not feasible
#         3	0.0563377429471974	Not feasible
#        12	0.0010675883656769	Not feasible
#        10	0.0009947779155088	Optimal
#         9	0.0005741953447193	Optimal
#         1	0.2134730809015157	Not feasible
#        11	0.0010240360894943	Not feasible
#         5	0.0039221694808970	Not feasible
#        13	0.0010421695950655	Optimal
#        12	0.0010094070025015	Optimal
#        10	0.0008612930170790	Optimal
#         2	0.2416885152617220	Not feasible
#        11	0.0010048418532588	Not feasible
#        13	0.0010167215459979	Not feasible
#        14	0.0010548789803712	Optimal
#         9	0.0009124881153151	Optimal
#         8	0.0014140336324588	Not feasible
#        14	0.0010130642742497	Not feasible
#        15	0.0010612336730241	Optimal
#        15	0.0010112356383756	Not feasible
#        10	0.0013687321729727	Not feasible
#        16	0.0010644110193505	Not feasible
#        12	0.0009330674351689	Optimal
#         6	0.0022779384841171	Not feasible
#        16	0.0010103213204386	Not feasible
# Solution for Streptococcus_sp_2_1_36FAA : <Solution 0.001 at 0x7f21319c0310>
# Building (14 threads):   2%|▏         | 8/495 [06:36<7:17:35, 53.91s/it]
# Loading Brevibacterium_massiliense_5401308
#        17	0.0010628223461873	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp8k70a2ck.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        11	0.0011406101441439	Not feasible
#         2	0.2787874114201013	Not feasible
#        13	0.0009689546442139	Optimal
#        18	0.0010620280096057	Not feasible
# Solution for Lactobacillus_paracasei_subsp_paracasei_ATCC_25302 : <Solution 0.001 at 0x7f2127aee290>
# Building (14 threads):   2%|▏         | 9/495 [06:41<5:12:43, 38.61s/it]
#        12	0.0010265491297295	Optimal
# Loading Actinomyces_odontolyticus_ATCC_17982
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp8dgy1qde.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        14	0.0009868982487364	Optimal
#        13	0.0010835796369367	Not feasible
#        15	0.0009958700509976	Optimal
#         5	0.0190995768599902	Not feasible
#         6	0.0019610847404485	Not feasible
#         4	0.0281688714735987	Not feasible
#        14	0.0010550643833331	Not feasible
#        16	0.0010003559521282	Optimal
# Read LP format model from file /tmp/tmpx9o0w9uy.lp
# Reading time = 0.01 seconds
# : 1097 rows, 2470 columns, 10782 nonzeros
#        17	0.0010025989026935	Not feasible
#         2	0.1067365404507579	Not feasible
#        15	0.0010408067565313	Not feasible
# Read LP format model from file /tmp/tmpywd6d144.lp
# Reading time = 0.00 seconds
# : 793 rows, 1708 columns, 7238 nonzeros
#        16	0.0010336779431304	Optimal
#        18	0.0010014774274109	Optimal
#         4	0.0188833441743414	Not feasible
#        17	0.0010372423498309	Optimal
#        19	0.0010020381650522	Optimal
# Solution for Marvinbryantia_formatexigens_I_52_DSM_14469 : <Solution 0.001 at 0x7f21850565f0>
# Building (14 threads):   2%|▏         | 10/495 [06:55<4:11:38, 31.13s/it]
#         6	0.0146526955696692	Not feasible
# Loading Ureaplasma_parvum_serovar_1_str_ATCC_27813
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpjbk6k7f9.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        18	0.0010390245531811	Optimal
# Read LP format model from file /tmp/tmpes7gjdpq.lp
# Reading time = 0.00 seconds
# : 794 rows, 1706 columns, 7118 nonzeros
# Read LP format model from file /tmp/tmpvbd9v1jd.lp
# Reading time = 0.00 seconds
# : 623 rows, 1330 columns, 5350 nonzeros
#        19	0.0010399156548562	Optimal
# Solution for Actinomyces_viscosus_C505 : <Solution 0.001 at 0x7f211cb31c30>
# Building (14 threads):   2%|▏         | 11/495 [07:00<3:06:39, 23.14s/it]
# Read LP format model from file /tmp/tmp407eoq2w.lp
# Reading time = 0.01 seconds
# : 1107 rows, 2468 columns, 10612 nonzeros
# Loading Ralstonia_sp_5_7_47FAA
#         7	0.0011389692420585	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmppmq5hzkr.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmp73wrn936.lp
# Reading time = 0.00 seconds
# : 623 rows, 1328 columns, 5188 nonzeros
#         3	0.1208442576308610	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         7	0.0009805423702243	Optimal
#         8	0.0014708135553364	Not feasible
#         5	0.0140844357367994	Not feasible
#         3	0.0533682702253789	Not feasible
#         9	0.0012256779627803	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         1	0.0586082698927088	Not feasible
# Read LP format model from file /tmp/tmp98ravt7g.lp
# Reading time = 0.01 seconds
# : 1194 rows, 2986 columns, 13080 nonzeros
#        10	0.0011031101665023	Not feasible
#         2	0.0293041349463544	Not feasible
#        11	0.0010418262683633	Not feasible
#         9	0.0007070168162294	Optimal
#        12	0.0010111843192938	Optimal
#         3	0.0146520674731772	Not feasible
#        13	0.0010265052938285	Not feasible
#         4	0.0073260337365886	Not feasible
#        10	0.0010605252243441	Not feasible
#         1	0.0723727951495785	Not feasible
#         8	0.0005694846210293	Optimal
#        14	0.0010188448065611	Not feasible
# Read LP format model from file /tmp/tmpz8x1uhc3.lp
# Reading time = 0.01 seconds
# : 1225 rows, 2984 columns, 12960 nonzeros
#         9	0.0008542269315439	Optimal
#         5	0.0036630168682943	Not feasible
#        15	0.0010150145629275	Not feasible
#        10	0.0009965980868012	Optimal
#        11	0.0008837710202868	Optimal
#        11	0.0010677836644299	Not feasible
#         6	0.0018315084341471	Not feasible
#        12	0.0010321908756156	Not feasible
#        13	0.0010143944812084	Not feasible
#        16	0.0010130994411106	Optimal
#         4	0.0266841351126895	Not feasible
#        14	0.0010054962840048	Optimal
#         2	0.0361863975747892	Not feasible
#         7	0.0009157542170736	Optimal
#        15	0.0010099453826066	Optimal
#         8	0.0013736313256104	Not feasible
#         9	0.0011446927713420	Not feasible
#        17	0.0010140570020190	Optimal
# Solution for Anaerofustis_stercorihominis_DSM_17244 : <Solution 0.001 at 0x7f22e775b160>
#        16	0.0010121699319075	Optimal
#         5	0.0094416720871707	Not feasible
# Building (14 threads):   2%|▏         | 12/495 [07:38<3:42:31, 27.64s/it]
#        10	0.0010302234942078	Not feasible
# Loading Clostridium_spiroforme_DSM_1552
#        11	0.0009729888556407	Optimal
#        12	0.0009721481223154	Optimal
#        17	0.0010132822065579	Not feasible
#        12	0.0010016061749242	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpdl9n8fvz.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        13	0.0010159148345660	Not feasible
#        14	0.0010087605047451	Optimal
#        18	0.0010127260692327	Not feasible
# Solution for Haemophilus_haemolyticus_M19501 : <Solution 0.001 at 0x7f22d0fe5090>
# Building (14 threads):   3%|▎         | 13/495 [07:40<2:40:08, 19.93s/it]
# Loading Bacteroides_dorei_DSM_17855
#        15	0.0010123376696556	Not feasible
#         6	0.0070422178683997	Not feasible
#        16	0.0010105490872003	Not feasible
#        17	0.0010096547959727	Not feasible
# Solution for Ureaplasma_parvum_serovar_1_str_ATCC_27813 : <Solution 0.001 at 0x7f2262e4da20>
# Building (14 threads):   3%|▎         | 14/495 [07:41<1:54:07, 14.24s/it]
# Loading Streptococcus_gordonii_str_Challis_substr_CH1
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpx_kimtl6.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpra65dhqw.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         6	0.0095497884299951	Not feasible
#        13	0.0010163366733298	Not feasible
#         3	0.0180931987873946	Not feasible
# Read LP format model from file /tmp/tmpyhhi63kt.lp
# Reading time = 0.00 seconds
# : 909 rows, 1886 columns, 8182 nonzeros
#        14	0.0009942423978226	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmp5pyhwol3.lp
# Reading time = 0.00 seconds
# : 1090 rows, 2606 columns, 11138 nonzeros
#        15	0.0010052895355762	Optimal
# Read LP format model from file /tmp/tmpp8evvt3r.lp
# Reading time = 0.00 seconds
# : 1061 rows, 2372 columns, 10116 nonzeros
#         5	0.0133420675563447	Not feasible
# Read LP format model from file /tmp/tmpdk0siuhk.lp
# Reading time = 0.00 seconds
# : 932 rows, 1884 columns, 8062 nonzeros
#         7	0.0073263477848346	Not feasible
#        16	0.0010108131044530	Optimal
#         1	0.0371551736040632	Not feasible
# Read LP format model from file /tmp/tmpx86myc73.lp
# Reading time = 0.00 seconds
# : 1101 rows, 2604 columns, 10938 nonzeros
#        17	0.0010135748888914	Optimal
#         4	0.0090465993936973	Not feasible
#        18	0.0010149557811106	Not feasible
#         3	0.1393937057100506	Not feasible
# Read LP format model from file /tmp/tmp53ozhtlm.lp
# Reading time = 0.00 seconds
# : 1086 rows, 2370 columns, 9994 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        19	0.0010142653350010	Optimal
# Solution for Listeria_monocytogenes_4a_L99 : <Solution 0.001 at 0x7f216956d4e0>
# Building (14 threads):   3%|▎         | 15/495 [08:07<2:20:54, 17.61s/it]
# Loading Oxalobacter_formigenes_HOxBLS
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpcnpp1j87.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         5	0.0045232996968487	Not feasible
# Read LP format model from file /tmp/tmp3il78i3f.lp
# Reading time = 0.00 seconds
# : 850 rows, 1822 columns, 7954 nonzeros
#         7	0.0035211089341998	Not feasible
#         2	0.0185775868020316	Not feasible
#         6	0.0066710337781724	Not feasible
# Read LP format model from file /tmp/tmpf_vj7mbl.lp
# Reading time = 0.00 seconds
# : 876 rows, 1820 columns, 7834 nonzeros
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         7	0.0047748942149975	Not feasible
#         6	0.0022616498484243	Not feasible
#         1	0.1065586635242210	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         7	0.0033355168890862	Not feasible
#         3	0.0092887934010158	Not feasible
#         2	0.0532793317621105	Not feasible
#         4	0.0604221288154305	Not feasible
#         7	0.0011308249242122	Not feasible
#         8	0.0017605544670999	Not feasible
#         6	0.0047208360435853	Not feasible
#         1	0.4923559629884023	Not feasible
#         3	0.0266396658810553	Not feasible
#         1	0.0274272151358350	Not feasible
#         8	0.0005654124621061	Optimal
#         8	0.0036631738924173	Not feasible
#         8	0.0016677584445431	Optimal
#         9	0.0008481186931591	Optimal
#         4	0.0133198329405276	Not feasible
#         4	0.0046443967005079	Not feasible
#        10	0.0009894718086856	Optimal
#         9	0.0025016376668146	Not feasible
#         1	0.1312061748250231	Not feasible
#         2	0.0137136075679175	Not feasible
#         8	0.0023874471074988	Not feasible
#        11	0.0010601483664489	Not feasible
#        10	0.0020846980556789	Not feasible
#        12	0.0010248100875673	Optimal
#         2	0.2461779814942012	Not feasible
#        13	0.0010424792270081	Optimal
#        14	0.0010513137967285	Not feasible
#        15	0.0010468965118683	Not feasible
#        16	0.0010446878694382	Optimal
#         9	0.0008802772335500	Optimal
#        11	0.0018762282501110	Optimal
#        17	0.0010457921906532	Not feasible
#        10	0.0013204158503249	Not feasible
#        12	0.0019804631528949	Not feasible
#        18	0.0010452400300457	Optimal
# Solution for Actinomyces_odontolyticus_ATCC_17982 : <Solution 0.001 at 0x7f20d2328250>
# Building (14 threads):   3%|▎         | 16/495 [09:21<4:37:55, 34.81s/it]
# Loading Lactobacillus_plantarum_JDM1
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpvjj_sorz.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         3	0.0068568037839588	Not feasible
#         5	0.0066599164702638	Not feasible
#        11	0.0011003465419374	Optimal
#        13	0.0019283457015029	Optimal
#         3	0.1230889907471006	Not feasible
#         2	0.0656030874125116	Not feasible
#        12	0.0012103811961312	Not feasible
#        14	0.0019544044271989	Not feasible
#         5	0.0023221983502539	Not feasible
# Read LP format model from file /tmp/tmpn22bm5o7.lp
# Reading time = 0.00 seconds
# : 1051 rows, 2470 columns, 10490 nonzeros
#        15	0.0019413750643509	Not feasible
#        13	0.0011553638690343	Not feasible
#        16	0.0019348603829269	Not feasible
#         4	0.0034284018919794	Not feasible
# Read LP format model from file /tmp/tmpcl13obgr.lp
# Reading time = 0.00 seconds
# : 1074 rows, 2468 columns, 10290 nonzeros
#        17	0.0019316030422149	Not feasible
#         6	0.0033299582351319	Not feasible
#        14	0.0011278552054859	Optimal
#         7	0.0023604180217927	Not feasible
#         1	0.0941796353825233	Not feasible
#        15	0.0011416095372601	Optimal
#         3	0.0328015437062558	Not feasible
#        16	0.0011484867031472	Not feasible
#         4	0.0696968528550253	Not feasible
#         5	0.0302110644077152	Not feasible
#         4	0.0615444953735503	Not feasible
#        18	0.0019299743718589	Optimal
#        17	0.0011450481202037	Optimal
#        19	0.0019307887070369	Not feasible
# Solution for Bacteroides_ovatus_SD_CMC_3f : <Solution 0.002 at 0x7f211ca3a9b0>
# Building (14 threads):   3%|▎         | 17/495 [09:55<4:34:32, 34.46s/it]
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Loading Yersinia_enterocolitica_subsp_enterocolitica_8081
#         9	0.0011937235537494	Not feasible
#        18	0.0011467674116754	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpbw45iszd.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         5	0.0017142009459897	Not feasible
#        19	0.0011459077659395	Optimal
# Solution for Dorea_formicigenerans_ATCC_27755 : <Solution 0.001 at 0x7f210429df90>
# Building (14 threads):   4%|▎         | 18/495 [10:02<3:26:58, 26.03s/it]
# Loading Aeromonas_caviae_Ae398
#         6	0.0011610991751270	Optimal
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpnmg_xxg1.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         7	0.0017416487626905	Not feasible
#         7	0.0016649791175660	Not feasible
# Read LP format model from file /tmp/tmplphp5lh7.lp
# Reading time = 0.00 seconds
# : 1340 rows, 3374 columns, 14518 nonzeros
#         8	0.0014513739689087	Not feasible
#         9	0.0013062365720178	Not feasible
#         9	0.0018315869462087	Not feasible
#        10	0.0012336678735724	Optimal
#         4	0.0164007718531279	Not feasible
#         6	0.0008571004729948	Optimal
#        11	0.0012699522227951	Optimal
#        12	0.0012880943974065	Optimal
#         7	0.0012856507094923	Not feasible
# Read LP format model from file /tmp/tmpsfagp8gg.lp
# Reading time = 0.01 seconds
# : 1262 rows, 3138 columns, 13702 nonzeros
#         8	0.0008324895587830	Optimal
#        13	0.0012971654847122	Not feasible
#         8	0.0010713755912436	Not feasible
#         9	0.0012487343381745	Not feasible
#        14	0.0012926299410593	Not feasible
# Read LP format model from file /tmp/tmpjce73_j0.lp
# Reading time = 0.01 seconds
# : 1365 rows, 3372 columns, 14348 nonzeros
#         9	0.0009642380321192	Optimal
#        10	0.0010406119484787	Not feasible
#        15	0.0012903621692329	Optimal
#         2	0.0470898176912616	Not feasible
#        10	0.0010178068116814	Not feasible
#        11	0.0009365507536308	Optimal
#        16	0.0012914960551461	Optimal
#        12	0.0009885813510548	Optimal
#        17	0.0012920629981027	Optimal
# Solution for Brevibacterium_massiliense_5401308 : <Solution 0.001 at 0x7f2095319630>
#        11	0.0009910224219003	Optimal
# Building (14 threads):   4%|▍         | 19/495 [10:29<3:29:41, 26.43s/it]
# Loading Alistipes_shahii_WAL_8301
#        12	0.0010044146167908	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpgg1gscxe.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        13	0.0010145966497668	Not feasible
#        13	0.0009977185193456	Optimal
#         5	0.0307722476867751	Not feasible
#        14	0.0010010665680682	Optimal
#         5	0.0082003859265639	Not feasible
#        15	0.0010027405924295	Optimal
#        14	0.0010015890004108	Optimal
# Read LP format model from file /tmp/tmpuwav_xm4.lp
# Reading time = 0.01 seconds
# : 1287 rows, 3136 columns, 13532 nonzeros
#        16	0.0010035776046102	Not feasible
# Solution for Oxalobacter_formigenes_HOxBLS : <Solution 0.001 at 0x7f20fea5f160>
# Building (14 threads):   4%|▍         | 20/495 [10:37<2:45:44, 20.94s/it]
#        15	0.0010080928250888	Not feasible
# Loading Porphyromonas_gingivalis_W83
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp81bhfb2a.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        16	0.0010048409127498	Not feasible
#        17	0.0010032149565803	Not feasible
# Read LP format model from file /tmp/tmp9zx_j1o0.lp
# Reading time = 0.00 seconds
# : 953 rows, 2132 columns, 9214 nonzeros
#        18	0.0010024019784955	Optimal
# Solution for Clostridium_spiroforme_DSM_1552 : <Solution 0.001 at 0x7f210baab250>
# Building (14 threads):   4%|▍         | 21/495 [10:41<2:06:00, 15.95s/it]
# Loading Rhodococcus_equi_ATCC_33707
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmp4isb5z1s.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmprlqgyf_v.lp
# Reading time = 0.00 seconds
# : 970 rows, 2072 columns, 8888 nonzeros
#        10	0.0005968617768747	Optimal
# Read LP format model from file /tmp/tmpqvgay9lt.lp
# Reading time = 0.00 seconds
# : 978 rows, 2130 columns, 9044 nonzeros
# Read LP format model from file /tmp/tmpylujwquf.lp
# Reading time = 0.00 seconds
# : 995 rows, 2070 columns, 8718 nonzeros
#        11	0.0008952926653120	Optimal
#         6	0.0041001929632820	Not feasible
#         6	0.0151055322038576	Not feasible
#         6	0.0153861238433876	Not feasible
#        12	0.0010445081095307	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmpif3ij21x.lp
# Reading time = 0.01 seconds
# : 1300 rows, 3152 columns, 13770 nonzeros
#         8	0.0011802090108963	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        13	0.0009699003874214	Optimal
#         3	0.0235449088456308	Not feasible
#         1	0.2541516245871500	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        14	0.0010072042484760	Optimal
#        15	0.0010258561790034	Not feasible
# Read LP format model from file /tmp/tmpf5j0zdlv.lp
# Reading time = 0.01 seconds
# : 1301 rows, 3150 columns, 13600 nonzeros
#        16	0.0010165302137397	Not feasible
#         7	0.0020500964816410	Not feasible
#        17	0.0010118672311079	Optimal
#         1	0.0693579319879375	Not feasible
#        18	0.0010141987224238	Not feasible
#        10	0.0009157934731043	Optimal
#         7	0.0076930619216938	Not feasible
#        19	0.0010130329767658	Not feasible
#        20	0.0010124501039369	Not feasible
# Solution for Clostridium_botulinum_A_str_ATCC_19397 : <Solution 0.001 at 0x7f217e82be50>
# Building (14 threads):   4%|▍         | 22/495 [11:27<3:15:32, 24.80s/it]
# Loading Streptococcus_anginosus_1_2_62CV
#         2	0.0346789659939688	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpe2536z1u.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
# Read LP format model from file /tmp/tmpjx1euuwd.lp
# Reading time = 0.00 seconds
# : 815 rows, 1764 columns, 7508 nonzeros
# Read LP format model from file /tmp/tmp4gfe04t0.lp
# Reading time = 0.00 seconds
# : 817 rows, 1762 columns, 7388 nonzeros
#        11	0.0013736902096565	Not feasible
#         2	0.1270758122935750	Not feasible
#        12	0.0011447418413804	Not feasible
#         4	0.0117724544228154	Not feasible
#         1	0.1854402132549866	Not feasible
#         8	0.0010250482408205	Optimal
#         3	0.0173394829969844	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         9	0.0015375723612307	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#        10	0.0012813103010256	Optimal
#        13	0.0010302676572424	Optimal
#        11	0.0014094413311282	Not feasible
#        12	0.0013453758160769	Not feasible
#        13	0.0013133430585513	Optimal
#         4	0.0086697414984922	Not feasible
#        14	0.0010875047493114	Not feasible
#         2	0.0927201066274933	Not feasible
#        14	0.0013293594373141	Optimal
#        15	0.0013373676266955	Not feasible
#        16	0.0013333635320048	Not feasible
#         8	0.0038465309608469	Not feasible
#        17	0.0013313614846594	Not feasible
#         7	0.0075527661019288	Not feasible
#         5	0.0348484264275127	Not feasible
#        18	0.0013303604609868	Not feasible
#        15	0.0010588862032769	Optimal
#        19	0.0013298599491504	Optimal
# Solution for Bacteroides_dorei_DSM_17855 : <Solution 0.001 at 0x7f20b5350d00>
# Building (14 threads):   5%|▍         | 23/495 [12:04<3:44:14, 28.51s/it]
# Loading Bifidobacterium_animalis_lactis_DSM_10140
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpd5wfos3b.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         9	0.0005901045054482	Optimal
#        16	0.0010731954762941	Not feasible
#         5	0.0043348707492461	Not feasible
#         1	0.0184054046170223	Not feasible
#         3	0.0463600533137467	Not feasible
#        17	0.0010660408397855	Not feasible
#        18	0.0010624635215312	Not feasible
# Read LP format model from file /tmp/tmpkc7_lug4.lp
# Reading time = 0.00 seconds
# : 868 rows, 1912 columns, 8180 nonzeros
#        19	0.0010606748624040	Not feasible
#         3	0.0635379061467875	Not feasible
# Read LP format model from file /tmp/tmpnrprfe4m.lp
# Reading time = 0.00 seconds
# : 868 rows, 1910 columns, 8010 nonzeros
#         5	0.0058862272114077	Not feasible
#         2	0.0092027023085112	Not feasible
#        20	0.0010597805328405	Optimal
# Solution for Escherichia_sp_4_1_40B : <Solution 0.001 at 0x7f22a939b4c0>
# Building (14 threads):   5%|▍         | 24/495 [12:20<3:13:36, 24.66s/it]
# Loading Streptococcus_uberis_0140J
#         6	0.0021674353746230	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpz_3th8oe.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#         9	0.0019232654804234	Not feasible
#         4	0.0231800266568733	Not feasible
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
# Read LP format model from file /tmp/tmpy_5szdmp.lp
# Reading time = 0.00 seconds
# : 1064 rows, 2490 columns, 10616 nonzeros
#         3	0.0046013511542556	Not feasible
#        10	0.0008851567581723	Optimal
#         7	0.0010837176873115	Not feasible
#         5	0.0115900133284367	Not feasible
# Read LP format model from file /tmp/tmplyjlwmw0.lp
# Reading time = 0.00 seconds
# : 1066 rows, 2488 columns, 10416 nonzeros
#         4	0.0317689530733938	Not feasible
#        10	0.0009616327402117	Optimal
#        11	0.0010326828845343	Not feasible
#         6	0.0057950066642183	Not feasible
#         4	0.0023006755771278	Not feasible
#         8	0.0005418588436558	Optimal
# Iteration	 Solution to check	Solver Status
# ---------	------------------	-------------
#         9	0.0008127882654836	Optimal
#        11	0.0014424491103176	Not feasible
#         1	0.0393640633471588	Not feasible
#        10	0.0009482529763976	Optimal
#        11	0.0010159853318546	Not feasible
#         1	0.4576334489709876	Not feasible
#        12	0.0009821191541261	Optimal
#        12	0.0012020409252647	Not feasible
#        13	0.0009990522429903	Optimal
#        14	0.0010075187874224	Optimal
#        15	0.0010117520596385	Not feasible
#        13	0.0010818368327382	Not feasible
#        16	0.0010096354235305	Not feasible
#        12	0.0009589198213533	Optimal
#        17	0.0010085771054764	Optimal
#        18	0.0010091062645035	Optimal
# Solution for Porphyromonas_gingivalis_W83 : <Solution 0.001 at 0x7f2128bc2dd0>
# Building (14 threads):   5%|▌         | 25/495 [13:03<3:56:50, 30.24s/it]
# Loading Lactobacillus_coleohominis_101_4_CHN
#         5	0.0158844765366969	Not feasible
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-08-16
# Read LP format model from file /tmp/tmpmck0eqzl.lp
# Reading time = 0.00 seconds
# : 0 rows, 0 columns, 0 nonzeros
#        14	0.0010217347864750	Not feasible
#         1	0.4764609344306396	Not feasible
#        13	0.0009958013529438	Optimal
#         2	0.0196820316735794	Not feasible
#        15	0.0009916837633433	Optimal
# Read LP format model from file /tmp/tmp9qak93u7.lp
# Reading time = 0.00 seconds
# : 960 rows, 2116 columns, 9036 nonzeros
#         5	0.0011503377885639	Not feasible
#         7	0.0028975033321092	Not feasible
#        16	0.0010067092749091	Optimal
#         8	0.0037763830509644	Not feasible
#        17	0.0010142220306921	Not feasible
#        14	0.0010142421187390	Not feasible
#         3	0.0098410158367897	Not feasible
# Read LP format model from file /tmp/tmp6k1zuwbi.lp
# Reading time = 0.00 seconds
# : 971 rows, 2114 columns, 8836 nonzeros
#        18	0.0010104656528006	Not feasible
